# %%
import pandas as pd
import numpy as np

# %%
miasta = pd.read_csv('F:/PandasUdemy/analityk-edu/worldcities.csv')

# %%
miasta.head()
# Out:
#       city city_ascii      lat       lng      country iso2 iso3   admin_name  \
# 0    Tokyo      Tokyo  35.6897  139.6922        Japan   JP  JPN        Tōkyō
# 1  Jakarta    Jakarta  -6.2146  106.8451    Indonesia   ID  IDN      Jakarta
# 2    Delhi      Delhi  28.6600   77.2300        India   IN  IND        Delhi
# 3   Mumbai     Mumbai  18.9667   72.8333        India   IN  IND  Mahārāshtra
# 4   Manila     Manila  14.5958  120.9772  Philippines   PH  PHL       Manila
#
#    capital  population          id
# 0  primary  37977000.0  1392685764
# 1  primary  34540000.0  1360771077
# 2    admin  29617000.0  1356872604
# 3    admin  23355000.0  1356226629
# 4  primary  23088000.0  1608618140

# %%
miasta[['lat','lng']]
# Out:
#            lat       lng
# 0      35.6897  139.6922
# 1      -6.2146  106.8451
# 2      28.6600   77.2300
# 3      18.9667   72.8333
# 4      14.5958  120.9772
# ...        ...       ...
# 26564  81.7166  -17.8000
# 26565  62.5333  -42.2167
# 26566  51.3894   30.0989
# 26567  69.6510  162.3336
# 26568  74.0165  111.5100
#
# [26569 rows x 2 columns]

# %%
miasta.city
# Out:
# 0              Tokyo
# 1            Jakarta
# 2              Delhi
# 3             Mumbai
# 4             Manila
#             ...
# 26564           Nord
# 26565    Timmiarmiut
# 26566    Cheremoshna
# 26567      Ambarchik
# 26568        Nordvik
# Name: city, Length: 26569, dtype: object

# %%
miasta.shape
# Out:
# (26569, 11)

# %%
len(miasta)
# Out:
# 26569

# %%
miasta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26569 entries, 0 to 26568
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        26569 non-null  object
#  1   city_ascii  26569 non-null  object
#  2   lat         26569 non-null  float64
#  3   lng         26569 non-null  float64
#  4   country     26569 non-null  object
#  5   iso2        26538 non-null  object
#  6   iso3        26569 non-null  object
#  7   admin_name  26493 non-null  object
#  8   capital     7626 non-null   object
#  9   population  25596 non-null  float64
#  10  id          26569 non-null  int64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 2.2+ MB

# %%
miasta.describe()
# Out:
#                 lat           lng    population            id
# count  26569.000000  26569.000000  2.559600e+04  2.656900e+04
# mean      33.095264    -11.363860  1.623457e+05  1.556097e+09
# std       22.393678     73.946817  8.996585e+05  2.873890e+08
# min      -54.934100   -179.590000  0.000000e+00  1.004003e+09
# 25%       27.918300    -78.779400  9.246000e+03  1.276656e+09
# 50%       40.218800     -0.768900  2.007950e+04  1.643148e+09
# 75%       47.987800     29.683300  5.936925e+04  1.840005e+09
# max       81.716600    179.366700  3.797700e+07  1.934000e+09

# %%
miasta.population.describe()
# Out:
# count    2.559600e+04
# mean     1.623457e+05
# std      8.996585e+05
# min      0.000000e+00
# 25%      9.246000e+03
# 50%      2.007950e+04
# 75%      5.936925e+04
# max      3.797700e+07
# Name: population, dtype: float64

# %%
miasta.isnull().sum()
# Out:
# city              0
# city_ascii        0
# lat               0
# lng               0
# country           0
# iso2             31
# iso3              0
# admin_name       76
# capital       18943
# population      973
# id                0
# dtype: int64

# %%
miasta.duplicated().sum()
# Out:
# 0

# %%
miasta.population.isnull().sum()
# Out:
# 973

# %%
miasta['capital'].unique()
# Out:
# array(['primary', 'admin', nan, 'minor'], dtype=object)

# %%
miasta['capital'].value_counts()
# Out:
# capital
# minor      3754
# admin      3664
# primary     208
# Name: count, dtype: int64

# %%
miasta['capital'].isnull().sum()
# Out:
# 18943

# %%
miasta.loc[miasta['capital'].isnull()]
# Out:
#               city   city_ascii      lat       lng        country iso2 iso3  \
# 12        New York     New York  40.6943  -73.9249  United States   US  USA
# 27     Los Angeles  Los Angeles  34.1139 -118.4068  United States   US  USA
# 29         Nanyang      Nanyang  32.9987  112.5292          China   CN  CHN
# 35           Linyi        Linyi  35.0606  118.3425          China   CN  CHN
# 38         Baoding      Baoding  38.8671  115.4845          China   CN  CHN
# ...            ...          ...      ...       ...            ...  ...  ...
# 26564         Nord         Nord  81.7166  -17.8000      Greenland   GL  GRL
# 26565  Timmiarmiut  Timmiarmiut  62.5333  -42.2167      Greenland   GL  GRL
# 26566  Cheremoshna  Cheremoshna  51.3894   30.0989        Ukraine   UA  UKR
# 26567    Ambarchik    Ambarchik  69.6510  162.3336         Russia   RU  RUS
# 26568      Nordvik      Nordvik  74.0165  111.5100         Russia   RU  RUS
#
# ...

# %%
miasta[['city','country']].head(10)
# Out:
#           city       country
# 0        Tokyo         Japan
# 1      Jakarta     Indonesia
# 2        Delhi         India
# 3       Mumbai         India
# 4       Manila   Philippines
# 5     Shanghai         China
# 6    São Paulo        Brazil
# 7        Seoul  Korea, South
# 8  Mexico City        Mexico
# 9    Guangzhou         China

# %%
kostium = pd.read_csv('F:/PandasUdemy/analityk-edu/Halloween.csv', header=2)

# %%
kostium.head()
# Out:
#        region             1            2             3         4          5
# 0      Alaska   Beetlejuice  Black Widow        Rabbit     Ninja    Pokemon
# 1     Alabama  Harley Quinn        Witch        Cowboy    Rabbit  Star Wars
# 2    Arkansas          Doll        Purge  Harley Quinn     1980s      Witch
# 3     Arizona        Rabbit        Witch         Ninja     Angel   Dinosaur
# 4  California         Witch        Clown        Rabbit  Fortnite   Dinosaur

# %%
kostium[:10][['region','1']]
# Out:
#                  region                1
# 0                Alaska      Beetlejuice
# 1               Alabama     Harley Quinn
# 2              Arkansas             Doll
# 3               Arizona           Rabbit
# 4            California            Witch
# 5              Colorado         Dinosaur
# 6           Connecticut  Powerpuff Girls
# 7  District of Columbia          Beyonce
# 8              Delaware             Doll
# 9               Florida           Rabbit

# %%
kostium[kostium['1'] == 'Doll']['5']
# Out:
# 2           Witch
# 8    Ghostbusters
# Name: 5, dtype: object

# %%
kostium.index
# Out:
# RangeIndex(start=0, stop=51, step=1)

# %%
kostium.set_index('region', inplace=True)

# %%
kostium.loc[:'Arizona']
# Out:
#                      1            2             3       4          5
# region
# Alaska     Beetlejuice  Black Widow        Rabbit   Ninja    Pokemon
# Alabama   Harley Quinn        Witch        Cowboy  Rabbit  Star Wars
# Arkansas          Doll        Purge  Harley Quinn   1980s      Witch
# Arizona         Rabbit        Witch         Ninja   Angel   Dinosaur

# %%
kostium.loc['Arizona','1'] = 'Batman'

# %%
kostium.loc['Arizona','1']
# Out:
# 'Batman'

# %%
kostium['1'] =='Batman'
# Out:
# region
# Alaska                  False
# Alabama                 False
# Arkansas                False
# Arizona                  True
# California              False
# Colorado                False
# Connecticut             False
# District of Columbia    False
# Delaware                False
# Florida                 False
# Georgia                 False
# Hawaii                  False
# Iowa                    False
# Idaho                   False
# Illinois                False
# Indiana                 False
# Kansas                  False
# Kentucky                False
# Louisiana               False
# Massachusetts           False
# Maryland                False
# Maine                   False
# Michigan                False
# Minnesota               False
# Missouri                False
# Mississippi             False
# Montana                 False
# North Carolina          False
# North Dakota            False
# Nebraska                False
# ...

# %%
kostium.index[kostium['1']=='Batman'][0]
# Out:
# 'Arizona'

# %%
kostium.reset_index(inplace=True)

# %%
kostium[['region','1']][:20]
# Out:
#                   region                1
# 0                 Alaska      Beetlejuice
# 1                Alabama     Harley Quinn
# 2               Arkansas             Doll
# 3                Arizona           Batman
# 4             California            Witch
# 5               Colorado         Dinosaur
# 6            Connecticut  Powerpuff Girls
# 7   District of Columbia          Beyonce
# 8               Delaware             Doll
# 9                Florida           Rabbit
# 10               Georgia            Witch
# 11                Hawaii     Monsters Inc
# 12                  Iowa           Chucky
# 13                 Idaho            Witch
# 14              Illinois         Dinosaur
# 15               Indiana            Witch
# 16                Kansas     Mickey Mouse
# 17              Kentucky           Zombie
# 18             Louisiana            Witch
# 19         Massachusetts         Dinosaur

# %%
kostium.loc[6,'1'] = 'Batman'

# %%
kostium[['region','1']][:20]
# Out:
#                   region             1
# 0                 Alaska   Beetlejuice
# 1                Alabama  Harley Quinn
# 2               Arkansas          Doll
# 3                Arizona        Batman
# 4             California         Witch
# 5               Colorado      Dinosaur
# 6            Connecticut        Batman
# 7   District of Columbia       Beyonce
# 8               Delaware          Doll
# 9                Florida        Rabbit
# 10               Georgia         Witch
# 11                Hawaii  Monsters Inc
# 12                  Iowa        Chucky
# 13                 Idaho         Witch
# 14              Illinois      Dinosaur
# 15               Indiana         Witch
# 16                Kansas  Mickey Mouse
# 17              Kentucky        Zombie
# 18             Louisiana         Witch
# 19         Massachusetts      Dinosaur

# %%
kostium.set_index('region', inplace=True)

# %%
kostium.loc['California','1'] = 'NOWitch'

# %%
kostium[['1']][:20]
# Out:
#                                  1
# region
# Alaska                 Beetlejuice
# Alabama               Harley Quinn
# Arkansas                      Doll
# Arizona                     Batman
# California                 NOWitch
# Colorado                  Dinosaur
# Connecticut                 Batman
# District of Columbia       Beyonce
# Delaware                      Doll
# Florida                     Rabbit
# Georgia                      Witch
# Hawaii                Monsters Inc
# Iowa                        Chucky
# Idaho                        Witch
# Illinois                  Dinosaur
# Indiana                      Witch
# Kansas                Mickey Mouse
# Kentucky                    Zombie
# Louisiana                    Witch
# Massachusetts             Dinosaur

# %%
kostium.reset_index(inplace=True)

# %%
kostium['region'].is_unique
# Out:
# True

# %%
kostium['1'].is_unique
# Out:
# False

# %%
kostium[['1','2','3','4','5']].value_counts()
# Out:
# 1                 2                 3               4                5
# Angel             Dinosaur          Harley Quinn    Witch            Spider             1
# Witch             Bride Of Chucky   Ninja           Dragon           1990s              1
# Ninja             Harley Quinn      Dinosaur        Rabbit           Zombie             1
#                                                     Scooby-Doo       Cop                1
# Physician         Purge             Lion            Pirate           The Mad Hatter     1
# Purge             Dragon            Lego            Lego             Angel              1
# Rabbit            Clown             Harley Quinn    Dinosaur         Witch              1
#                   Pirate            Angel           Dinosaur         Harley Quinn       1
#                   Witch             Harley Quinn    Dinosaur         Spider-Man         1
# Spider            Spider            Bear            Winnie The Pooh  Witch              1
# ...

# %%
unique_values = {}
for column in kostium.columns:
    unique_values[column] = kostium[column].unique()

# %%
# Wyświetlanie wyników
for column, values in unique_values.items():
    print(f"Unique values in {column}:\n{values}\n")
# Out:
# Unique values in region:
# ['Alaska' 'Alabama' 'Arkansas' 'Arizona' 'California' 'Colorado'
#  'Connecticut' 'District of Columbia' 'Delaware' 'Florida' 'Georgia'
#  'Hawaii' 'Iowa' 'Idaho' 'Illinois' 'Indiana' 'Kansas' 'Kentucky'
#  'Louisiana' 'Massachusetts' 'Maryland' 'Maine' 'Michigan' 'Minnesota'
#  'Missouri' 'Mississippi' 'Montana' 'North Carolina' 'North Dakota'
#  'Nebraska' 'New Hampshire' 'New Jersey' 'New Mexico' 'Nevada' 'New York'
#  'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Virginia' 'Vermont'
#  'Washington' 'Wisconsin' 'West Virginia' 'Wyoming']
#
# Unique values in 1:
# ['Beetlejuice' 'Harley Quinn' 'Doll' 'Batman' 'NOWitch' 'Dinosaur'
#  'Beyonce' 'Rabbit' 'Witch' 'Monsters Inc' 'Chucky' 'Mickey Mouse'
#  'Zombie' 'Ninja' 'Angel' 'Purge' 'Star Wars' 'Joker' 'Clueless' 'Dragon'
#  'Fortnite' 'Hermione Granger' 'Wonder Woman' 'Spider' 'Deer' 'Physician']
#
# Unique values in 2:
# ...

# %%
unique_costiums = pd.unique(kostium[['1','2','3','4','5']].values.flatten())

# %%
unique_costiums
# Out:
# array(['Beetlejuice', 'Black Widow', 'Rabbit', 'Ninja', 'Pokemon',
#        'Harley Quinn', 'Witch', 'Cowboy', 'Star Wars', 'Doll', 'Purge',
#        '1980s', 'Batman', 'Angel', 'Dinosaur', 'NOWitch', 'Clown',
#        'Fortnite', 'Bear', 'Mulan', 'Buzz Lightyear', 'Beyonce',
#        'Powerpuff Girls', nan, 'Luigi', 'Catwoman', 'Princess',
#        'Ghostbusters', 'Pirate', 'Monsters Inc', 'Descendants',
#        'Baby Yoda', 'Chucky', 'Zombie', 'Bride Of Chucky', 'Dragon',
#        '1990s', 'Devil', 'Spider-Man', 'Mickey Mouse', 'Paw Patrol',
#        'Cheerleader', 'Pumpkin', 'Alien', 'Vampire', 'Dalmatian', 'Lego',
#        'The Wizard Of Oz', 'Marilyn Monroe', 'Eleven', 'Joker',
#        'Mean Girls', 'Scooby-Doo', 'Cop', 'Clueless', 'It', 'Fairy',
#        'Hermione Granger', 'Wonder Woman', 'Spider', 'Winnie The Pooh',
#        'Superhero', 'Deer', 'Duck', 'Prince', 'Unicorn', 'Physician',
#        'Lion', 'The Mad Hatter'], dtype=object)

# %%
# Out:
# C:\Users\kpas9\AppData\Local\Temp\ipykernel_13224\2047997436.py:1: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   pd.unique(kostium[['1','2']])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 pd.unique(kostium[['1','2']])
#
# File D:\ProgramData\anaconda3\Lib\site-packages\pandas\core\algorithms.py:401, in unique(values)
#     307 def unique(values):
#     308     """
#     309     Return unique values based on a hash table.
#     310
#    (...)
#     399     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     400     """
# --> 401     return unique_with_mask(values)
#
# File D:\ProgramData\anaconda3\Lib\site-packages\pandas\core\algorithms.py:429, in unique_with_mask(values, mask)
# ...

# %%
kostium.head()
# Out:
#        region             1            2             3         4          5
# 0      Alaska   Beetlejuice  Black Widow        Rabbit     Ninja    Pokemon
# 1     Alabama  Harley Quinn        Witch        Cowboy    Rabbit  Star Wars
# 2    Arkansas          Doll        Purge  Harley Quinn     1980s      Witch
# 3     Arizona        Batman        Witch         Ninja     Angel   Dinosaur
# 4  California       NOWitch        Clown        Rabbit  Fortnite   Dinosaur

# %%
for index, row in kostium.iterrows():
    if row['1']=='Rabbit':
        print(row['region'])
# Out:
# Florida
# Michigan
# Virginia

# %%
kostium[(kostium['1'] == 'Doll') | (kostium['5'] == 'Witch')]
# Out:
#           region         1          2             3                4  \
# 2       Arkansas      Doll      Purge  Harley Quinn            1980s
# 8       Delaware      Doll   Princess      Dinosaur           Cowboy
# 12          Iowa    Chucky  Star Wars        Rabbit           Zombie
# 21         Maine  Dinosaur      Ninja         Alien            Alien
# 22      Michigan    Rabbit      Clown  Harley Quinn         Dinosaur
# 41  South Dakota    Spider     Spider          Bear  Winnie The Pooh
#
#                5
# 2          Witch
# 8   Ghostbusters
# 12         Witch
# 21         Witch
# 22         Witch
# 41         Witch

# %%
kostium[(kostium['1'] == 'Doll') & (kostium['5'] == 'Witch')]
# Out:
#      region     1      2             3      4      5
# 2  Arkansas  Doll  Purge  Harley Quinn  1980s  Witch

# %%
kostium[(kostium['1'] == 'Witch') & (kostium['2'] == 'Ninja')]
# Out:
#      region      1      2       3         4             5
# 10  Georgia  Witch  Ninja  Pirate  Dinosaur  Harley Quinn

# %%
kostium.loc[kostium['1'] == 'Doll', 'Nowa'] = 1

# %%
angel = kostium['1'] == 'Doll'

# %%
kostium.where(angel).drop(axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13224\2655075748.py in ?()
# ----> 1 kostium.where(angel).drop(axis=0)
#
# D:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5343                 weight  250.0   150.0
#    5344         falcon  speed   320.0   250.0
#    5345                 weight  1.0     0.8
#    5346         """
# -> 5347         return super().drop(
#    5348             labels=labels,
#    5349             axis=axis,
#    5350             index=index,
#
# D:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    4699             axes = {"index": index}
#    4700             if self.ndim == 2:
#    4701                 axes["columns"] = columns
#    4702         else:
# ...

# %%
df = kostium[kostium['1'] != 'Doll']

# %%
df.head()
# Out:
#        region             1            2       3             4          5  \
# 0      Alaska   Beetlejuice  Black Widow  Rabbit         Ninja    Pokemon
# 1     Alabama  Harley Quinn        Witch  Cowboy        Rabbit  Star Wars
# 3     Arizona        Batman        Witch   Ninja         Angel   Dinosaur
# 4  California       NOWitch        Clown  Rabbit      Fortnite   Dinosaur
# 5    Colorado      Dinosaur        Witch    Bear  Harley Quinn      Clown
#
#    Nowa
# 0   NaN
# 1   NaN
# 3   NaN
# 4   NaN
# 5   NaN

# %%
def fun(nd):
    if nd == 'Witch':
        return 'Ok'
    else:
        return 'Beee'

# %%
df.loc[1,'2']
# Out:
# 'Witch'

# %%
def code(wiersz):
    wiersz['CODE'], wiersz['ending'] = wiersz['region'][:3], wiersz['region'][3:]
    return wiersz.str.upper()

# %%
df.apply(code, axis=1)
# Out:
#                   region                 1                 2               3  \
# 0                 ALASKA       BEETLEJUICE       BLACK WIDOW          RABBIT
# 1                ALABAMA      HARLEY QUINN             WITCH          COWBOY
# 3                ARIZONA            BATMAN             WITCH           NINJA
# 4             CALIFORNIA           NOWITCH             CLOWN          RABBIT
# 5               COLORADO          DINOSAUR             WITCH            BEAR
# 6            CONNECTICUT            BATMAN             ANGEL           MULAN
# 7   DISTRICT OF COLUMBIA           BEYONCE   POWERPUFF GIRLS             NaN
# 9                FLORIDA            RABBIT            PIRATE           ANGEL
# 10               GEORGIA             WITCH             NINJA          PIRATE
# 11                HAWAII      MONSTERS INC      MONSTERS INC     DESCENDANTS
# 12                  IOWA            CHUCKY         STAR WARS          RABBIT
# ...

# %%
df.head()
# Out:
#        region             1            2       3             4          5  \
# 0      Alaska   Beetlejuice  Black Widow  Rabbit         Ninja    Pokemon
# 1     Alabama  Harley Quinn        Witch  Cowboy        Rabbit  Star Wars
# 3     Arizona        Batman        Witch   Ninja         Angel   Dinosaur
# 4  California       NOWitch        Clown  Rabbit      Fortnite   Dinosaur
# 5    Colorado      Dinosaur        Witch    Bear  Harley Quinn      Clown
#
#    Nowa
# 0   NaN
# 1   NaN
# 3  What
# 4   NaN
# 5   NaN
