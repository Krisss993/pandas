# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
bar = pd.read_csv('F:/PandasUdemy/course-files/weather_barcelona.csv', index_col='Date')

# %%
bar.head()
# Out:
#             TempMax  TempMin  Rain  AvgTempMax  AvgTempMin
# Date
# 2018-01-01       17       11     0          13           7
# 2018-01-02       19        8     0          13           7
# 2018-01-03       23       11     0          13           7
# 2018-01-04       24       15     0          13           7
# 2018-01-05       20       10     0          13           7

# %%
rom = pd.read_csv('F:/PandasUdemy/course-files/weather_rome.csv', index_col='Date')

# %%
ams = pd.read_csv('F:/PandasUdemy/course-files/weather_amsterdam.csv', index_col='Date')

# %%
bar.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bar['TempMax'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bar.plot(y='TempMax')
# Out:
# <Axes: xlabel='Date'>

# %%
bar.plot(y=['TempMax','TempMin'])
# Out:
# <Axes: xlabel='Date'>

# %%
nasa = pd.read_csv("F:/PandasUdemy/course-files/nasa_facebook_statuses.csv", 
                   usecols=["status_published","num_reactions", "num_comments","num_shares","num_likes"])

# %%
nasa["status_published"] = pd.to_datetime(nasa["status_published"])

# %%
filter =(nasa['status_published'] >= '2016-5-1') & (nasa['status_published']
< '2016-6-1')
nasa = nasa[filter]
#Add column with day only
nasa['day'] = nasa.apply(lambda row: row["status_published"].day,axis=1)
#Remove non-numeric column
nasa.drop('status_published', axis=1, inplace=True)
#Group all columns by sum
nasa_by_day = nasa.groupby(by='day').sum()
nasa_by_day.head()
# Out:
#      num_reactions  num_comments  num_shares  num_likes
# day
# 1            62629           727        4403      60243
# 2           188255          2328       23897     177989
# 3            53700           770       10858      50264
# 4           140098          1776       23360     133302
# 5            93146          1070        7627      89657

# %%
nasa_by_day.plot()
# Out:
# <Axes: xlabel='day'>

# %%
nasa_by_day['num_shares'].plot()
# Out:
# <Axes: xlabel='day'>

# %%
nasa_by_day[['num_shares','num_comments']].plot()
# Out:
# <Axes: xlabel='day'>

# %%
nasa_by_day.plot(y=['num_shares','num_comments'])
# Out:
# <Axes: xlabel='day'>

# %%
temp_max = pd.DataFrame(index=bar.index)

# %%
temp_max['Barcelona'] = bar['TempMax']
temp_max['Rome'] = rom['TempMax']
temp_max['Amsterdam'] = ams['TempMax']

# %%
temp_max.head()
# Out:
#             Barcelona  Rome  Amsterdam
# Date
# 2018-01-01         17    14          8
# 2018-01-02         19    13          9
# 2018-01-03         23    14         11
# 2018-01-04         24    16         11
# 2018-01-05         20    17          8

# %%
temp_max.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
temp_max.plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
temp_max.plot(figsize=(12,5), subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
temp_max.plot(figsize=(12,5), title = 'Max temp by city')
# Out:
# <Axes: title={'center': 'Max temp by city'}, xlabel='Date'>

# %%
temp_max.plot(figsize=(12,5), logy = True)
# Out:
# <Axes: xlabel='Date'>

# %%
temp_max[:14].plot(figsize=(12,5), xticks=(range(14)), rot=(45))
# Out:
# <Axes: xlabel='Date'>

# %%
temp_max[:7].plot(figsize=(12,5), table=True)
# Out:
# <Axes: xlabel='Date'>

# %%
nasa_by_day.plot(figsize=(12,5), title="NASA Facebook activity", subplots=True)
# Out:
# array([<Axes: xlabel='day'>, <Axes: xlabel='day'>, <Axes: xlabel='day'>,
#        <Axes: xlabel='day'>], dtype=object)

# %%
nasa_by_day.plot(figsize=(12,5), title="NASA Facebook activity", logy=True)
# Out:
# <Axes: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
nasa_by_day[:32].plot(figsize=(12,5), title="NASA Facebook activity", logy=True, xticks=(range(31)), rot=45)
# Out:
# <Axes: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
bar.head()
# Out:
#             TempMax  TempMin  Rain  AvgTempMax  AvgTempMin
# Date
# 2018-01-01       17       11     0          13           7
# 2018-01-02       19        8     0          13           7
# 2018-01-03       23       11     0          13           7
# 2018-01-04       24       15     0          13           7
# 2018-01-05       20       10     0          13           7

# %%
bar.plot(color=['b','g','r','m','k'])
# Out:
# <Axes: xlabel='Date'>

# %%
bar.plot(colormap='magma')
# Out:
# <Axes: xlabel='Date'>

# %%
bar.plot(colormap='gnuplot')
# Out:
# <Axes: xlabel='Date'>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-deep')

# %%
bar.plot(colormap='gnuplot')
# Out:
# <Axes: xlabel='Date'>

# %%
def GradeDay(row):
    if row['TempMax'] >= row['AvgTempMax']:
        return 'PLUS'
    else:
        return 'MINUS'

# %%
rom['GradeDay'] = rom.apply(GradeDay, axis=1)

# %%
# Out:
#             TempMax  TempMin Rain  AvgTempMax  AvgTempMin GradeDay
# Date
# 2018-01-01       14        8   0           12           4     PLUS
# 2018-01-02       13        7   0           12           4     PLUS
# 2018-01-03       14        1   0           12           4     PLUS
# 2018-01-04       16        6   0           12           4     PLUS
# 2018-01-05       17        7   0           12           3     PLUS

# %%
bar['GradeDay'] = bar.apply(GradeDay, axis=1)

# %%
ams['GradeDay'] = ams.apply(GradeDay, axis=1)

# %%
rom.head()
# Out:
#             TempMax  TempMin Rain  AvgTempMax  AvgTempMin GradeDay
# Date
# 2018-01-01       14        8   0           12           4     PLUS
# 2018-01-02       13        7   0           12           4     PLUS
# 2018-01-03       14        1   0           12           4     PLUS
# 2018-01-04       16        6   0           12           4     PLUS
# 2018-01-05       17        7   0           12           3     PLUS

# %%
rom['GradeDay'].value_counts()
# Out:
# GradeDay
# PLUS     70
# MINUS    20
# Name: count, dtype: int64

# %%
cities3 = pd.DataFrame(index=['MINUS', 'PLUS'])

# %%
cities3['Barcelona'] = bar['GradeDay'].value_counts()

# %%
cities3.head()
# Out:
#        Barcelona
# MINUS         26
# PLUS          64

# %%
cities3['Rome'] = rom['GradeDay'].value_counts()

# %%
cities3['Amsterdam'] = ams['GradeDay'].value_counts()

# %%
cities3.head()
# Out:
#        Barcelona  Rome  Amsterdam
# MINUS         26    20         22
# PLUS          64    70         68

# %%
cities3['Barcelona'].plot(kind='pie', figsize=(5,5))
# Out:
# <Axes: ylabel='Barcelona'>

# %%
cities3.plot(kind='pie', subplots=True,figsize=(10,10), colors=['b','g'], labels=['colder','warmer'], autopct='%.0f%%', fontsize = 16,
            textprops=dict(color='w'), layout=(2,2), explode=(0.2,0))
# Out:
# array([[<Axes: ylabel='Barcelona'>, <Axes: ylabel='Rome'>],
#        [<Axes: ylabel='Amsterdam'>, <Axes: >]], dtype=object)

# %%
import datetime
 #Import data
nasa = pd.read_csv("F:/PandasUdemy/course-files/nasa_facebook_statuses.csv", 
                    usecols=["status_published","num_reactions", "num_comments","num_shares","num_likes"])
 #Convert column type to date time
nasa["status_published"] = pd.to_datetime(nasa["status_published"])
 #Select observations between two datetimes - May 2015
filter =(nasa['status_published'] >= '2016-3-1') & (nasa['status_published'] < '2016-6-1')
nasa = nasa[filter]
 #Add column with day only
nasa['month'] = nasa.apply(lambda row: row["status_published"].month,axis=1)
 #Group all columns by sum
nasa_by_month = nasa.groupby('month').agg(
    {'num_reactions':'sum', 
     'num_comments':'sum',
     'num_shares':'sum',
     'num_likes':'sum'
    }
)
nasa_by_month.head()
# Out:
#        num_reactions  num_comments  num_shares  num_likes
# month
# 3            3003815         49108      392585    2846361
# 4            2927616        120118      370803    2760385
# 5            2708977         46122      393576    2548960

# %%
nasa.head(10)
# Out:
#        status_published  num_reactions  num_comments  num_shares  num_likes  \
# 137 2016-05-31 20:37:02           3003           339         412       2840
# 138 2016-05-31 19:43:18          29975           259        2620      28646
# 139 2016-05-31 18:04:59          10998           158        1379      10221
# 140 2016-05-31 16:31:30          21482           142        1088      20555
# 141 2016-05-31 15:11:02            958            26          94        914
# 142 2016-05-31 14:15:42          18795           139        1000      17819
# 143 2016-05-31 12:04:01           6931           312           0       6420
# 144 2016-05-31 11:17:31           1875            44         189       1799
# 145 2016-05-31 10:45:03           5861           109         954       5489
# 146 2016-05-30 20:03:02          37226           689        5559      34378
#
#      month
# 137      5
# 138      5
# 139      5
# 140      5
# 141      5
# 142      5
# 143      5
# 144      5
# 145      5
# ...

# %%
nasa_by_month['num_likes'].plot(kind='pie', figsize=(5,5), title='NASA Facebook activity', labels =['marzec','kwiecien','maj'])
# Out:
# <Axes: title={'center': 'NASA Facebook activity'}, ylabel='num_likes'>

# %%
cities3
plt.style.use('basic')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\style\core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py:866, in _rc_params_in_file(fname, transform, fail_on_error)
#     865 rc_temp = {}
# --> 866 with _open_file_or_url(fname) as fd:
#     867     try:
#
# File D:\ProgramData\anaconda3\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File D:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py:843, in _open_file_or_url(fname)
#     842 fname = os.path.expanduser(fname)
# --> 843 with open(fname, encoding='utf-8') as f:
#     844     yield f
#
# ...

# %%
cities3['Barcelona'].plot(kind='barh')
# Out:
# <Axes: >

# %%
cities3.plot(kind='bar', stacked=True)
# Out:
# <Axes: >

# %%
temp_max
# Out:
#             Barcelona  Rome  Amsterdam
# Date
# 2018-01-01         17    14          8
# 2018-01-02         19    13          9
# 2018-01-03         23    14         11
# 2018-01-04         24    16         11
# 2018-01-05         20    17          8
# ...               ...   ...        ...
# 2018-03-27         16    16         10
# 2018-03-28         20    17          8
# 2018-03-29         17    19         11
# 2018-03-30         19    20         14
# 2018-03-31         19    17         11
#
# [90 rows x 3 columns]

# %%
temp_max.plot(kind='box')
# Out:
# <Axes: >

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange', medians='DarkBlue', caps='Gray')

# %%
temp_max.plot(kind='box', color=color)
# Out:
# <Axes: >

# %%
bar['TempMax'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
bar['TempMax'].value_counts()
# Out:
# TempMax
# 15    17
# 16    11
# 14    10
# 17     9
# 18     8
# 12     8
# 20     4
# 13     4
# 19     4
# 11     4
# 10     3
# 24     2
# 23     1
# 22     1
# 9      1
# 5      1
# 7      1
# 21     1
# Name: count, dtype: int64

# %%
bar['TempMax'].nunique()
# Out:
# 18

# %%
bar['TempMax'].plot(kind='hist', bins=18)
# Out:
# <Axes: ylabel='Frequency'>

# %%
autos = pd.read_csv("F:/PandasUdemy/course-files/autos.csv", encoding='latin-1')

# %%
autos.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# ...

# %%
import re

# %%
regex_tc = re.compile('.*toyota.*corolla.*', re.IGNORECASE)

# %%
filter_tc = autos['name'].apply(lambda x:bool(regex_tc.search(x)))

# %%
tc.head()
# Out:
#               dateCrawled                                          name  \
# 861   2016-03-07 13:46:32                  Toyota_Corolla_1.6_Combi_Sol
# 912   2016-03-27 23:53:18  Toyota_Corolla_Verso_2.2_D_CAT_DPF_Executive
# 1898  2016-03-22 20:52:00                                Toyota_Corolla
# 2264  2016-03-12 23:47:09            Toyota_Corolla_1.6_VVT_i_Combi_Sol
# 2386  2016-03-10 14:48:16            Toyota_Corolla_Verso_2.2_D_CAT_Sol
#
#       seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 861   privat   Angebot   1800  control       kombi                2003
# 912   privat   Angebot   5300     test         bus                2008
# 1898  privat   Angebot   3200  control  kleinwagen                2004
# 2264  privat   Angebot   2990  control       kombi                2004
# 2386  privat   Angebot   5900     test         bus                2006
#
#       gearbox  powerPS    model  kilometer  monthOfRegistration fuelType  \
# ...

# %%
filter1
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 371523    False
# 371524    False
# 371525    False
# 371526    False
# 371527    False
# Name: name, Length: 371528, dtype: bool

# %%
filter2 = autos['price'] < 12000

# %%
filter3 = autos['yearOfRegistration'] >= 1990

# %%
tc = autos[filter_tc & filter2 & filter3]

# %%
tc.head()
# Out:
#               dateCrawled                                          name  \
# 861   2016-03-07 13:46:32                  Toyota_Corolla_1.6_Combi_Sol
# 912   2016-03-27 23:53:18  Toyota_Corolla_Verso_2.2_D_CAT_DPF_Executive
# 1898  2016-03-22 20:52:00                                Toyota_Corolla
# 2264  2016-03-12 23:47:09            Toyota_Corolla_1.6_VVT_i_Combi_Sol
# 2386  2016-03-10 14:48:16            Toyota_Corolla_Verso_2.2_D_CAT_Sol
#
#       seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 861   privat   Angebot   1800  control       kombi                2003
# 912   privat   Angebot   5300     test         bus                2008
# 1898  privat   Angebot   3200  control  kleinwagen                2004
# 2264  privat   Angebot   2990  control       kombi                2004
# 2386  privat   Angebot   5900     test         bus                2006
#
#       gearbox  powerPS    model  kilometer  monthOfRegistration fuelType  \
# ...

# %%
regex_a = re.compile('.*Audi.a4.*', re.IGNORECASE)

# %%
filter_a = autos['name'].apply(lambda x: bool(regex_a.search(x)))

# %%
filter2 = autos['price'] < 12000

# %%
filter3 = autos['yearOfRegistration'] >= 1990
a4 = autos[filter_a & filter2 & filter3]

# %%
a4.head()
# Out:
#              dateCrawled                             name  seller offerType  \
# 103  2016-03-15 17:41:31             Audi_A4_B5_1_6_Liter  privat   Angebot
# 105  2016-04-01 09:54:39  Audi_a4_2.5_TDI_Tausch_moeglich  privat   Angebot
# 147  2016-03-14 12:46:46       Audi_A4_b5_Avant_TÜV_10/17  privat   Angebot
# 316  2016-03-19 10:54:59            Audi_A4_Cabriolet_3.0  privat   Angebot
# 408  2016-03-20 23:45:11                      Audi_A4_1.8  privat   Angebot
#
#      price   abtest vehicleType  yearOfRegistration  gearbox  powerPS model  \
# 103    499  control   limousine                1995  manuell      101    a4
# 105   6500     test   limousine                2004  manuell      163    a4
# 147   1500     test       kombi                1996  manuell      126    a4
# 316   5299     test      cabrio                2002  manuell      220    a4
# 408   2700  control   limousine                1999  manuell      125    a4
#
# ...

# %%
tc.plot(kind='scatter', x='yearOfRegistration', y='price')
# Out:
# <Axes: xlabel='yearOfRegistration', ylabel='price'>

# %%
ax = a4.plot(kind='scatter', x='yearOfRegistration', y='price', color = 'Blue', label='Audi')

# %%
tc.plot(kind='scatter', x='yearOfRegistration', y='price', color='Green', label='Toyota', ax=ax)
# Out:
# <Axes: xlabel='yearOfRegistration', ylabel='price'>

# %%
ax = a4.plot(kind='scatter', x='yearOfRegistration', y='price', color = 'Blue', label='Audi')
tc.plot(kind='scatter', x='yearOfRegistration', y='price', color='Green', label='Toyota', ax=ax)
# Out:
# <Axes: xlabel='yearOfRegistration', ylabel='price'>

# %%
tc.plot.hexbin(x='yearOfRegistration', y='price', gridsize=20, title='Toyota')
# Out:
# <Axes: title={'center': 'Toyota'}, xlabel='yearOfRegistration', ylabel='price'>

# %%
a4.plot.hexbin(x='yearOfRegistration', y='price', gridsize=20, title='Audi')
# Out:
# <Axes: title={'center': 'Audi'}, xlabel='yearOfRegistration', ylabel='price'>

# %%
tc_counts = tc['yearOfRegistration'].value_counts().sort_index()

# %%
tc_counts.head()
# Out:
# yearOfRegistration
# 1990     6
# 1991     4
# 1992     5
# 1993    12
# 1994     3
# Name: count, dtype: int64

# %%
audi_counts = a4['yearOfRegistration'].value_counts().sort_index()

# %%
audi_counts.head()
# Out:
# yearOfRegistration
# 1992      1
# 1993      1
# 1994     39
# 1995    454
# 1996    602
# Name: count, dtype: int64

# %%
car_counts = pd.DataFrame(index = tc_counts.index.append(audi_counts.index).unique())

# %%
car_counts['Toyota'] = tc_counts

# %%
car_counts['Audi'] = audi_counts

# %%
car_counts.head()
# Out:
#                     Toyota  Audi
# yearOfRegistration
# 1990                   6.0   NaN
# 1991                   4.0   NaN
# 1992                   5.0   1.0
# 1993                  12.0   1.0
# 1994                   3.0  39.0

# %%
car_counts.fillna(0, inplace=True)

# %%
car_counts.sort_index(inplace=True)

# %%
car_counts.plot()
# Out:
# <Axes: xlabel='yearOfRegistration'>

# %%
car_counts.plot(kind='area')
# Out:
# <Axes: xlabel='yearOfRegistration'>

# %%
marathon = pd.read_csv("F:/PandasUdemy/course-files/marathon_results_2017.csv", usecols=['Age','M/F','Country','40K'])

# %%
marathon['40K'].value_counts()
# Out:
# 40K
# 3:32:23    14
# 3:13:59    13
# 3:31:55    13
# 3:41:14    13
# 3:42:26    13
#            ..
# 4:19:20     1
# 4:20:44     1
# 4:09:20     1
# 4:16:42     1
# 7:41:23     1
# Name: count, Length: 8944, dtype: int64

# %%
marathon['TimeSeconds'] = marathon['40K'].apply(lambda x:pd.Timedelta(x).total_seconds())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 marathon['TimeSeconds'] = marathon['40K'].apply(lambda x:pd.Timedelta(x).total_seconds())
#
# File D:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
#    4757         by_row=by_row,
#    4758         args=args,
#    4759         kwargs=kwargs,
# -> 4760     ).apply()
#
# ...

# %%
marathon['40K'] = marathon['40K'].str.replace('[^0-9:]', '', regex=True)

# %%
marathon['TimeSeconds'] = marathon['40K'].apply(lambda x:pd.Timedelta(x).total_seconds())

# %%
marathon['TimeSeconds'].value_counts()
# Out:
# TimeSeconds
# 12743.0    14
# 12715.0    13
# 11639.0    13
# 13274.0    13
# 12107.0    13
#            ..
# 15560.0     1
# 15644.0     1
# 14960.0     1
# 15402.0     1
# 27683.0     1
# Name: count, Length: 8943, dtype: int64

# %%
marathon['TimeSeconds'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 26405    False
# 26406    False
# 26407    False
# 26408    False
# 26409    False
# Name: TimeSeconds, Length: 26410, dtype: bool

# %%
marathon.loc[marathon['TimeSeconds'].isna()==True]
# Out:
#        Age M/F Country 40K  TimeSeconds
# 14688   30   M     USA              NaN
# 16590   29   M     USA              NaN
# 16658   55   M     USA              NaN
# 17026   46   F     USA              NaN
# 25517   35   M     USA              NaN
# 25940   33   M     USA              NaN

# %%
marathon.head()
# Out:
#    Age M/F Country      40K  TimeSeconds
# 0   24   M     KEN  2:02:53       7373.0
# 1   30   M     USA  2:03:14       7394.0
# 2   25   M     JPN  2:03:38       7418.0
# 3   32   M     USA  2:04:35       7475.0
# 4   31   M     KEN  2:05:00       7500.0

# %%
marathon.plot(y='TimeSeconds', x='Age', kind='scatter')
# Out:
# <Axes: xlabel='Age', ylabel='TimeSeconds'>

# %%
filter_m = marathon['M/F'] == 'M'

# %%
filter_m
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 26405    False
# 26406     True
# 26407    False
# 26408     True
# 26409     True
# Name: M/F, Length: 26410, dtype: bool

# %%
marathon_m = marathon[filter_m]

# %%
filter_f = marathon['M/F'] == 'F'

# %%
marathon_f = marathon[filter_f]

# %%
marathon_f.head()
# Out:
#     Age M/F Country      40K  TimeSeconds
# 20   37   F     KEN  2:14:43       8083.0
# 23   27   F     BRN  2:15:42       8142.0
# 24   25   F     USA  2:15:54       8154.0
# 33   33   F     USA  2:17:25       8245.0
# 43   33   F     KEN  2:19:07       8347.0

# %%
marathon_m.head()
# Out:
#    Age M/F Country      40K  TimeSeconds
# 0   24   M     KEN  2:02:53       7373.0
# 1   30   M     USA  2:03:14       7394.0
# 2   25   M     JPN  2:03:38       7418.0
# 3   32   M     USA  2:04:35       7475.0
# 4   31   M     KEN  2:05:00       7500.0

# %%
ax= marathon_m.plot(x='Age', y='TimeSeconds', label='M', kind='scatter', color = 'blue')
marathon_f.plot(x='Age', y='TimeSeconds', label='F', kind='scatter', color='pink', ax=ax)
# Out:
# <Axes: xlabel='Age', ylabel='TimeSeconds'>

# %%
filter_70 = marathon['Age'] > 70

# %%
m70 = marathon.loc[filter_70]

# %%
m70['M/F'].value_counts()
# Out:
# M/F
# M    107
# F     20
# Name: count, dtype: int64

# %%
marathon_f.plot(kind='hexbin', x='TimeSeconds', y='Age', gridsize=20)
# Out:
# <Axes: xlabel='TimeSeconds', ylabel='Age'>

# %%
marathon_m.plot(kind='hexbin', x='TimeSeconds', y='Age', gridsize=20)
# Out:
# <Axes: xlabel='TimeSeconds', ylabel='Age'>

# %%
import datetime

# %%
# Import data
nasa = pd.read_csv("F:/PandasUdemy/course-files/nasa_facebook_statuses.csv", usecols=["status_published", "num_likes"])

# Convert column type to datetime
nasa["status_published"] = pd.to_datetime(nasa["status_published"])

# Select observations between two datetimes - May 2016
filter = (nasa['status_published'] >= '2016-05-01') & (nasa['status_published'] < '2016-06-01')
nasa = nasa[filter]

# Add column with day only
nasa['day'] = nasa['status_published'].dt.day

# Group by day and sum only 'num_likes'
nasa_by_day = nasa.groupby(by='day')['num_likes'].sum()

# %%
nasa_by_day.head()
# Out:
# day
# 1     60243
# 2    177989
# 3     50264
# 4    133302
# 5     89657
# Name: num_likes, dtype: int64

# %%
#Import data
bean = pd.read_csv("F:/PandasUdemy/course-files/mrbean_facebook_statuses.csv",usecols=["status_published","num_likes"])
 #Convert column type to date time
bean["status_published"] = pd.to_datetime(bean["status_published"])

# %%
bean.head()
# Out:
#      status_published  num_likes
# 0 2016-06-23 11:35:48      16079
# 1 2016-06-21 10:00:01     114008
# 2 2016-06-19 10:00:01     218579
# 3 2016-06-18 11:00:02      20338
# 4 2016-06-17 09:00:01     215591

# %%
days = nasa["day"].append(bean["day"])
days = days.unique()
fb = pd.DataFrame(index=days).sort_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5000\2520848075.py in ?()
# ----> 1 days = nasa["day"].append(bean["day"])
#       2 days = days.unique()
#       3 fb = pd.DataFrame(index=days).sort_index()
#
# D:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'append'
