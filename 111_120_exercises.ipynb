# %% [markdown]
# <a href="https://colab.research.google.com/github/Krisss993/pandas/blob/main/111_120_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas
#
# ### Spis treści:
# * [Import biblioteki](#0)
# * [Ćwiczenie 111](#1)
# * [Ćwiczenie 112](#2)
# * [Ćwiczenie 113](#3)
# * [Ćwiczenie 114](#4)
# * [Ćwiczenie 115](#5)
# * [Ćwiczenie 116](#6)
# * [Ćwiczenie 117](#7)
# * [Ćwiczenie 118](#8)
# * [Ćwiczenie 119](#9)
# * [Ćwiczenie 120](#10)

# %% [markdown]
# ### <a name='0'></a>Import biblioteki

# %%
import numpy as np
import pandas as pd

np.random.seed(42)
pd.__version__
# Out:
# '2.0.3'

# %% [markdown]
# ### <a name='1'></a> Ćwiczenie 111
# Zbuduj obiekt _DatetimeIndex_ zawierający daty w formacie 'yyyy-mm-dd' dla wszystkich dni ze stycznia 2020 roku i przypisz do zmiennej _date_range_.
#
# __Oczekiwany wynik:__
#
#
# ```
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31'],
#               dtype='datetime64[ns]', freq='D')
# ```

# %%
date_index = pd.date_range(start = '2020-01-01', periods=31, freq='D')
date_index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
date_index = pd.date_range(start = '2020-01-01', end='2020-02', freq='D')
date_index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31', '2020-02-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
date_index = np.arange('2020-01-01','2020-02', dtype='datetime64[D]')
date_index
# Out:
# array(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#        '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#        '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#        '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#        '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#        '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#        '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#        '2020-01-29', '2020-01-30', '2020-01-31'], dtype='datetime64[D]')

# %% [markdown]
# Ze zmiennej _date_range_ zbuduj obiekt typu _Series_.

# %%
s = pd.Series(date_index)
s
# Out:
# 0    2020-01-01
# 1    2020-01-02
# 2    2020-01-03
# 3    2020-01-04
# 4    2020-01-05
# 5    2020-01-06
# 6    2020-01-07
# 7    2020-01-08
# 8    2020-01-09
# 9    2020-01-10
# 10   2020-01-11
# 11   2020-01-12
# 12   2020-01-13
# 13   2020-01-14
# 14   2020-01-15
# 15   2020-01-16
# 16   2020-01-17
# 17   2020-01-18
# 18   2020-01-19
# 19   2020-01-20
# 20   2020-01-21
# 21   2020-01-22
# 22   2020-01-23
# 23   2020-01-24
# 24   2020-01-25
# 25   2020-01-26
# 26   2020-01-27
# 27   2020-01-28
# 28   2020-01-29
# 29   2020-01-30
# 30   2020-01-31
# dtype: datetime64[ns]

# %% [markdown]
# ### <a name='2'></a> Ćwiczenie 112
# Zbuduj obiekt _DatetimeIndex_ zawierający daty w formacie 'yyyy-mm-dd' dla wszystkich poniedziałków z 2020 roku i przypisz do zmiennej _date_range_.

# %%
date_index = pd.date_range(start='2020-01-06',end='01-2021', freq='W-MON')
date_index
# Out:
# DatetimeIndex(['2020-01-06', '2020-01-13', '2020-01-20', '2020-01-27',
#                '2020-02-03', '2020-02-10', '2020-02-17', '2020-02-24',
#                '2020-03-02', '2020-03-09', '2020-03-16', '2020-03-23',
#                '2020-03-30', '2020-04-06', '2020-04-13', '2020-04-20',
#                '2020-04-27', '2020-05-04', '2020-05-11', '2020-05-18',
#                '2020-05-25', '2020-06-01', '2020-06-08', '2020-06-15',
#                '2020-06-22', '2020-06-29', '2020-07-06', '2020-07-13',
#                '2020-07-20', '2020-07-27', '2020-08-03', '2020-08-10',
#                '2020-08-17', '2020-08-24', '2020-08-31', '2020-09-07',
#                '2020-09-14', '2020-09-21', '2020-09-28', '2020-10-05',
#                '2020-10-12', '2020-10-19', '2020-10-26', '2020-11-02',
#                '2020-11-09', '2020-11-16', '2020-11-23', '2020-11-30',
#                '2020-12-07', '2020-12-14', '2020-12-21', '2020-12-28'],
#               dtype='datetime64[ns]', freq='W-MON')

# %% [markdown]
# ### <a name='3'></a> Ćwiczenie 113
# Zbuduj obiekt _DatetimeIndex_ zawierający daty w formacie 'yyyy-mm-dd hh:mm:ss' dla 1 stycznia 2021 roku z odstępem czasowym 1h i przypisz do zmiennej _date_range_.
#
# __Oczekiwany wynik:__
#
#
# ```
# DatetimeIndex(['2021-01-01 00:00:00', '2021-01-01 01:00:00',
#                '2021-01-01 02:00:00', '2021-01-01 03:00:00',
#                '2021-01-01 04:00:00', '2021-01-01 05:00:00',
#                '2021-01-01 06:00:00', '2021-01-01 07:00:00',
#                '2021-01-01 08:00:00', '2021-01-01 09:00:00',
#                '2021-01-01 10:00:00', '2021-01-01 11:00:00',
#                '2021-01-01 12:00:00', '2021-01-01 13:00:00',
#                '2021-01-01 14:00:00', '2021-01-01 15:00:00',
#                '2021-01-01 16:00:00', '2021-01-01 17:00:00',
#                '2021-01-01 18:00:00', '2021-01-01 19:00:00',
#                '2021-01-01 20:00:00', '2021-01-01 21:00:00',
#                '2021-01-01 22:00:00', '2021-01-01 23:00:00'],
#               dtype='datetime64[ns]', freq='H')
# ```

# %%
date_index = pd.date_range('2021-01-01 00:00:00', periods=24, freq='H')
date_index
# Out:
# DatetimeIndex(['2021-01-01 00:00:00', '2021-01-01 01:00:00',
#                '2021-01-01 02:00:00', '2021-01-01 03:00:00',
#                '2021-01-01 04:00:00', '2021-01-01 05:00:00',
#                '2021-01-01 06:00:00', '2021-01-01 07:00:00',
#                '2021-01-01 08:00:00', '2021-01-01 09:00:00',
#                '2021-01-01 10:00:00', '2021-01-01 11:00:00',
#                '2021-01-01 12:00:00', '2021-01-01 13:00:00',
#                '2021-01-01 14:00:00', '2021-01-01 15:00:00',
#                '2021-01-01 16:00:00', '2021-01-01 17:00:00',
#                '2021-01-01 18:00:00', '2021-01-01 19:00:00',
#                '2021-01-01 20:00:00', '2021-01-01 21:00:00',
#                '2021-01-01 22:00:00', '2021-01-01 23:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %% [markdown]
# ### <a name='4'></a> Ćwiczenie 114
# Zbuduj poniższy obiekt _DataFrame_.
#
# __Wskazówki:__ Kolumna _day_ zawiera daty od 01 marca 2021 do 31 marca 2021. Kolumna _day_of_year_ to numer dnia w całym roku.
#
#
# ```
#       day	       day_of_year
#  0	2021-03-01	60
#  1	2021-03-02	61
#  2	2021-03-03	62
#  3	2021-03-04	63
#  4	2021-03-05	64
#  5	2021-03-06	65
#  6	2021-03-07	66
#  7	2021-03-08	67
#  8	2021-03-09	68
#  9	2021-03-10	69
# 10	2021-03-11	70
# 11	2021-03-12	71
# 12	2021-03-13	72
# 13	2021-03-14	73
# 14	2021-03-15	74
# 15	2021-03-16	75
# 16	2021-03-17	76
# 17	2021-03-18	77
# 18	2021-03-19	78
# 19	2021-03-20	79
# 20	2021-03-21	80
# 21	2021-03-22	81
# 22	2021-03-23	82
# 23	2021-03-24	83
# 24	2021-03-25	84
# 25	2021-03-26	85
# 26	2021-03-27	86
# 27	2021-03-28	87
# 28	2021-03-29	88
# 29	2021-03-30	89
# 30	2021-03-31	90
# ```

# %%
date_index = pd.date_range('2021-03-01', freq='D', periods=31)
df = pd.DataFrame(date_index, columns=['day'])
df['day_of_the_year'] = df['day'].dt.day_of_year
df
# Out:
#           day  day_of_the_year
# 0  2021-03-01               60
# 1  2021-03-02               61
# 2  2021-03-03               62
# 3  2021-03-04               63
# 4  2021-03-05               64
# 5  2021-03-06               65
# 6  2021-03-07               66
# 7  2021-03-08               67
# 8  2021-03-09               68
# 9  2021-03-10               69
# 10 2021-03-11               70
# 11 2021-03-12               71
# 12 2021-03-13               72
# 13 2021-03-14               73
# 14 2021-03-15               74
# 15 2021-03-16               75
# 16 2021-03-17               76
# 17 2021-03-18               77
# 18 2021-03-19               78
# 19 2021-03-20               79
# 20 2021-03-21               80
# 21 2021-03-22               81
# 22 2021-03-23               82
# 23 2021-03-24               83
# 24 2021-03-25               84
# 25 2021-03-26               85
# 26 2021-03-27               86
# 27 2021-03-28               87
# 28 2021-03-29               88
# 29 2021-03-30               89
# 30 2021-03-31               90

# %% [markdown]
# ### <a name='5'></a> Ćwiczenie 115
#
# Podany jest poniższy słownik _data_dict_.
#
# ```
# data_dict = {
#     'normal': np.random.normal(loc=0, scale=1, size=1000),
#     'uniform': np.random.uniform(low=0, high=1, size=1000),
#     'binomial': np.random.binomial(n=1, p=0.2, size=1000)
# }
# ```
#
# Zbuduj z tego słownika obiekt _DateFrame_. Dodatkowo jako indeks dodaj datę od 2020-01-01 i przypisz do zmiennej _df_.

# %%
data_dict = {
    'normal': np.random.normal(loc=0, scale=1, size=1000),
    'uniform': np.random.uniform(low=0, high=1, size=1000),
    'binomial': np.random.binomial(n=1, p=0.2, size=1000)
}
df = pd.DataFrame(data=data_dict, index=pd.date_range('2020-01-01',freq='D', periods=1000))
df
# Out:
#               normal   uniform  binomial
# 2020-01-01  0.496714  0.167483         0
# 2020-01-02 -0.138264  0.104568         0
# 2020-01-03  0.647689  0.636430         0
# 2020-01-04  1.523030  0.706476         0
# 2020-01-05 -0.234153  0.031586         1
# ...              ...       ...       ...
# 2022-09-22 -0.281100  0.280683         1
# 2022-09-23  1.797687  0.206993         0
# 2022-09-24  0.640843  0.516573         0
# 2022-09-25 -0.571179  0.005506         1
# 2022-09-26  0.572583  0.007664         0
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### <a name='6'></a> Ćwiczenie 116
# Wyświetl 10 pierwszych wierszy obiektu _df_ z poprzedniego ćwiczenia.

# %%
# tutaj wpisz rozwiązanie

# %% [markdown]
# Wyświetl 8 ostatnich wierszy obiektu df z poprzedniego ćwiczenia.

# %%
# tutaj wpisz rozwiązanie

# %% [markdown]
# ### <a name='7'></a> Ćwiczenie 117
# Wyświetl podstawowe informacje o obiekcie _df_ (liczba wierszy, liczba kolumn, typ zmiennych).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1000 entries, 2020-01-01 to 2022-09-26
# Freq: D
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   normal    1000 non-null   float64
#  1   uniform   1000 non-null   float64
#  2   binomial  1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 31.2 KB

# %% [markdown]
# Wyświetl podstawowe statystyki obiektu _df_ (wartość średnia, odchylenie, min, max, mediana).

# %%
df.describe()
# Out:
#             normal      uniform    binomial
# count  1000.000000  1000.000000  1000.00000
# mean      0.019332     0.503649     0.19200
# std       0.979216     0.288357     0.39407
# min      -3.241267     0.003218     0.00000
# 25%      -0.647590     0.247199     0.00000
# 50%       0.025301     0.516126     0.00000
# 75%       0.647944     0.746319     0.00000
# max       3.852731     0.999414     1.00000

# %% [markdown]
# ### <a name='8'></a> Ćwiczenie 118
# Zaimportuj bibliotekę _seaborn_ do wizualizacji danych.

# %%
import seaborn as sns

sns.set()

# %% [markdown]
# Używając meteody _pd.DataFrame.plot_ zbuduj histogramy dla kolejnych trzech zmiennych.
# * normal (20 słupków)

# %%
df.hist('normal',bins=20)
# Out:
# array([[<Axes: title={'center': 'normal'}>]], dtype=object)

# %% [markdown]
# * uniform (30 słupków)

# %%
df.hist('uniform',bins=30)
# Out:
# array([[<Axes: title={'center': 'uniform'}>]], dtype=object)

# %% [markdown]
# * binomial

# %%
df.hist('binomial',bins=20)
# Out:
# array([[<Axes: title={'center': 'binomial'}>]], dtype=object)

# %% [markdown]
# ### <a name='9'></a> Ćwiczenie 119
# Zapisz obiekt _df_ do pliku _'dataframe.csv'_.

# %%
df.to_csv('df.csv')

# %% [markdown]
# __Sprawdzenie:__
# Wyświetlenie 5 pierwszych linijek pliku _dataframe.csv_

# %%
# !head -5 df.csv
# Out:
# ,normal,uniform,binomial
# 2020-01-01,0.4967141530112327,0.16748258225906976,0
# 2020-01-02,-0.13826430117118466,0.10456784033440025,0
# 2020-01-03,0.6476885381006925,0.6364302495436367,0
# 2020-01-04,1.5230298564080254,0.7064757264869012,0

# %% [markdown]
# ### <a name='10'></a> Ćwiczenie 110
# Wczytaj do zmiennej _df_new_ plik _dataframe.csv_ (pamiętaj o poprawnym wczytaniu indeksu).

# %%
df_new = pd.read_csv('df.csv')

# %%
df_new
# Out:
#      Unnamed: 0    normal   uniform  binomial
# 0    2020-01-01  0.496714  0.167483         0
# 1    2020-01-02 -0.138264  0.104568         0
# 2    2020-01-03  0.647689  0.636430         0
# 3    2020-01-04  1.523030  0.706476         0
# 4    2020-01-05 -0.234153  0.031586         1
# ..          ...       ...       ...       ...
# 995  2022-09-22 -0.281100  0.280683         1
# 996  2022-09-23  1.797687  0.206993         0
# 997  2022-09-24  0.640843  0.516573         0
# 998  2022-09-25 -0.571179  0.005506         1
# 999  2022-09-26  0.572583  0.007664         0
#
# [1000 rows x 4 columns]
