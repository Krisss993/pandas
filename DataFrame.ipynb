# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
mc=pd.read_csv('F:/PandasUdemy/course-files/mcdonalds.csv')

# %%
mc
# Out:
#                                                       Serving Size  Calories  \
# Item
# Egg McMuffin                                        4.8 oz (136 g)       300
# Egg White Delight                                   4.8 oz (135 g)       250
# Sausage McMuffin                                    3.9 oz (111 g)       370
# Sausage McMuffin with Egg                           5.7 oz (161 g)       450
# Sausage McMuffin with Egg Whites                    5.7 oz (161 g)       400
# ...                                                            ...       ...
# McFlurry with Oreo Cookies (Small)                 10.1 oz (285 g)       510
# McFlurry with Oreo Cookies (Medium)                13.4 oz (381 g)       690
# McFlurry with Oreo Cookies (Snack)                  6.7 oz (190 g)       340
# McFlurry with Reese's Peanut Butter Cups (Medium)  14.2 oz (403 g)       810
# McFlurry with Reese's Peanut Butter Cups (Snack)    7.1 oz (202 g)       410
#
# ...

# %%
mc.head()
# Out:
#                                Item    Serving Size  Calories  \
# 0                      Egg McMuffin  4.8 oz (136 g)       300
# 1                 Egg White Delight  4.8 oz (135 g)       250
# 2                  Sausage McMuffin  3.9 oz (111 g)       370
# 3         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat
# 0                120
# 1                 70
# 2                200
# 3                250
# 4                210

# %%
df.dtypes.value_counts()
# Out:
# int64      18
# object      3
# float64     3
# Name: count, dtype: int64

# %%
series=pd.read_csv('F:/PandasUdemy/course-files/mcdonalds.csv',usecols=['Item','Calories'],index_col='Item').squeeze()

# %%
series.head()
# Out:
# Item
# Egg McMuffin                        300
# Egg White Delight                   250
# Sausage McMuffin                    370
# Sausage McMuffin with Egg           450
# Sausage McMuffin with Egg Whites    400
# Name: Calories, dtype: int64

# %%
series.count()
# Out:
# 260

# %%
df.count()
# Out:
# Category                         260
# Item                             260
# Serving Size                     260
# Calories                         260
# Calories from Fat                260
# TotalFat                         260
# Total Fat (% Daily Value)        260
# Saturated Fat                    260
# Saturated Fat (% Daily Value)    260
# Trans Fat                        260
# Cholesterol                      260
# Cholesterol (% Daily Value)      260
# Sodium                           260
# Sodium (% Daily Value)           260
# Carbohydrates                    260
# Carbohydrates (% Daily Value)    260
# Dietary Fiber                    260
# Dietary Fiber (% Daily Value)    260
# Sugars                           260
# Protein                          260
# Vitamin A (% Daily Value)        260
# Vitamin C (% Daily Value)        260
# Calcium (% Daily Value)          260
# Iron (% Daily Value)             260
# dtype: int64

# %%
len(df)
# Out:
# 260

# %%
series.dtypes
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# Category                          object
# Item                              object
# Serving Size                      object
# Calories                           int64
# Calories from Fat                  int64
# TotalFat                         float64
# Total Fat (% Daily Value)          int64
# Saturated Fat                    float64
# Saturated Fat (% Daily Value)      int64
# Trans Fat                        float64
# Cholesterol                        int64
# Cholesterol (% Daily Value)        int64
# Sodium                             int64
# Sodium (% Daily Value)             int64
# Carbohydrates                      int64
# Carbohydrates (% Daily Value)      int64
# Dietary Fiber                      int64
# Dietary Fiber (% Daily Value)      int64
# Sugars                             int64
# Protein                            int64
# Vitamin A (% Daily Value)          int64
# Vitamin C (% Daily Value)          int64
# Calcium (% Daily Value)            int64
# ...

# %%
df.dtypes.value_counts()
# Out:
# int64      18
# object      3
# float64     3
# Name: count, dtype: int64

# %%
series.axes
# Out:
# [Index(['Egg McMuffin', 'Egg White Delight', 'Sausage McMuffin',
#         'Sausage McMuffin with Egg', 'Sausage McMuffin with Egg Whites',
#         'Steak & Egg McMuffin', 'Bacon, Egg & Cheese Biscuit (Regular Biscuit)',
#         'Bacon, Egg & Cheese Biscuit (Large Biscuit)',
#         'Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)',
#         'Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)',
#         ...
#         'Shamrock Shake (Medium)', 'Shamrock Shake (Large)',
#         'McFlurry with M&M’s Candies (Small)',
#         'McFlurry with M&M’s Candies (Medium)',
#         'McFlurry with M&M’s Candies (Snack)',
#         'McFlurry with Oreo Cookies (Small)',
#         'McFlurry with Oreo Cookies (Medium)',
#         'McFlurry with Oreo Cookies (Snack)',
#         'McFlurry with Reese's Peanut Butter Cups (Medium)',
#         'McFlurry with Reese's Peanut Butter Cups (Snack)'],
#        dtype='object', name='Item', length=260)]

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=260, step=1),
#  Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#         'TotalFat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#         'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#         'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#         'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#         'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#         'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#         'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#        dtype='object')]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=260, step=1)

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'TotalFat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
df.values
# Out:
# array([['Breakfast', 'Egg McMuffin', '4.8 oz (136 g)', ..., 0, 25, 15],
#        ['Breakfast', 'Egg White Delight', '4.8 oz (135 g)', ..., 0, 25,
#         8],
#        ['Breakfast', 'Sausage McMuffin', '3.9 oz (111 g)', ..., 0, 25,
#         10],
#        ...,
#        ['Smoothies & Shakes', 'McFlurry with Oreo Cookies (Snack)',
#         '6.7 oz (190 g)', ..., 0, 25, 6],
#        ['Smoothies & Shakes',
#         "McFlurry with Reese's Peanut Butter Cups (Medium)",
#         '14.2 oz (403 g)', ..., 0, 60, 6],
#        ['Smoothies & Shakes',
#         "McFlurry with Reese's Peanut Butter Cups (Snack)",
#         '7.1 oz (202 g)', ..., 0, 30, 4]], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   TotalFat                       260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
df['Calories'].value_counts()
# Out:
# Calories
# 0      16
# 340    10
# 430    10
# 280     9
# 250     8
#        ..
# 640     1
# 800     1
# 740     1
# 620     1
# 810     1
# Name: count, Length: 78, dtype: int64

# %%
df.sample(n=3,axis='columns').head()
# Out:
#    TotalFat  Dietary Fiber (% Daily Value)  Cholesterol
# 0      13.0                             17          260
# 1       8.0                             17           25
# 2      23.0                             17           45
# 3      28.0                             17          285
# 4      23.0                             17           50

# %%
fuel=pd.read_csv('F:/PandasUdemy/course-files/fuel.csv',usecols=['Vehicle ID','Year','Make','Model','Class',
                                                                      'Fuel Type','Combined MPG (FT1)'], low_memory=False,
                index_col='Vehicle ID')

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class Fuel Type  Combined MPG (FT1)
# 0             Minicompact Cars   Regular                20.0
# 1             Minicompact Cars   Regular                20.0
# 2                  Two Seaters   Regular                21.0
# 3                  Two Seaters   Regular                21.0
# 4  Special Purpose Vehicle 2WD   Regular                17.0

# %%
fuel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31684 entries, 0 to 31683
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Vehicle ID          31684 non-null  int64
#  1   Year                31684 non-null  int64
#  2   Make                31684 non-null  object
#  3   Model               31683 non-null  object
#  4   Class               31683 non-null  object
#  5   Fuel Type           31683 non-null  object
#  6   Combined MPG (FT1)  31683 non-null  float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 1.7+ MB

# %%
fuel.columns
# Out:
# Index(['Vehicle ID', 'Year', 'Make', 'Model', 'Class', 'Fuel Type',
#        'Combined MPG (FT1)'],
#       dtype='object')

# %%
fuel.dtypes.value_counts()
# Out:
# object     4
# int64      2
# float64    1
# Name: count, dtype: int64

# %%
fuel.index
# Out:
# RangeIndex(start=0, stop=31684, step=1)

# %%
fuel['Make'].head()
# Out:
# 0    Alfa Romeo
# 1    Alfa Romeo
# 2    Alfa Romeo
# 3    Alfa Romeo
# 4    AM General
# Name: Make, dtype: object

# %%
fuel['Make'].value_counts().head(10)
# Out:
# Make
# Chevrolet        3389
# Ford             2721
# Dodge            2361
# GMC              2174
# Toyota           1599
# BMW              1180
# Nissan           1082
# Mercedes-Benz     948
# Mitsubishi        937
# Pontiac           893
# Name: count, dtype: int64

# %%
fuel.shape
# Out:
# (31684, 7)

# %%
fuel.dtypes.value_counts()
# Out:
# object     4
# int64      2
# float64    1
# Name: count, dtype: int64

# %%
fuel.Make
# Out:
# 0        Alfa Romeo
# 1        Alfa Romeo
# 2        Alfa Romeo
# 3        Alfa Romeo
# 4        AM General
#             ...
# 31679    Mitsubishi
# 31680    Mitsubishi
# 31681    Mitsubishi
# 31682    Mitsubishi
# 31683     Mitsubish
# Name: Make, Length: 31684, dtype: object

# %%
fuel.Make.dtype
# Out:
# dtype('O')

# %%
type(fuel.Make)
# Out:
# pandas.core.series.Series

# %%
fuel.Make
# Out:
# 0        Alfa Romeo
# 1        Alfa Romeo
# 2        Alfa Romeo
# 3        Alfa Romeo
# 4        AM General
#             ...
# 31679    Mitsubishi
# 31680    Mitsubishi
# 31681    Mitsubishi
# 31682    Mitsubishi
# 31683     Mitsubish
# Name: Make, Length: 31684, dtype: object

# %%
df.Calories.median()
# Out:
# 340.0

# %%
df.Calories.max()
# Out:
# 1880

# %%
df.Calories.idxmax()
# Out:
# 82

# %%
df.Calories.iloc[82]
# Out:
# 1880

# %%
df.Item[df.Calories.idxmax()]
# Out:
# 'Chicken McNuggets (40 piece)'

# %%
s=df['Item']

# %%
s[242]
# Out:
# 'Vanilla Shake (Medium)'

# %%
s.iloc[242]
# Out:
# 'Vanilla Shake (Medium)'

# %%
df.iloc[242].loc['Item']
# Out:
# 'Vanilla Shake (Medium)'

# %%
df.loc[242,'Item']
# Out:
# 'Vanilla Shake (Medium)'

# %%
df[['Item','Calories']].head()
# Out:
#                                Item  Calories
# 0                      Egg McMuffin       300
# 1                 Egg White Delight       250
# 2                  Sausage McMuffin       370
# 3         Sausage McMuffin with Egg       450
# 4  Sausage McMuffin with Egg Whites       400

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                20.0
# 26561        Regular                21.0
# 27681        Regular                21.0
# 27550        Regular                17.0

# %%
fuel.Make.head()
# Out:
# Vehicle ID
# 26587    Alfa Romeo
# 27705    Alfa Romeo
# 26561    Alfa Romeo
# 27681    Alfa Romeo
# 27550    AM General
# Name: Make, dtype: object

# %%
fuel.Make.max()
# Out:
# 'smart'

# %%
fuel.Make.value_counts().head()
# Out:
# Make
# Chevrolet    3389
# Ford         2721
# Dodge        2361
# GMC          2174
# Toyota       1599
# Name: count, dtype: int64

# %%
fuel.iloc[1873]
# Out:
# Year                             1984
# Make                       Volkswagen
# Model                           Jetta
# Class                 Subcompact Cars
# Fuel Type                     Regular
# Combined MPG (FT1)               23.0
# Name: 26784, dtype: object

# %%
fuel.loc[1873,'Combined MPG (FT1)']
# Out:
# 19.0

# %%
fuel.Make.idxmax()
# Out:
# 25150

# %%
fuel.loc[fuel.Make.idxmax()]
# Out:
# Year                                2008
# Make                               smart
# Model                 fortwo convertible
# Class                        Two Seaters
# Fuel Type                        Premium
# Combined MPG (FT1)                  36.0
# Name: 25150, dtype: object

# %%
fuel.Make.loc[fuel.Make.idxmax()]
# Out:
# 'smart'

# %%
fuel.loc[fuel['Combined MPG (FT1)'].max()]
# Out:
# Year                             1985
# Make                            Dodge
# Model                        Conquest
# Class                 Subcompact Cars
# Fuel Type                     Premium
# Combined MPG (FT1)               18.0
# Name: 112, dtype: object

# %%
df.TotalFat.head()
# Out:
# 0    13.0
# 1     8.0
# 2    23.0
# 3    28.0
# 4    23.0
# Name: TotalFat, dtype: float64

# %%
df['TotalFat'].head()
# Out:
# 0    13.0
# 1     8.0
# 2    23.0
# 3    28.0
# 4    23.0
# Name: TotalFat, dtype: float64

# %%
df['TotalFat0'] = 0

# %%
df['TotalFat0']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 255    0
# 256    0
# 257    0
# 258    0
# 259    0
# Name: TotalFat0, Length: 260, dtype: int64

# %%
df['Sug&fat'] = df['Sugars']+df['TotalFat']

# %%
df['Sug&fat']
# Out:
# 0       16.0
# 1       11.0
# 2       25.0
# 3       30.0
# 4       25.0
#        ...
# 255     81.0
# 256    108.0
# 257     54.0
# 258    135.0
# 259     67.0
# Name: Sug&fat, Length: 260, dtype: float64

# %%
df.insert(loc=2, column='SPF', value=df.Sugars+df.TotalFat)

# %%
df.SPF
# Out:
# 0       16.0
# 1       11.0
# 2       25.0
# 3       30.0
# 4       25.0
#        ...
# 255     81.0
# 256    108.0
# 257     54.0
# 258    135.0
# 259     67.0
# Name: SPF, Length: 260, dtype: float64

# %%
df.head()
# Out:
#     Category                              Item   SPF    Serving Size  \
# 0  Breakfast                      Egg McMuffin  16.0  4.8 oz (136 g)
# 1  Breakfast                 Egg White Delight  11.0  4.8 oz (135 g)
# 2  Breakfast                  Sausage McMuffin  25.0  3.9 oz (111 g)
# 3  Breakfast         Sausage McMuffin with Egg  30.0  5.7 oz (161 g)
# 4  Breakfast  Sausage McMuffin with Egg Whites  25.0  5.7 oz (161 g)
#
#    Calories  Calories from Fat  TotalFat  Total Fat (% Daily Value)  \
# 0       300                120      13.0                         20
# 1       250                 70       8.0                         12
# 2       370                200      23.0                         35
# 3       450                250      28.0                         43
# 4       400                210      23.0                         35
#
#    Saturated Fat  Saturated Fat (% Daily Value)  ...  \
# 0            5.0                             25  ...
# ...

# %%
del df['SPF']

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200      23.0                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Dietary Fiber  \
# ...

# %%
df = df.drop(columns=['Sug&fat'])

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200      23.0                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  \
# ...

# %%
df.drop(columns=['SPF'], inplace=True)

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200      23.0                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  \
# ...

# %%
fuel.insert(loc=5, column='Combined KPL', value=fuel['Combined MPG (FT1)'] * 1.609 / 3.78)

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined KPL  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular      8.513228                20.0
# 27705        Regular      8.513228                20.0
# 26561        Regular      8.938889                21.0
# 27681        Regular      8.938889                21.0
# 27550        Regular      7.236243                17.0

# %%
fuel['liters per km'] =100/ fuel['Combined KPL']

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined KPL  Combined MPG (FT1)  liters per km
# Vehicle ID
# 26587        Regular      8.513228                20.0      11.746426
# 27705        Regular      8.513228                20.0      11.746426
# 26561        Regular      8.938889                21.0      11.187073
# 27681        Regular      8.938889                21.0      11.187073
# 27550        Regular      7.236243                17.0      13.819325

# %%
fuel.drop(columns=['Combined MPG (FT1)'], axis=1, inplace=True)

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined KPL  liters per km
# Vehicle ID
# 26587        Regular      8.513228      11.746426
# 27705        Regular      8.513228      11.746426
# 26561        Regular      8.938889      11.187073
# 27681        Regular      8.938889      11.187073
# 27550        Regular      7.236243      13.819325

# %%
del fuel['Combined KPL']

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  liters per km
# Vehicle ID
# 26587        Regular      11.746426
# 27705        Regular      11.746426
# 26561        Regular      11.187073
# 27681        Regular      11.187073
# 27550        Regular      13.819325

# %%
mc.loc[1,'Calories']=np.NaN
mc.loc[2,'TotalFat']=np.NaN

# %%
mc.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       NaN
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200       NaN                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
mc.dropna(axis=1).head()
# Out:
#     Category                              Item    Serving Size  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)
#
#    Calories from Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120                         20            5.0
# 1                 70                         12            3.0
# 2                200                         35            8.0
# 3                250                         43           10.0
# 4                210                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  Cholesterol  \
# 0                             25        0.0          260
# 1                             15        0.0           25
# ...

# %%
mc.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       NaN
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200       NaN                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
mc.fillna(value=0).head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       0.0
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200       0.0                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
replDefTable = {'Category':'UNKNOWN','TotalFat':666,'Calories':666}

# %%
mc.fillna(value=replDefTable).head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)     666.0
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200     666.0                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
mc['Calories'].fillna(value=777).head()
# Out:
# 0    300.0
# 1    777.0
# 2    370.0
# 3    450.0
# 4    400.0
# Name: Calories, dtype: float64

# %%
mc.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       NaN
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120      13.0                         20            5.0
# 1                 70       8.0                         12            3.0
# 2                200       NaN                         35            8.0
# 3                250      28.0                         43           10.0
# 4                210      23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
avgTotalFat = mc['TotalFat'].mean()

# %%
avgTotalFat
mc2=mc

# %%
mc2['TotalFat'].fillna(value=avgTotalFat,inplace=True)

# %%
mc2.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       NaN
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    Calories from Fat   TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120  13.000000                         20            5.0
# 1                 70   8.000000                         12            3.0
# 2                200  14.131274                         35            8.0
# 3                250  28.000000                         43           10.0
# 4                210  23.000000                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
mc2['Calories'].ffill(inplace=True)

# %%
mc2.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)     300.0
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    Calories from Fat   TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120  13.000000                         20            5.0
# 1                 70   8.000000                         12            3.0
# 2                200  14.131274                         35            8.0
# 3                250  28.000000                         43           10.0
# 4                210  23.000000                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                20.0
# 26561        Regular                21.0
# 27681        Regular                21.0
# 27550        Regular                17.0

# %%
fuel.loc[27705, 'Class'] = np.NaN
fuel.loc[26561, 'Class'] = np.NaN
fuel.loc[27550, 'Fuel Type'] = np.NaN
fuel.loc[27705, 'Combined MPG (FT1)'] = np.NaN
fuel.loc[27681, 'Combined MPG (FT1)'] = np.NaN

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5                          NaN
# 26561       1984  Alfa Romeo  Spider Veloce 2000                          NaN
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                 NaN
# 26561        Regular                21.0
# 27681        Regular                 NaN
# 27550            NaN                17.0

# %%
fuel.fillna(value=-1).head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5                           -1
# 26561       1984  Alfa Romeo  Spider Veloce 2000                           -1
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                -1.0
# 26561        Regular                21.0
# 27681        Regular                -1.0
# 27550             -1                17.0

# %%
replRul={'Class':'---','Fuel Type':'---','Combined MPG (FT1)':-1}

# %%
fuel.fillna(value=replRul).head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5                          ---
# 26561       1984  Alfa Romeo  Spider Veloce 2000                          ---
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                -1.0
# 26561        Regular                21.0
# 27681        Regular                -1.0
# 27550            ---                17.0

# %%
avgMPG=fuel['Combined MPG (FT1)'].mean()

# %%
avgMPG
# Out:
# 19.444177898424922

# %%
fuel.dropna(how='any').head()
# Out:
#             Year                         Make              Model  \
# Vehicle ID
# 26587       1984                   Alfa Romeo          GT V6 2.5
# 28426       1984                   AM General  DJ Po Vehicle 2WD
# 27549       1984                   AM General   FJ8c Post Office
# 28425       1984                   AM General   FJ8c Post Office
# 27593       1984  American Motors Corporation          Eagle 4WD
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587                  Minicompact Cars   Regular                20.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 27549       Special Purpose Vehicle 2WD   Regular                13.0
# 28425       Special Purpose Vehicle 2WD   Regular                13.0
# 27593       Special Purpose Vehicle 4WD   Regular                17.0

# %%
fuel2=fuel

# %%
fuel2['Class'].fillna(value='?',inplace=True)
fuel2['Fuel Type'].fillna(value='?',inplace=True)
fuel2['Combined MPG (FT1)'].fillna(value=avgMPG,inplace=True)

# %%
fuel2.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5                            ?
# 26561       1984  Alfa Romeo  Spider Veloce 2000                            ?
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular           20.000000
# 27705        Regular           19.444178
# 26561        Regular           21.000000
# 27681        Regular           19.444178
# 27550              ?           17.000000

# %%
fuel.bfill().head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5                  Two Seaters
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                21.0
# 26561        Regular                21.0
# 27681        Regular                17.0
# 27550        Regular                17.0

# %%
mc.sort_values(by='Calories').head()
# Out:
#          Category                    Item  Serving Size  Calories  \
# 122     Beverages  Diet Dr Pepper (Small)  16 fl oz cup       0.0
# 146  Coffee & Tea         Coffee (Medium)  16 fl oz cup       0.0
# 145  Coffee & Tea          Coffee (Small)  12 fl oz cup       0.0
# 140  Coffee & Tea        Iced Tea (Child)  12 fl oz cup       0.0
# 139  Coffee & Tea        Iced Tea (Large)  30 fl oz cup       0.0
#
#      Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 122                  0       0.0                          0            0.0
# 146                  0       0.0                          0            0.0
# 145                  0       0.0                          0            0.0
# 140                  0       0.0                          0            0.0
# 139                  0       0.0                          0            0.0
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
mc.sort_values(by='Calories', ascending=False).head()
# Out:
#           Category                                               Item  \
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
# 32       Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 34       Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 33       Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
#
#        Serving Size  Calories  Calories from Fat  TotalFat  \
# 82  22.8 oz (646 g)    1880.0               1060     118.0
# 32  15.3 oz (434 g)    1150.0                540      60.0
# 31  14.8 oz (420 g)    1090.0                510      56.0
# 34  15.4 oz (437 g)    1050.0                450      50.0
# 33  14.9 oz (423 g)     990.0                410      46.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 82                        182           20.0                            101
# ...

# %%
mc['Calories'] = mc['Calories'].astype('float')
mc.loc[82,'Calories']=np.NaN

# %%
mc.loc[82,'Calories']
# Out:
# nan

# %%
mc.sort_values(by='Calories').tail()
# Out:
#           Category                                               Item  \
# 33       Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 34       Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 31       Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 32       Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
#
#        Serving Size  Calories  Calories from Fat  TotalFat  \
# 33  14.9 oz (423 g)     990.0                410      46.0
# 34  15.4 oz (437 g)    1050.0                450      50.0
# 31  14.8 oz (420 g)    1090.0                510      56.0
# 32  15.3 oz (434 g)    1150.0                540      60.0
# 82  22.8 oz (646 g)       NaN               1060     118.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 33                         70           16.0                             78
# ...

# %%
mc.sort_values(by='Calories',na_position='first').head()
# Out:
#            Category                          Item     Serving Size  Calories  \
# 82   Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)       NaN
# 125       Beverages        Diet Dr Pepper (Child)     12 fl oz cup       0.0
# 138    Coffee & Tea             Iced Tea (Medium)     21 fl oz cup       0.0
# 137    Coffee & Tea              Iced Tea (Small)     16 fl oz cup       0.0
# 136       Beverages           Dasani Water Bottle       16.9 fl oz       0.0
#
#      Calories from Fat  TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 82                1060     118.0                        182           20.0
# 125                  0       0.0                          0            0.0
# 138                  0       0.0                          0            0.0
# 137                  0       0.0                          0            0.0
# 136                  0       0.0                          0            0.0
#
# ...

# %%
mc.sort_values(by=['Calories','Category'],na_position='first').head(20)
# Out:
#            Category                          Item     Serving Size  Calories  \
# 82   Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)       NaN
# 114       Beverages             Diet Coke (Small)     16 fl oz cup       0.0
# 115       Beverages            Diet Coke (Medium)     21 fl oz cup       0.0
# 116       Beverages             Diet Coke (Large)     30 fl oz cup       0.0
# 117       Beverages             Diet Coke (Child)     12 fl oz cup       0.0
# 122       Beverages        Diet Dr Pepper (Small)     16 fl oz cup       0.0
# 123       Beverages       Diet Dr Pepper (Medium)     21 fl oz cup       0.0
# 124       Beverages        Diet Dr Pepper (Large)     30 fl oz cup       0.0
# 125       Beverages        Diet Dr Pepper (Child)     12 fl oz cup       0.0
# 136       Beverages           Dasani Water Bottle       16.9 fl oz       0.0
# 137    Coffee & Tea              Iced Tea (Small)     16 fl oz cup       0.0
# ...

# %%
mc.sort_values(by=['Category','Calories']).head(20)
# Out:
#         Category                                       Item    Serving Size  \
# 48   Beef & Pork                                  Hamburger   3.5 oz (98 g)
# 49   Beef & Pork                               Cheeseburger    4 oz (113 g)
# 52   Beef & Pork                                   McDouble  5.2 oz (147 g)
# 50   Beef & Pork                        Double Cheeseburger  5.7 oz (161 g)
# 54   Beef & Pork                               Daily Double  6.7 oz (190 g)
# 55   Beef & Pork                            Jalapeño Double  5.6 oz (159 g)
# 53   Beef & Pork                             Bacon McDouble  5.7 oz (161 g)
# 56   Beef & Pork                                      McRib  7.3 oz (208 g)
# 43   Beef & Pork                Quarter Pounder with Cheese  7.1 oz (202 g)
# 42   Beef & Pork                                    Big Mac  7.4 oz (211 g)
# 46   Beef & Pork                     Quarter Pounder Deluxe  8.6 oz (244 g)
# ...

# %%
mc.sort_values(by=['Category','Calories'],ascending=[True,False]).head(20)
# Out:
#         Category                                       Item    Serving Size  \
# 47   Beef & Pork         Double Quarter Pounder with Cheese   10 oz (283 g)
# 51   Beef & Pork                     Bacon Clubhouse Burger  9.5 oz (270 g)
# 45   Beef & Pork  Quarter Pounder with Bacon Habanero Ranch  8.3 oz (235 g)
# 44   Beef & Pork        Quarter Pounder with Bacon & Cheese    8 oz (227 g)
# 46   Beef & Pork                     Quarter Pounder Deluxe  8.6 oz (244 g)
# 42   Beef & Pork                                    Big Mac  7.4 oz (211 g)
# 43   Beef & Pork                Quarter Pounder with Cheese  7.1 oz (202 g)
# 56   Beef & Pork                                      McRib  7.3 oz (208 g)
# 53   Beef & Pork                             Bacon McDouble  5.7 oz (161 g)
# 50   Beef & Pork                        Double Cheeseburger  5.7 oz (161 g)
# 54   Beef & Pork                               Daily Double  6.7 oz (190 g)
# ...

# %%
frame=pd.read_csv('F:/PandasUdemy/course-files/mcdonalds.csv',usecols=['Item','Category','Serving Size','Calories','TotalFat'])

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame.sort_index(ascending=True).head()
# Out:
#                                      Category       Serving Size  Calories  \
# Item
# 1% Low Fat Milk Jug                 Beverages  1 carton (236 ml)       100
# Apple Slices                   Snacks & Sides      1.2 oz (34 g)        15
# Bacon Buffalo Ranch McChicken  Chicken & Fish     5.7 oz (161 g)       430
# Bacon Cheddar McChicken        Chicken & Fish       6 oz (171 g)       480
# Bacon Clubhouse Burger            Beef & Pork     9.5 oz (270 g)       720
#
#                                TotalFat
# Item
# 1% Low Fat Milk Jug                 2.5
# Apple Slices                        0.0
# Bacon Buffalo Ranch McChicken      21.0
# Bacon Cheddar McChicken            24.0
# Bacon Clubhouse Burger             40.0

# %%
fuel.loc[27681, 'Combined MPG (FT1)'] = np.NaN

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5                          NaN
# 26561       1984  Alfa Romeo  Spider Veloce 2000                          NaN
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                 NaN
# 26561        Regular                21.0
# 27681        Regular                 NaN
# 27550            NaN                17.0

# %%
fuel.sort_values(by=['Make','Model']).head()
# Out:
#             Year        Make                Model  \
# Vehicle ID
# 27550       1984  AM General    DJ Po Vehicle 2WD
# 28426       1984  AM General    DJ Po Vehicle 2WD
# 27549       1984  AM General     FJ8c Post Office
# 28425       1984  AM General     FJ8c Post Office
# 1032        1985  AM General  Post Office DJ5 2WD
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 27550       Special Purpose Vehicle 2WD       NaN                17.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 27549       Special Purpose Vehicle 2WD   Regular                13.0
# 28425       Special Purpose Vehicle 2WD   Regular                13.0
# 1032        Special Purpose Vehicle 2WD   Regular                16.0

# %%
fuel.sort_values(by='Combined MPG (FT1)',ascending=False).head()
# Out:
#             Year        Make           Model             Class    Fuel Type  \
# Vehicle ID
# 31673       2012  Mitsubishi          i-MiEV   Subcompact Cars  Electricity
# 32278       2012        Ford  Focus Electric      Compact Cars  Electricity
# 32276       2011         BMW        Active E   Subcompact Cars  Electricity
# 30979       2011      Nissan            Leaf      Midsize Cars  Electricity
# 30978       2008        MINI           MiniE  Minicompact Cars  Electricity
#
#             Combined MPG (FT1)
# Vehicle ID
# 31673                    112.0
# 32278                    105.0
# 32276                    102.0
# 30979                     99.0
# 30978                     98.0

# %%
fuel.sort_values(by=['Make','Combined MPG (FT1)'], ascending=[True,False]).head()
# Out:
#             Year        Make                Model  \
# Vehicle ID
# 27550       1984  AM General    DJ Po Vehicle 2WD
# 28426       1984  AM General    DJ Po Vehicle 2WD
# 1032        1985  AM General  Post Office DJ5 2WD
# 27549       1984  AM General     FJ8c Post Office
# 28425       1984  AM General     FJ8c Post Office
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 27550       Special Purpose Vehicle 2WD       NaN                17.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 1032        Special Purpose Vehicle 2WD   Regular                16.0
# 27549       Special Purpose Vehicle 2WD   Regular                13.0
# 28425       Special Purpose Vehicle 2WD   Regular                13.0

# %%
fuel.sort_values(by='Combined MPG (FT1)',na_position='first').head()
# Out:
#             Year         Make               Model        Class Fuel Type  \
# Vehicle ID
# 27705       1984   Alfa Romeo           GT V6 2.5          NaN   Regular
# 27681       1984   Alfa Romeo  Spider Veloce 2000  Two Seaters   Regular
# 2914        1987  Lamborghini            Countach  Two Seaters   Premium
# 5267        1989  Lamborghini            Countach  Two Seaters   Premium
# 4141        1988  Lamborghini            Countach  Two Seaters   Premium
#
#             Combined MPG (FT1)
# Vehicle ID
# 27705                      NaN
# 27681                      NaN
# 2914                       7.0
# 5267                       7.0
# 4141                       7.0

# %%
fuel.sort_index(ascending=False).head()
# Out:
#             Year     Make                    Model  \
# Vehicle ID
# 34766       2011   Nissan    Murano CrossCabriolet
# 34765       2011  Lincoln           MKT Hearse AWD
# 34764       2011      Kia             Sportage 4WD
# 34763       2011     Jeep       Grand Cherokee 4WD
# 34762       2011  Lincoln  Navigator Limo. 2WD FFV
#
#                                   Class        Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 34766       Sport Utility Vehicle - 4WD          Premium                19.0
# 34765       Sport Utility Vehicle - 4WD          Regular                16.0
# 34764       Sport Utility Vehicle - 4WD          Regular                23.0
# 34763       Sport Utility Vehicle - 4WD          Regular                18.0
# 34762       Sport Utility Vehicle - 2WD  Gasoline or E85                13.0

# %%
mc.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)     300.0
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)     370.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    Calories from Fat   TotalFat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120  13.000000                         20            5.0
# 1                 70   8.000000                         12            3.0
# 2                200  14.131274                         35            8.0
# 3                250  28.000000                         43           10.0
# 4                210  23.000000                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame.dtypes
# Out:
# Category         object
# Item             object
# Serving Size     object
# Calories          int64
# TotalFat        float64
# dtype: object

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      260 non-null    object
#  1   Item          260 non-null    object
#  2   Serving Size  260 non-null    object
#  3   Calories      260 non-null    int64
#  4   TotalFat      260 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 61.7 KB

# %%
frame.loc[1,'Serving Size']=np.NaN
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight             NaN       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame.loc[2,'Calories']=np.NaN
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight             NaN     250.0
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       NaN
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      260 non-null    object
#  1   Item          260 non-null    object
#  2   Serving Size  259 non-null    object
#  3   Calories      259 non-null    float64
#  4   TotalFat      260 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 61.6 KB

# %%
frame['Calories'].fillna(value=0,inplace=True)
frame['Serving Size'].fillna(value=0,inplace=True)

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)     300.0
# 1  Breakfast                 Egg White Delight               0     250.0
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       0.0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame['Calories']=frame['Calories'].astype('int')

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      260 non-null    object
#  1   Item          260 non-null    object
#  2   Serving Size  260 non-null    object
#  3   Calories      260 non-null    int32
#  4   TotalFat      260 non-null    float64
# dtypes: float64(1), int32(1), object(3)
# memory usage: 60.6 KB

# %%
frame['Category'].value_counts()
# Out:
# Category
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: count, dtype: int64

# %%
frame['Category']=frame['Category'].astype('category')

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      260 non-null    category
#  1   Item          260 non-null    object
#  2   Serving Size  260 non-null    object
#  3   Calories      260 non-null    int32
#  4   TotalFat      260 non-null    float64
# dtypes: category(1), float64(1), int32(1), object(2)
# memory usage: 44.3 KB

# %%
frame['Serving Size'].value_counts()
# Out:
# Serving Size
# 16 fl oz cup       45
# 12 fl oz cup       38
# 22 fl oz cup       20
# 20 fl oz cup       16
# 30 fl oz cup        7
#                    ..
# 8 oz (227 g)        1
# 7.4 oz (211 g)      1
# 4 oz (114 g)        1
# 2 oz (56 g)         1
# 14.2 oz (403 g)     1
# Name: count, Length: 107, dtype: int64

# %%
frame['Serving Size']=frame['Serving Size'].astype('category')

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      260 non-null    category
#  1   Item          260 non-null    object
#  2   Serving Size  260 non-null    category
#  3   Calories      260 non-null    int32
#  4   TotalFat      260 non-null    float64
# dtypes: category(2), float64(1), int32(1), object(1)
# memory usage: 38.2 KB

# %%
fuel.head()
# Out:
#             Year        Make               Model                        Class  \
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 27705       1984  Alfa Romeo           GT V6 2.5                          NaN
# 26561       1984  Alfa Romeo  Spider Veloce 2000                          NaN
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                 NaN
# 26561        Regular                21.0
# 27681        Regular                 NaN
# 27550            NaN                17.0

# %%
fuel['Year']=fuel['Year'].astype('int')

# %%
fuel.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31684 entries, 26587 to 32106
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                31684 non-null  int32
#  1   Make                31684 non-null  object
#  2   Model               31683 non-null  object
#  3   Class               31682 non-null  object
#  4   Fuel Type           31683 non-null  object
#  5   Combined MPG (FT1)  31682 non-null  float64
# dtypes: float64(1), int32(1), object(4)
# memory usage: 9.8 MB

# %%
fuel['Make'].value_counts()
# Out:
# Make
# Chevrolet                 3389
# Ford                      2721
# Dodge                     2361
# GMC                       2174
# Toyota                    1599
#                           ...
# General Motors               1
# Panoz Auto-Development       1
# Goldacre                     1
# Panos                        1
# Mitsubish                    1
# Name: count, Length: 128, dtype: int64

# %%
fuel['Make']=fuel['Make'].astype('category')

# %%
fuel.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31684 entries, 26587 to 32106
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                31684 non-null  int32
#  1   Make                31684 non-null  category
#  2   Model               31683 non-null  object
#  3   Class               31682 non-null  object
#  4   Fuel Type           31683 non-null  object
#  5   Combined MPG (FT1)  31682 non-null  float64
# dtypes: category(1), float64(1), int32(1), object(3)
# memory usage: 7.9 MB

# %%
fuel['Model'].value_counts()
# Out:
# Model
# F150 Pickup 2WD                 194
# Truck 2WD                       187
# F150 Pickup 4WD                 172
# Ranger Pickup 2WD               169
# Mustang                         156
#                                ...
# Silver Spur II Mpw Touring L      1
# Brooklands/Brklnds L              1
# Vdp                               1
# Pas-Typhoon                       1
# Lancer AWD                        1
# Name: count, Length: 2957, dtype: int64

# %%
fuel['Class'].value_counts()
# Out:
# Class
# Compact Cars                    4489
# Subcompact Cars                 4299
# Midsize Cars                    3393
# Standard Pickup Trucks          2354
# Sport Utility Vehicle - 4WD     2034
# Sport Utility Vehicle - 2WD     1598
# Special Purpose Vehicles        1455
# Two Seaters                     1447
# Large Cars                      1351
# Small Station Wagons            1275
# Vans                            1141
# Standard Pickup Trucks 2WD      1043
# Minicompact Cars                 940
# Standard Pickup Trucks 4WD       846
# Midsize-Large Station Wagons     656
# Small Pickup Trucks              538
# Special Purpose Vehicle 2WD      536
# Midsize Station Wagons           492
# Vans, Cargo Type                 397
# Small Pickup Trucks 2WD          365
# Special Purpose Vehicle 4WD      287
# Minivan - 2WD                    278
# Vans, Passenger Type             253
# Small Pickup Trucks 4WD          162
# Minivan - 4WD                     41
# ...

# %%
fuel['Fuel Type'].value_counts()
# Out:
# Fuel Type
# Regular                       22438
# Premium                        7375
# Diesel                          936
# Gasoline or E85                 767
# CNG                              55
# Electricity                      33
# Premium or E85                   33
# Gasoline or natural gas          18
# Midgrade                         16
# Gasoline or propane               8
# Premium Gas or Electricity        3
# ?                                 1
# Name: count, dtype: int64

# %%
fuel['Fuel Type']=fuel['Fuel Type'].astype('category')

# %%
fuel['Class']=fuel['Class'].astype('category')

# %%
fuel['Model']=fuel['Model'].astype('category')

# %%
fuel.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31684 entries, 26587 to 32106
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                31684 non-null  int32
#  1   Make                31684 non-null  category
#  2   Model               31683 non-null  category
#  3   Class               31682 non-null  category
#  4   Fuel Type           31683 non-null  category
#  5   Combined MPG (FT1)  31682 non-null  float64
# dtypes: category(4), float64(1), int32(1)
# memory usage: 2.1 MB

# %%
fuel['Combined MPG (FT1)']=fuel['Combined MPG (FT1)'].astype('float')

# %%
fuel.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31684 entries, 26587 to 32106
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                31684 non-null  int32
#  1   Make                31684 non-null  category
#  2   Model               31683 non-null  category
#  3   Class               31682 non-null  category
#  4   Fuel Type           31683 non-null  category
#  5   Combined MPG (FT1)  31682 non-null  float64
# dtypes: category(4), float64(1), int32(1)
# memory usage: 2.1 MB

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight               0       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)         0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
frame.sort_values(by='Calories', ascending=False).head()
# Out:
#           Category                                               Item  \
# 82  Chicken & Fish                       Chicken McNuggets (40 piece)
# 32       Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 34       Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 33       Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
#
#        Serving Size  Calories  TotalFat
# 82  22.8 oz (646 g)      1880     118.0
# 32  15.3 oz (434 g)      1150      60.0
# 31  14.8 oz (420 g)      1090      56.0
# 34  15.4 oz (437 g)      1050      50.0
# 33  14.9 oz (423 g)       990      46.0

# %%
frame['Calories'].rank().head()
# Out:
# 0    116.0
# 1     83.5
# 2      9.0
# 3    178.5
# 4    156.0
# Name: Calories, dtype: float64

# %%
frame['Calories Rank'] = frame['Calories'].rank(ascending=False)

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight               0       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)         0
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat  Calories Rank
# 0      13.0          116.0
# 1       8.0           83.5
# 2      23.0            9.0
# 3      28.0          178.5
# 4      23.0          156.0

# %%
frame.sort_values(by='Calories').head(20)
# Out:
#            Category                     Item    Serving Size  Calories  \
# 114       Beverages        Diet Coke (Small)    16 fl oz cup         0
# 147    Coffee & Tea           Coffee (Large)    16 fl oz cup         0
# 146    Coffee & Tea          Coffee (Medium)    16 fl oz cup         0
# 145    Coffee & Tea           Coffee (Small)    12 fl oz cup         0
# 140    Coffee & Tea         Iced Tea (Child)    12 fl oz cup         0
# 139    Coffee & Tea         Iced Tea (Large)    30 fl oz cup         0
# 138    Coffee & Tea        Iced Tea (Medium)    21 fl oz cup         0
# 137    Coffee & Tea         Iced Tea (Small)    16 fl oz cup         0
# 136       Beverages      Dasani Water Bottle      16.9 fl oz         0
# 124       Beverages   Diet Dr Pepper (Large)    30 fl oz cup         0
# 125       Beverages   Diet Dr Pepper (Child)    12 fl oz cup         0
# 122       Beverages   Diet Dr Pepper (Small)    16 fl oz cup         0
# ...

# %%
frame.sort_values(by='Calories', ascending=False).head(20)
# Out:
#                Category                                               Item  \
# 82       Chicken & Fish                       Chicken McNuggets (40 piece)
# 32            Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 31            Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 34            Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 33            Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 81       Chicken & Fish                       Chicken McNuggets (20 piece)
# 253  Smoothies & Shakes               McFlurry with M&M’s Candies (Medium)
# 246  Smoothies & Shakes                           Strawberry Shake (Large)
# 249  Smoothies & Shakes                            Chocolate Shake (Large)
# 251  Smoothies & Shakes                             Shamrock Shake (Large)
# 243  Smoothies & Shakes                              Vanilla Shake (Large)
# ...

# %%
frame.nlargest(columns=['Calories'], n=3)
# Out:
#           Category                                           Item  \
# 82  Chicken & Fish                   Chicken McNuggets (40 piece)
# 32       Breakfast    Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)
#
#        Serving Size  Calories  TotalFat  Calories Rank
# 82  22.8 oz (646 g)      1880     118.0            1.0
# 32  15.3 oz (434 g)      1150      60.0            2.0
# 31  14.8 oz (420 g)      1090      56.0            3.0

# %%
frame.tail(3)
# Out:
#                Category                                               Item  \
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  TotalFat  Calories Rank
# 257   6.7 oz (190 g)       340      11.0          127.5
# 258  14.2 oz (403 g)       810      32.0           12.0
# 259   7.1 oz (202 g)       410      16.0          101.5

# %%
frame2=frame

# %%
frame2.sort_values(by='Calories Rank',inplace=True)

# %%
frame2.head(3)
# Out:
#           Category                                           Item  \
# 82  Chicken & Fish                   Chicken McNuggets (40 piece)
# 32       Breakfast    Big Breakfast with Hotcakes (Large Biscuit)
# 31       Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)
#
#        Serving Size  Calories  TotalFat  Calories Rank
# 82  22.8 oz (646 g)      1880     118.0            1.0
# 32  15.3 oz (434 g)      1150      60.0            2.0
# 31  14.8 oz (420 g)      1090      56.0            3.0

# %%
frame2.tail(3)
# Out:
#          Category                 Item  Serving Size  Calories  TotalFat  \
# 114     Beverages    Diet Coke (Small)  16 fl oz cup         0       0.0
# 136     Beverages  Dasani Water Bottle    16.9 fl oz         0       0.0
# 145  Coffee & Tea       Coffee (Small)  12 fl oz cup         0       0.0
#
#      Calories Rank
# 114          252.0
# 136          252.0
# 145          252.0

# %%
frame.nsmallest(n=3, columns='Calories')
# Out:
#          Category              Item    Serving Size  Calories  TotalFat  \
# 146  Coffee & Tea   Coffee (Medium)    16 fl oz cup         0       0.0
# 2       Breakfast  Sausage McMuffin  3.9 oz (111 g)         0      23.0
# 147  Coffee & Tea    Coffee (Large)    16 fl oz cup         0       0.0
#
#      Calories Rank
# 146          252.0
# 2            252.0
# 147          252.0

# %%
 fortune=pd.read_csv('F:/PandasUdemy/course-files/Fortune_500_2017.csv',
                     usecols=['Rank','Title','Employees','Profits','Assets'],index_col='Rank')

# %%
fortune.head()
# Out:
#                    Title  Employees  Profits  Assets
# Rank
# 1                Walmart    2300000  13643.0  198825
# 2     Berkshire Hathaway     367700  24074.0  620854
# 3                  Apple     116000  45687.0  321686
# 4            Exxon Mobil      72700   7840.0  330314
# 5               McKesson      68000   2258.0   56563

# %%
fortune['Most Employees']=fortune['Employees'].rank(ascending=False)

# %%
fortune.head()
# Out:
#                    Title  Employees  Profits  Assets  Most Employees
# Rank
# 1                Walmart    2300000  13643.0  198825             1.0
# 2     Berkshire Hathaway     367700  24074.0  620854             7.0
# 3                  Apple     116000  45687.0  321686            57.0
# 4            Exxon Mobil      72700   7840.0  330314            94.0
# 5               McKesson      68000   2258.0   56563           104.5

# %%
fortune['RankByProfit']=fortune['Profits'].rank(ascending=False)

# %%
fortune.head()
# Out:
#                    Title  Employees  Profits  Assets  Most Employees  \
# Rank
# 1                Walmart    2300000  13643.0  198825             1.0
# 2     Berkshire Hathaway     367700  24074.0  620854             7.0
# 3                  Apple     116000  45687.0  321686            57.0
# 4            Exxon Mobil      72700   7840.0  330314            94.0
# 5               McKesson      68000   2258.0   56563           104.5
#
#       RankByProfit
# Rank
# 1             11.0
# 2              3.0
# 3              1.0
# 4             27.0
# 5            102.0

# %%
fortune.nlargest(n=3,columns='Assets')
# Out:
#                       Title  Employees  Profits   Assets  Most Employees  \
# Rank
# 20               Fannie Mae       7000  12313.0  3287968           446.5
# 21        J.P. Morgan Chase     243355  24733.0  2490972            20.0
# 26    Bank of America Corp.     208024  17906.0  2187702            29.0
#
#       RankByProfit
# Rank
# 20            15.0
# 21             2.0
# 26             6.0

# %%
fortune.nsmallest(n=3,columns='Assets')
# Out:
#                        Title  Employees  Profits  Assets  Most Employees  \
# Rank
# 395   A-Mark Precious Metals         83      9.3     437           500.0
# 247        Core-Mark Holding       7688     54.2    1497           434.0
# 495                 Big Lots      23150    152.8    1608           266.0
#
#       RankByProfit
# Rank
# 395          434.0
# 247          430.0
# 495          403.0

# %%
fortune.nsmallest(n=10,columns='Most Employees')
# Out:
#                    Title  Employees  Profits  Assets  Most Employees  \
# Rank
# 1                Walmart    2300000  13643.0  198825             1.0
# 18                Kroger     443000   1975.0   36505             2.0
# 399   Yum China Holdings     420000    502.0    3727             3.0
# 32                   IBM     414400  11872.0  117470             4.0
# 23            Home Depot     406000   7957.0   42966             5.0
# 112           McDonald’s     375000   4686.5   31024             6.0
# 2     Berkshire Hathaway     367700  24074.0  620854             7.0
# 12            Amazon.com     341400   2371.0   83402             8.0
# 58                 FedEx     335767   1820.0   46064             9.0
# 46                   UPS     335520   3431.0   40377            10.0
#
#       RankByProfit
# Rank
# 1             11.0
# 18           117.0
# 399          300.0
# 32            16.0
# 23            26.0
# 112           51.0
# 2              3.0
# 12            96.0
# ...

# %%
frame[frame['Calories']>=400]
# Out:
#            Category                                               Item  \
# 82   Chicken & Fish                       Chicken McNuggets (40 piece)
# 32        Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 31        Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 34        Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 33        Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# ..              ...                                                ...
# 8         Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 16        Breakfast   Southern Style Chicken Biscuit (Regular Biscuit)
# 4         Breakfast                   Sausage McMuffin with Egg Whites
# 195    Coffee & Tea             Hot Chocolate with Nonfat Milk (Large)
# 20        Breakfast     Bacon, Egg & Cheese McGriddles with Egg Whites
#
#         Serving Size  Calories  TotalFat  Calories Rank
# 82   22.8 oz (646 g)      1880     118.0            1.0
# ...

# %%
totalfat20 = frame['TotalFat']<=20

# %%
frame[totalfat20]
# Out:
#                Category                       Item  Serving Size  Calories  \
# 248  Smoothies & Shakes   Chocolate Shake (Medium)  16 fl oz cup       700
# 245  Smoothies & Shakes  Strawberry Shake (Medium)  16 fl oz cup       690
# 242  Smoothies & Shakes     Vanilla Shake (Medium)  16 fl oz cup       660
# 250  Smoothies & Shakes    Shamrock Shake (Medium)  16 fl oz cup       660
# 247  Smoothies & Shakes    Chocolate Shake (Small)  12 fl oz cup       560
# ..                  ...                        ...           ...       ...
# 116           Beverages          Diet Coke (Large)  30 fl oz cup         0
# 115           Beverages         Diet Coke (Medium)  21 fl oz cup         0
# 114           Beverages          Diet Coke (Small)  16 fl oz cup         0
# 136           Beverages        Dasani Water Bottle    16.9 fl oz         0
# 145        Coffee & Tea             Coffee (Small)  12 fl oz cup         0
#
#      TotalFat  Calories Rank
# 248      20.0           19.0
# ...

# %%
isBreakfast = frame['Category'] == 'Breakfast'

# %%
frame[isBreakfast & totalfat20].head()
# Out:
#      Category                                               Item  \
# 39  Breakfast                                     Cinnamon Melts
# 8   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 16  Breakfast   Southern Style Chicken Biscuit (Regular Biscuit)
# 20  Breakfast     Bacon, Egg & Cheese McGriddles with Egg Whites
# 35  Breakfast                                           Hotcakes
#
#       Serving Size  Calories  TotalFat  Calories Rank
# 39    4 oz (114 g)       460      19.0           77.0
# 8   5.4 oz (153 g)       410      20.0          101.5
# 16    5 oz (143 g)       410      20.0          101.5
# 20  6.3 oz (178 g)       400      15.0          105.0
# 35  5.3 oz (151 g)       350       9.0          121.0

# %%
fortune.head()
# Out:
#                    Title  Employees  Profits  Assets  Most Employees  \
# Rank
# 1                Walmart    2300000  13643.0  198825             1.0
# 2     Berkshire Hathaway     367700  24074.0  620854             7.0
# 3                  Apple     116000  45687.0  321686            57.0
# 4            Exxon Mobil      72700   7840.0  330314            94.0
# 5               McKesson      68000   2258.0   56563           104.5
#
#       RankByProfit
# Rank
# 1             11.0
# 2              3.0
# 3              1.0
# 4             27.0
# 5            102.0

# %%
isEmployeesRankFirst10 = fortune['Most Employees']<=10

# %%
isProfitRank10 = fortune['RankByProfit']<=10

# %%
isEmployeesRankMore400 = fortune['Most Employees']>=400

# %%
fortune[isEmployeesRankMore400 & isProfitRank10]
# Out:
#              Title  Employees  Profits  Assets  Most Employees  RankByProfit
# Rank
# 148   Altria Group       8300  14239.0   45932           424.0          10.0

# %%
frame.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    TotalFat
# 0      13.0
# 1       8.0
# 2      23.0
# 3      28.0
# 4      23.0

# %%
hasMore400Cal = frame['Calories'] >= 400

# %%
hasMore400Cal[:5]
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: Calories, dtype: bool

# %%
frame.where(hasMore400Cal).head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0        NaN                               NaN             NaN       NaN
# 1        NaN                               NaN             NaN       NaN
# 2        NaN                               NaN             NaN       NaN
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)     450.0
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)     400.0
#
#    TotalFat
# 0       NaN
# 1       NaN
# 2       NaN
# 3      28.0
# 4      23.0

# %%
frame[hasMore400Cal].head()
# Out:
#     Category                                           Item    Serving Size  \
# 3  Breakfast                      Sausage McMuffin with Egg  5.7 oz (161 g)
# 4  Breakfast               Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# 5  Breakfast                           Steak & Egg McMuffin  6.5 oz (185 g)
# 6  Breakfast  Bacon, Egg & Cheese Biscuit (Regular Biscuit)  5.3 oz (150 g)
# 7  Breakfast    Bacon, Egg & Cheese Biscuit (Large Biscuit)  5.8 oz (164 g)
#
#    Calories  TotalFat
# 3       450      28.0
# 4       400      23.0
# 5       430      23.0
# 6       460      26.0
# 7       520      30.0

# %%
frame.where(hasMore400Cal).dropna(how='all').head()
# Out:
#     Category                                           Item    Serving Size  \
# 3  Breakfast                      Sausage McMuffin with Egg  5.7 oz (161 g)
# 4  Breakfast               Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# 5  Breakfast                           Steak & Egg McMuffin  6.5 oz (185 g)
# 6  Breakfast  Bacon, Egg & Cheese Biscuit (Regular Biscuit)  5.3 oz (150 g)
# 7  Breakfast    Bacon, Egg & Cheese Biscuit (Large Biscuit)  5.8 oz (164 g)
#
#    Calories  TotalFat
# 3     450.0      28.0
# 4     400.0      23.0
# 5     430.0      23.0
# 6     460.0      26.0
# 7     520.0      30.0

# %%
frame.query('Category == "Desserts"').head()
# Out:
#      Category                   Item     Serving Size  Calories  TotalFat
# 103  Desserts        Baked Apple Pie    2.7 oz (77 g)       250      13.0
# 104  Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160       8.0
# 105  Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150       6.0
# 106  Desserts    Kids Ice Cream Cone      1 oz (29 g)        45       1.5
# 107  Desserts       Hot Fudge Sundae   6.3 oz (179 g)       330       9.0

# %%
frame.query('Category in ["Desserts","Beverages"]').head()
# Out:
#      Category                   Item     Serving Size  Calories  TotalFat
# 103  Desserts        Baked Apple Pie    2.7 oz (77 g)       250      13.0
# 104  Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160       8.0
# 105  Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150       6.0
# 106  Desserts    Kids Ice Cream Cone      1 oz (29 g)        45       1.5
# 107  Desserts       Hot Fudge Sundae   6.3 oz (179 g)       330       9.0

# %%
frame.query('Category == "Desserts" and Calories < 200').head()
# Out:
#      Category                   Item     Serving Size  Calories  TotalFat
# 104  Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160       8.0
# 105  Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150       6.0
# 106  Desserts    Kids Ice Cream Cone      1 oz (29 g)        45       1.5

# %%
animals=pd.read_csv('F:/PandasUdemy/course-files/sleep_time.csv',index_col='ID',na_values=[np.nan])

# %%
animals.head()
# Out:
#                           name       genus   vore         order  conservation  \
# ID
# 1                      Cheetah    Acinonyx  carni     Carnivora            lc
# 2                   Owl monkey       Aotus   omni      Primates           NaN
# 3              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 4   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 5                          Cow         Bos  herbi  Artiodactyla  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ID
# 1          12.1        NaN          NaN   11.9      NaN   50.000
# 2          17.0        1.8          NaN    7.0  0.01550    0.480
# 3          14.4        2.4          NaN    9.6      NaN    1.350
# 4          14.9        2.3     0.133333    9.1  0.00029    0.019
# 5           4.0        0.7     0.666667   20.0  0.42300  600.000

# %%
herbi = animals.where(animals['vore'] == 'herbi')

# %%
herbi.head()
# Out:
#                name       genus   vore         order  conservation  \
# ID
# 1               NaN         NaN    NaN           NaN           NaN
# 2               NaN         NaN    NaN           NaN           NaN
# 3   Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 4               NaN         NaN    NaN           NaN           NaN
# 5               Cow         Bos  herbi  Artiodactyla  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 1           NaN        NaN          NaN    NaN      NaN     NaN
# 2           NaN        NaN          NaN    NaN      NaN     NaN
# 3          14.4        2.4          NaN    9.6      NaN    1.35
# 4           NaN        NaN          NaN    NaN      NaN     NaN
# 5           4.0        0.7     0.666667   20.0    0.423  600.00

# %%
carni = animals[animals['vore'] == 'carni']

# %%
len(herbi)
# Out:
# 83

# %%
len(carni)
# Out:
# 19

# %%
herbi.dropna(inplace=True)

# %%
herbi.head()
# Out:
#               name         genus   vore           order  conservation  \
# ID
# 5              Cow           Bos  herbi    Artiodactyla  domesticated
# 12      Guinea pig         Cavis  herbi        Rodentia  domesticated
# 14      Chinchilla    Chinchilla  herbi        Rodentia  domesticated
# 23           Horse         Equus  herbi  Perissodactyla  domesticated
# 40  Golden hamster  Mesocricetus  herbi        Rodentia            en
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ID
# 5           4.0        0.7     0.666667   20.0   0.4230  600.000
# 12          9.4        0.8     0.216667   14.6   0.0055    0.728
# 14         12.5        1.5     0.116667   11.5   0.0064    0.420
# 23          2.9        0.6     1.000000   21.1   0.6550  521.000
# 40         14.3        3.1     0.200000    9.7   0.0010    0.120

# %%
len(herbi)
# Out:
# 10

# %%
len(carni.dropna())
# Out:
# 19

# %%
carni.head()
# Out:
#                     name        genus   vore      order  conservation  \
# ID
# 1                Cheetah     Acinonyx  carni  Carnivora            lc
# 7      Northern fur seal  Callorhinus  carni  Carnivora            vu
# 9                    Dog        Canis  carni  Carnivora  domesticated
# 18  Long-nosed armadillo      Dasypus  carni  Cingulata            lc
# 28          Domestic cat        Felis  carni  Carnivora  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 1          12.1        0.0     0.000000   11.9   0.0000   50.00
# 7           8.7        1.4     0.383333   15.3   0.0000   20.49
# 9          10.1        2.9     0.333333   13.9   0.0700   14.00
# 18         17.4        3.1     0.383333    6.6   0.0108    3.50
# 28         12.5        3.2     0.416667   11.5   0.0256    3.30

# %%
# Out:
#                           name          genus   vore            order  \
# ID
# 1                      Cheetah       Acinonyx  carni        Carnivora
# 7            Northern fur seal    Callorhinus  carni        Carnivora
# 9                          Dog          Canis  carni        Carnivora
# 18        Long-nosed armadillo        Dasypus  carni        Cingulata
# 28                Domestic cat          Felis  carni        Carnivora
# 31                 Pilot whale  Globicephalus  carni          Cetacea
# 32                   Gray seal   Haliochoerus  carni        Carnivora
# 37        Thick-tailed opposum     Lutreolina  carni  Didelphimorphia
# 45                  Slow loris      Nyctibeus  carni         Primates
# 47  Northern grasshopper mouse      Onychomys  carni         Rodentia
# 51                       Tiger       Panthera  carni        Carnivora
# 52                      Jaguar       Panthera  carni        Carnivora
# ...

# %%
omni = animals[animals['vore']=='omni']

# %%
omni.head()
# Out:
#                           name          genus  vore         order  \
# ID
# 2                   Owl monkey          Aotus  omni      Primates
# 4   Greater short-tailed shrew        Blarina  omni  Soricomorpha
# 13                      Grivet  Cercopithecus  omni      Primates
# 15             Star-nosed mole      Condylura  omni  Soricomorpha
# 16   African giant pouched rat     Cricetomys  omni      Rodentia
#
#    conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 2           NaN         17.0        1.8          NaN    7.0  0.01550   0.480
# 4            lc         14.9        2.3     0.133333    9.1  0.00029   0.019
# 13           lc         10.0        0.7          NaN   14.0      NaN   4.750
# 15           lc         10.3        2.2          NaN   13.7  0.00100   0.060
# 16          NaN          8.3        2.0          NaN   15.7  0.00660   1.000

# %%
len(omni)
# Out:
# 20

# %%
omni = omni.dropna()

# %%
len(omni)
# Out:
# 5

# %%
omni['sleep_total'].mean()
# Out:
# 10.925

# %%
herbi['sleep_total'].mean()
# Out:
# 9.509374999999999

# %%
carni['sleep_total'].mean()
# Out:
# 10.378947368421054

# %%
animals.query('sleep_total >14')
# Out:
#                               name         genus     vore            order  \
# ID
# 2                       Owl monkey         Aotus     omni         Primates
# 3                  Mountain beaver    Aplodontia    herbi         Rodentia
# 4       Greater short-tailed shrew       Blarina     omni     Soricomorpha
# 6                 Three-toed sloth      Bradypus    herbi           Pilosa
# 18            Long-nosed armadillo       Dasypus    carni        Cingulata
# 20          North American Opossum     Didelphis     omni  Didelphimorphia
# 22                   Big brown bat     Eptesicus  insecti       Chiroptera
# 27       Western american chipmunk      Eutamias    herbi         Rodentia
# 37            Thick-tailed opposum    Lutreolina    carni  Didelphimorphia
# 39                Mongolian gerbil      Meriones    herbi         Rodentia
# 40                  Golden hamster  Mesocricetus    herbi         Rodentia
# ...

# %%
animals.query('sleep_total >14 and vore=="herbi"')
# Out:
#                               name         genus   vore     order  \
# ID
# 3                  Mountain beaver    Aplodontia  herbi  Rodentia
# 6                 Three-toed sloth      Bradypus  herbi    Pilosa
# 27       Western american chipmunk      Eutamias  herbi  Rodentia
# 39                Mongolian gerbil      Meriones  herbi  Rodentia
# 40                  Golden hamster  Mesocricetus  herbi  Rodentia
# 44            Round-tailed muskrat      Neofiber  herbi  Rodentia
# 70          Arctic ground squirrel  Spermophilus  herbi  Rodentia
# 72  Golden-mantled ground squirrel  Spermophilus  herbi  Rodentia
# 76       Eastern american chipmunk        Tamias  herbi  Rodentia
#
#    conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 3            nt         14.4        2.4          NaN    9.6      NaN   1.350
# 6           NaN         14.4        2.2     0.766667    9.6      NaN   3.850
# ...

# %%
animals.query('sleep_total > 14 and vore == "herbi" and bodywt > 1')
# Out:
#                 name       genus   vore     order conservation  sleep_total  \
# ID
# 3    Mountain beaver  Aplodontia  herbi  Rodentia           nt         14.4
# 6   Three-toed sloth    Bradypus  herbi    Pilosa          NaN         14.4
#
#     sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 3         2.4          NaN    9.6      NaN    1.35
# 6         2.2     0.766667    9.6      NaN    3.85

# %%
myAnimals = animals['vore'].isin(['carni','herbi'])

# %%
animals[myAnimals].head(10)
# Out:
#                  name        genus   vore         order  conservation  \
# ID
# 1             Cheetah     Acinonyx  carni     Carnivora            lc
# 3     Mountain beaver   Aplodontia  herbi      Rodentia            nt
# 5                 Cow          Bos  herbi  Artiodactyla  domesticated
# 6    Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 7   Northern fur seal  Callorhinus  carni     Carnivora            vu
# 9                 Dog        Canis  carni     Carnivora  domesticated
# 10           Roe deer    Capreolus  herbi  Artiodactyla            lc
# 11               Goat        Capri  herbi  Artiodactyla            lc
# 12         Guinea pig        Cavis  herbi      Rodentia  domesticated
# 14         Chinchilla   Chinchilla  herbi      Rodentia  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ID
# 1          12.1        NaN          NaN   11.9      NaN   50.000
# ...

# %%
notNaNCycle = animals['sleep_cycle'].notnull()

# %%
animals[notNaNCycle].head()
# Out:
#                           name        genus   vore         order  \
# ID
# 4   Greater short-tailed shrew      Blarina   omni  Soricomorpha
# 5                          Cow          Bos  herbi  Artiodactyla
# 6             Three-toed sloth     Bradypus  herbi        Pilosa
# 7            Northern fur seal  Callorhinus  carni     Carnivora
# 9                          Dog        Canis  carni     Carnivora
#
#     conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ID
# 4             lc         14.9        2.3     0.133333    9.1  0.00029    0.019
# 5   domesticated          4.0        0.7     0.666667   20.0  0.42300  600.000
# 6            NaN         14.4        2.2     0.766667    9.6      NaN    3.850
# 7             vu          8.7        1.4     0.383333   15.3      NaN   20.490
# 9   domesticated         10.1        2.9     0.333333   13.9  0.07000   14.000

# %%
NaNCycle = animals['sleep_cycle'].isnull()

# %%
animals[NaNCycle].head()
# Out:
#                name       genus   vore         order conservation  \
# ID
# 1           Cheetah    Acinonyx  carni     Carnivora           lc
# 2        Owl monkey       Aotus   omni      Primates          NaN
# 3   Mountain beaver  Aplodontia  herbi      Rodentia           nt
# 8      Vesper mouse     Calomys    NaN      Rodentia          NaN
# 10         Roe deer   Capreolus  herbi  Artiodactyla           lc
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# ID
# 1          12.1        NaN          NaN   11.9      NaN  50.000
# 2          17.0        1.8          NaN    7.0   0.0155   0.480
# 3          14.4        2.4          NaN    9.6      NaN   1.350
# 8           7.0        NaN          NaN   17.0      NaN   0.045
# 10          3.0        NaN          NaN   21.0   0.0982  14.800

# %%
sleepBetween = animals['sleep_total'].between(8,10)

# %%
animals[sleepBetween]
# Out:
#                          name          genus     vore         order  \
# ID
# 7           Northern fur seal    Callorhinus    carni     Carnivora
# 12                 Guinea pig          Cavis    herbi      Rodentia
# 13                     Grivet  Cercopithecus     omni      Primates
# 16  African giant pouched rat     Cricetomys     omni      Rodentia
# 17  Lesser short-tailed shrew      Cryptotis     omni  Soricomorpha
# 29                     Galago         Galago     omni      Primates
# 34                      Human           Homo     omni      Primates
# 35             Mongoose lemur          Lemur    herbi      Primates
# 48                     Rabbit    Oryctolagus    herbi    Lagomorpha
# 50                 Chimpanzee            Pan     omni      Primates
# 54                     Baboon          Papio     omni      Primates
# 65      African striped mouse      Rhabdomys     omni      Rodentia
# 66            Squirrel monkey        Saimiri     omni      Primates
# ...

# %%
fuel.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 fuel.head()
#
# NameError: name 'fuel' is not defined

# %%
fuel=pd.read_csv('F:/PandasUdemy/course-files/fuel.csv',usecols=['Vehicle ID','Year','Make','Model','Class',
                                                                      'Fuel Type','Combined MPG (FT1)','Start Stop Technology'], low_memory=False)

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class Fuel Type  Combined MPG (FT1)  \
# 0             Minicompact Cars   Regular                20.0
# 1             Minicompact Cars   Regular                20.0
# 2                  Two Seaters   Regular                21.0
# 3                  Two Seaters   Regular                21.0
# 4  Special Purpose Vehicle 2WD   Regular                17.0
#
#   Start Stop Technology
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
listOfCars = ['Renault','Toyota','Ford']

# %%
isinList = fuel['Make'].isin(listOfCars)

# %%
fuel[isinList].head()
# Out:
#      Vehicle ID  Year  Make       Model                        Class  \
# 668       27613  1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD
# 669       27616  1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD
# 670       27619  1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD
# 671       27622  1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD
# 672       28472  1984  Ford  Bronco 4WD  Special Purpose Vehicle 4WD
#
#     Fuel Type  Combined MPG (FT1) Start Stop Technology
# 668   Regular                13.0                   NaN
# 669   Regular                11.0                   NaN
# 670   Regular                10.0                   NaN
# 671   Regular                11.0                   NaN
# 672   Regular                13.0                   NaN

# %%
isNoStartStopDefined = fuel['Start Stop Technology'].notna()

# %%
fuel[isNoStartStopDefined].head()
# Out:
#        Vehicle ID  Year       Make                      Model  \
# 16448       30976  1998  Chevrolet               S10 Electric
# 16449       30977  1998  Chevrolet               S10 Electric
# 16711       30975  1998      Honda                    EV Plus
# 17323       30973  1999      Dodge  Caravan/Grand Caravan 2WD
# 17433       30971  1999       Ford          Ranger Pickup 2WD
#
#                             Class    Fuel Type  Combined MPG (FT1)  \
# 16448     Small Pickup Trucks 2WD  Electricity                55.0
# 16449     Small Pickup Trucks 2WD  Electricity                28.0
# 16711                Compact Cars  Electricity                48.0
# 17323               Minivan - 2WD  Electricity                35.0
# 17433  Standard Pickup Trucks 2WD  Electricity                58.0
#
#       Start Stop Technology
# 16448                     N
# 16449                     N
# 16711                     N
# 17323                     N
# 17433                     N

# %%
isStartStopDefined = fuel['Start Stop Technology'].isna()

# %%
fuel[isStartStopDefined]
# Out:
#        Vehicle ID  Year        Make               Model  \
# 0           26587  1984  Alfa Romeo           GT V6 2.5
# 1           27705  1984  Alfa Romeo           GT V6 2.5
# 2           26561  1984  Alfa Romeo  Spider Veloce 2000
# 3           27681  1984  Alfa Romeo  Spider Veloce 2000
# 4           27550  1984  AM General   DJ Po Vehicle 2WD
# ...           ...   ...         ...                 ...
# 31679       32060  2012  Mitsubishi              Lancer
# 31680       32063  2012  Mitsubishi          Lancer AWD
# 31681       32065  2012  Mitsubishi    Lancer Evolution
# 31682       32064  2012  Mitsubishi    Lancer Evolution
# 31683       32106  2012   Mitsubish                 NaN
#
#                              Class Fuel Type  Combined MPG (FT1)  \
# 0                 Minicompact Cars   Regular                20.0
# 1                 Minicompact Cars   Regular                20.0
# 2                      Two Seaters   Regular                21.0
# ...

# %%
 mpg50_60 = fuel['Combined MPG (FT1)'].between(50,60)

# %%
fuel[mpg50_60].head()
# Out:
#        Vehicle ID  Year       Make              Model  \
# 16448       30976  1998  Chevrolet       S10 Electric
# 17433       30971  1999       Ford  Ranger Pickup 2WD
# 18295       30966  2000       Ford  Ranger Pickup 2WD
# 18296       30967  2000       Ford  Ranger Pickup 2WD
# 18371       15606  2000      Honda            Insight
#
#                             Class    Fuel Type  Combined MPG (FT1)  \
# 16448     Small Pickup Trucks 2WD  Electricity                55.0
# 17433  Standard Pickup Trucks 2WD  Electricity                58.0
# 18295  Standard Pickup Trucks 2WD  Electricity                58.0
# 18296  Standard Pickup Trucks 2WD  Electricity                56.0
# 18371                 Two Seaters      Regular                53.0
#
#       Start Stop Technology
# 16448                     N
# 17433                     N
# 18295                     N
# 18296                     N
# 18371                     Y

# %%
print(f'There are {len(fuel[isinList])} cars within {listOfCars}')
# Out:
# There are 4376 cars within ['Renault', 'Toyota', 'Ford']

# %%
fuel['Model'].unique()
# Out:
# array(['GT V6 2.5', 'Spider Veloce 2000', 'DJ Po Vehicle 2WD', ...,
#        'i-MiEV', 'Lancer AWD', nan], dtype=object)

# %%
fuel['Model'].is_unique
# Out:
# False

# %%
fuel['Model'].nunique()
# Out:
# 2957

# %%
len(fuel['Model'].unique())
# Out:
# 2958

# %%
fuel['Model'].duplicated(keep='first')
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 31679     True
# 31680    False
# 31681     True
# 31682     True
# 31683    False
# Name: Model, Length: 31684, dtype: bool

# %%
fuel['Model'].duplicated(keep=False)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 31679     True
# 31680    False
# 31681     True
# 31682     True
# 31683    False
# Name: Model, Length: 31684, dtype: bool

# %%
uniqueVal = fuel['Model'].duplicated(keep='first')
fuel[-uniqueVal]
# Out:
#        Vehicle ID  Year                         Make  \
# 0           26587  1984                   Alfa Romeo
# 2           26561  1984                   Alfa Romeo
# 4           27550  1984                   AM General
# 6           27549  1984                   AM General
# 8           27593  1984  American Motors Corporation
# ...           ...   ...                          ...
# 31666       31631  2012                         MINI
# 31667       31632  2012                         MINI
# 31674       31673  2012                   Mitsubishi
# 31680       32063  2012                   Mitsubishi
# 31683       32106  2012                    Mitsubish
#
#                             Model                        Class    Fuel Type  \
# 0                       GT V6 2.5             Minicompact Cars      Regular
# 2              Spider Veloce 2000                  Two Seaters      Regular
# 4               DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD      Regular
# ...

# %%
fuel.drop_duplicates(subset=['Model'])
# Out:
#        Vehicle ID  Year                         Make  \
# 0           26587  1984                   Alfa Romeo
# 2           26561  1984                   Alfa Romeo
# 4           27550  1984                   AM General
# 6           27549  1984                   AM General
# 8           27593  1984  American Motors Corporation
# ...           ...   ...                          ...
# 31666       31631  2012                         MINI
# 31667       31632  2012                         MINI
# 31674       31673  2012                   Mitsubishi
# 31680       32063  2012                   Mitsubishi
# 31683       32106  2012                    Mitsubish
#
#                             Model                        Class    Fuel Type  \
# 0                       GT V6 2.5             Minicompact Cars      Regular
# 2              Spider Veloce 2000                  Two Seaters      Regular
# 4               DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD      Regular
# ...

# %%
surveys = pd.read_csv('F:/PandasUdemy/course-files/StackOverflowDeveloperSurvey2018.csv', usecols=['Country','Gender','OperatingSystem'], low_memory=False)

# %%
surveys.head()
# Out:
#           Country OperatingSystem Gender
# 0           Kenya     Linux-based   Male
# 1  United Kingdom     Linux-based   Male
# 2   United States             NaN    NaN
# 3   United States         Windows   Male
# 4    South Africa         Windows   Male

# %%
surveys['Country'].is_unique
# Out:
# False

# %%
countries = surveys.drop_duplicates(subset=['Country'])

# %%
countries.head()
# Out:
#           Country OperatingSystem  Gender
# 0           Kenya     Linux-based    Male
# 1  United Kingdom     Linux-based    Male
# 2   United States             NaN     NaN
# 4    South Africa         Windows    Male
# 7         Nigeria         Windows  Female

# %%
len(countries)
# Out:
# 184

# %%
countries.nunique()
# Out:
# Country            183
# OperatingSystem      4
# Gender               5
# dtype: int64

# %%
duplicatesKeepFirst = surveys['Country'].duplicated(keep='first')

# %%
surveys[~duplicatesKeepFirst].head()
# Out:
#           Country OperatingSystem  Gender
# 0           Kenya     Linux-based    Male
# 1  United Kingdom     Linux-based    Male
# 2   United States             NaN     NaN
# 4    South Africa         Windows    Male
# 7         Nigeria         Windows  Female

# %%
len(surveys[~duplicatesKeepFirst])
# Out:
# 184

# %%
surveys.drop_duplicates(subset=['Country','OperatingSystem'], inplace=True)

# %%
surveys.query('Country == "Poland"')
# Out:
#       Country OperatingSystem Gender
# 30     Poland     Linux-based   Male
# 34     Poland         Windows   Male
# 232    Poland             NaN    NaN
# 854    Poland           MacOS   Male
# 72587  Poland        BSD/Unix    NaN

# %%
frame = pd.read_csv('F:/PandasUdemy/course-files/mammals.csv')

# %%
frame.head()
# Out:
#               name     body  brain
# 0       Arctic fox    3.385   44.5
# 1       Owl monkey    0.480   15.5
# 2  Mountain beaver    1.350    8.1
# 3              Cow  465.000  423.0
# 4        Grey wolf   36.330  119.5

# %%
frame.columns = ['NAME','bodyKG','brainKG']

# %%
frame.head()
# Out:
#               NAME   bodyKG  brainKG
# 0       Arctic fox    3.385     44.5
# 1       Owl monkey    0.480     15.5
# 2  Mountain beaver    1.350      8.1
# 3              Cow  465.000    423.0
# 4        Grey wolf   36.330    119.5

# %%
newColNames = {'bodyKG':'body_kg', 'brainKG':'brain_kg'}

# %%
frame.rename(columns=newColNames, inplace=True)

# %%
frame.head()
# Out:
#               NAME  body_kg  brain_kg
# 0       Arctic fox    3.385      44.5
# 1       Owl monkey    0.480      15.5
# 2  Mountain beaver    1.350       8.1
# 3              Cow  465.000     423.0
# 4        Grey wolf   36.330     119.5

# %%
frame = pd.read_csv('F:/PandasUdemy/course-files/mammals.csv', index_col='name')

# %%
frame.head()
# Out:
#                     body  brain
# name
# Arctic fox         3.385   44.5
# Owl monkey         0.480   15.5
# Mountain beaver    1.350    8.1
# Cow              465.000  423.0
# Grey wolf         36.330  119.5

# %%
frame.rename(index= {'Cow':'land_cow'}, inplace=True)

# %%
frame.head()
# Out:
#                     body  brain
# name
# Arctic fox         3.385   44.5
# Owl monkey         0.480   15.5
# Mountain beaver    1.350    8.1
# land_cow         465.000  423.0
# Grey wolf         36.330  119.5

# %%
frameCopy = frame.copy()

# %%
frameCopy.head()
# Out:
#                    body  brain
# name
# Arctic fox         5.00   44.5
# Owl monkey         0.48   15.5
# Mountain beaver    1.35    8.1
# land_cow         465.00  423.0
# Grey wolf         36.33  119.5

# %%
frameCopy.loc['Arctic fox','body'] = 7

# %%
frameCopy.head()
# Out:
#                    body  brain
# name
# Arctic fox         7.00   44.5
# Owl monkey         0.48   15.5
# Mountain beaver    1.35    8.1
# land_cow         465.00  423.0
# Grey wolf         36.33  119.5

# %%
frame.head()
# Out:
#                    body  brain
# name
# Arctic fox         5.00   44.5
# Owl monkey         0.48   15.5
# Mountain beaver    1.35    8.1
# land_cow         465.00  423.0
# Grey wolf         36.33  119.5

# %%
professions = pd.read_csv('F:/PandasUdemy/course-files/Prestige.csv', index_col='name')

# %%
professions.head()
# Out:
#                      education  income  women  prestige  census  type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113  prof
# general.managers         12.26   25879   4.02      69.1    1130  prof
# accountants              12.77    9271  15.70      63.4    1171  prof
# purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# chemists                 14.62    8403  11.68      73.5    2111  prof

# %%
professionsOriginal = professions.copy()

# %%
professionsOriginal.head()
# Out:
#                      education  income  women  prestige  census  type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113  prof
# general.managers         12.26   25879   4.02      69.1    1130  prof
# accountants              12.77    9271  15.70      63.4    1171  prof
# purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# chemists                 14.62    8403  11.68      73.5    2111  prof

# %%
professions.rename(columns={'income':'incomeUSDperYear'}, inplace=True)

# %%
professions.rename(columns={'women':'women%','prestige':'prestigeIndicator'}, inplace=True)

# %%
professions.head()
# Out:
#                      education  incomeUSDperYear  women%  prestigeIndicator  \
# name
# gov.administrators       13.11             12351   11.16               68.8
# general.managers         12.26             25879    4.02               69.1
# accountants              12.77              9271   15.70               63.4
# purchasing.officers      11.42              8865    9.11               56.8
# chemists                 14.62              8403   11.68               73.5
#
#                      census  type
# name
# gov.administrators     1113  prof
# general.managers       1130  prof
# accountants            1171  prof
# purchasing.officers    1175  prof
# chemists               2111  prof

# %%
professions.rename(index={'accountants':'bookkeepers','general.managers':'managers'}, inplace=True)

# %%
professions.head()
# Out:
#                      education  incomeUSDperYear  women%  prestigeIndicator  \
# name
# gov.administrators       13.11             12351   11.16               68.8
# managers                 12.26             25879    4.02               69.1
# bookkeepers              12.77              9271   15.70               63.4
# purchasing.officers      11.42              8865    9.11               56.8
# chemists                 14.62              8403   11.68               73.5
#
#                      census  type
# name
# gov.administrators     1113  prof
# managers               1130  prof
# bookkeepers            1171  prof
# purchasing.officers    1175  prof
# chemists               2111  prof

# %%
professionsOriginal.head()
# Out:
#                      education  income  women  prestige  census  type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113  prof
# general.managers         12.26   25879   4.02      69.1    1130  prof
# accountants              12.77    9271  15.70      63.4    1171  prof
# purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# chemists                 14.62    8403  11.68      73.5    2111  prof

# %%
frame = pd.read_csv('F:/PandasUdemy/course-files/insurance.csv')

# %%
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 0   1         1     <1l    <25      197      38
# 1   2         1     <1l  25-29      264      35
# 2   3         1     <1l  30-35      246      20
# 3   4         1     <1l    >35     1680     156
# 4   5         1  1-1.5l    <25      284      63

# %%
frame.loc[2,'Claims']
# Out:
# 20

# %%
frame.iloc[2]['Claims']
# Out:
# 20

# %%
frame.loc[2,'Claims'] = 22

# %%
frame.loc[2,'Claims']
# Out:
# 22

# %%
frame['Age'] == "<25"
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 59    False
# 60     True
# 61    False
# 62    False
# 63    False
# Name: Age, Length: 64, dtype: bool

# %%
isYounger25 = frame['Age'] == "<25"

# %%
frame.where(isYounger25).dropna().head()
# Out:
#       ID  District   Group  Age  Holders  Claims
# 0    1.0       1.0     <1l  <25    197.0    38.0
# 4    5.0       1.0  1-1.5l  <25    284.0    63.0
# 8    9.0       1.0  1.5-2l  <25    133.0    19.0
# 12  13.0       1.0     >2l  <25     24.0     4.0
# 16  17.0       2.0     <1l  <25     85.0    22.0

# %%
frame[isYounger25].head()
# Out:
#     ID  District   Group  Age  Holders  Claims
# 0    1         1     <1l  <25      197      38
# 4    5         1  1-1.5l  <25      284      63
# 8    9         1  1.5-2l  <25      133      19
# 12  13         1     >2l  <25       24       4
# 16  17         2     <1l  <25       85      22

# %%
frame.loc[isYounger25,'Holders'] + 100
# Out:
# 0     297
# 4     384
# 8     233
# 12    124
# 16    185
# 20    249
# 24    166
# 28    109
# 32    135
# 36    153
# 40    124
# 44    107
# 48    120
# 52    131
# 56    118
# 60    103
# Name: Holders, dtype: int64

# %%
frame.loc[isYounger25,'Holders'] = frame.loc[isYounger25, 'Holders'] + 100

# %%
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 0   1         1     <1l    <25     3363      38
# 1   2         1     <1l  25-29      264      35
# 2   3         1     <1l  30-35      246      22
# 3   4         1     <1l    >35     1680     156
# 4   5         1  1-1.5l    <25     3450      63

# %%
frame.loc[isYounger25,'Holders'] += 2000

# %%
frame.head()
# Out:
#    ID  District   Group    Age  Holders  Claims
# 0   1         1     <1l    <25     5363      38
# 1   2         1     <1l  25-29      264      35
# 2   3         1     <1l  30-35      246      22
# 3   4         1     <1l    >35     1680     156
# 4   5         1  1-1.5l    <25     5450      63

# %%
professions = pd.read_csv('F:/PandasUdemy/course-files/Prestige.csv', index_col='name')

# %%
professions.head()
# Out:
#                      education  income  women  prestige  census  type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113  prof
# general.managers         12.26   25879   4.02      69.1    1130  prof
# accountants              12.77    9271  15.70      63.4    1171  prof
# purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# chemists                 14.62    8403  11.68      73.5    2111  prof

# %%
professions.loc['chemists','type'] = 'scientist'

# %%
professions.head()
# Out:
#                      education  income  women  prestige  census       type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113       prof
# general.managers         12.26   25879   4.02      69.1    1130       prof
# accountants              12.77    9271  15.70      63.4    1171       prof
# purchasing.officers      11.42    8865   9.11      56.8    1175       prof
# chemists                 14.62    8403  11.68      73.5    2111  scientist

# %%
isSci=professions['type'] == 'scientist'

# %%
isSci
# Out:
# name
# gov.administrators     False
# general.managers       False
# accountants            False
# purchasing.officers    False
# chemists                True
#                        ...
# bus.drivers            False
# taxi.drivers           False
# longshoremen           False
# typesetters            False
# bookbinders            False
# Name: type, Length: 102, dtype: bool

# %%
professions.loc[isSci,'type'] = 90

# %%
professions.head()
# Out:
#                      education  income  women  prestige  census  type
# name
# gov.administrators       13.11   12351  11.16      68.8    1113  prof
# general.managers         12.26   25879   4.02      69.1    1130  prof
# accountants              12.77    9271  15.70      63.4    1171  prof
# purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# chemists                 14.62    8403  11.68      73.5    2111    90

# %%
professions.loc[isSci,'income']*=1.5
# Out:
# C:\Users\kpas9\AppData\Local\Temp\ipykernel_13428\1629590718.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12604.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   professions.loc[isSci,'income']*=1.5

# %%
professions.head()
# Out:
#                      education   income  women  prestige  census  type
# name
# gov.administrators       13.11  12351.0  11.16      68.8    1113  prof
# general.managers         12.26  25879.0   4.02      69.1    1130  prof
# accountants              12.77   9271.0  15.70      63.4    1171  prof
# purchasing.officers      11.42   8865.0   9.11      56.8    1175  prof
# chemists                 14.62  12604.5  11.68      73.5    2111    90

# %%
frame=pd.read_csv('F:/PandasUdemy/course-files/sleep_time.csv', index_col='ID')

# %%
frame.head()
# Out:
#                           name       genus   vore         order  conservation  \
# ID
# 1                      Cheetah    Acinonyx  carni     Carnivora            lc
# 2                   Owl monkey       Aotus   omni      Primates           NaN
# 3              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 4   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 5                          Cow         Bos  herbi  Artiodactyla  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# ID
# 1          12.1        NaN          NaN   11.9      NaN   50.000
# 2          17.0        1.8          NaN    7.0  0.01550    0.480
# 3          14.4        2.4          NaN    9.6      NaN    1.350
# 4          14.9        2.3     0.133333    9.1  0.00029    0.019
# 5           4.0        0.7     0.666667   20.0  0.42300  600.000

# %%
del frame['bodywt']

# %%
frame.head()
# Out:
#                           name       genus   vore         order  conservation  \
# ID
# 1                      Cheetah    Acinonyx  carni     Carnivora            lc
# 2                   Owl monkey       Aotus   omni      Primates           NaN
# 3              Mountain beaver  Aplodontia  herbi      Rodentia            nt
# 4   Greater short-tailed shrew     Blarina   omni  Soricomorpha            lc
# 5                          Cow         Bos  herbi  Artiodactyla  domesticated
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt
# ID
# 1          12.1        NaN          NaN   11.9      NaN
# 2          17.0        1.8          NaN    7.0  0.01550
# 3          14.4        2.4          NaN    9.6      NaN
# 4          14.9        2.3     0.133333    9.1  0.00029
# 5           4.0        0.7     0.666667   20.0  0.42300

# %%
frame.drop(axis=1,columns=['awake','brainwt'], inplace=True)

# %%
frame.drop(axis='rows',labels=3,inplace=True)

# %%
frame.head()
# Out:
#                           name     genus   vore         order  conservation  \
# ID
# 1                      Cheetah  Acinonyx  carni     Carnivora            lc
# 2                   Owl monkey     Aotus   omni      Primates           NaN
# 4   Greater short-tailed shrew   Blarina   omni  Soricomorpha            lc
# 5                          Cow       Bos  herbi  Artiodactyla  domesticated
# 6             Three-toed sloth  Bradypus  herbi        Pilosa           NaN
#
#     sleep_total  sleep_rem  sleep_cycle
# ID
# 1          12.1        NaN          NaN
# 2          17.0        1.8          NaN
# 4          14.9        2.3     0.133333
# 5           4.0        0.7     0.666667
# 6          14.4        2.2     0.766667

# %%
frame.drop(labels=4, inplace=True)

# %%
frame.head()
# Out:
#                  name        genus   vore         order  conservation  \
# ID
# 1             Cheetah     Acinonyx  carni     Carnivora            lc
# 2          Owl monkey        Aotus   omni      Primates           NaN
# 5                 Cow          Bos  herbi  Artiodactyla  domesticated
# 6    Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 7   Northern fur seal  Callorhinus  carni     Carnivora            vu
#
#     sleep_total  sleep_rem  sleep_cycle
# ID
# 1          12.1        NaN          NaN
# 2          17.0        1.8          NaN
# 5           4.0        0.7     0.666667
# 6          14.4        2.2     0.766667
# 7           8.7        1.4     0.383333

# %%
frame.drop(5, inplace=True)

# %%
frame.head()
# Out:
#                  name        genus   vore      order conservation  \
# ID
# 1             Cheetah     Acinonyx  carni  Carnivora           lc
# 2          Owl monkey        Aotus   omni   Primates          NaN
# 6    Three-toed sloth     Bradypus  herbi     Pilosa          NaN
# 7   Northern fur seal  Callorhinus  carni  Carnivora           vu
# 8        Vesper mouse      Calomys    NaN   Rodentia          NaN
#
#     sleep_total  sleep_rem  sleep_cycle
# ID
# 1          12.1        NaN          NaN
# 2          17.0        1.8          NaN
# 6          14.4        2.2     0.766667
# 7           8.7        1.4     0.383333
# 8           7.0        NaN          NaN

# %%
dict = {'name': ['Panda4'], 'genus': [np.NaN], 'vore': [np.NaN], 'order': [np.NaN], 'conservation': [np.NaN], 'sleep_total': [10]}

# %%
frame2=pd.concat([frame, pd.DataFrame(dict)], ignore_index=True)

# %%
frame2
# Out:
#                     name        genus   vore      order conservation  \
# 0                Cheetah     Acinonyx  carni  Carnivora           lc
# 1             Owl monkey        Aotus   omni   Primates          NaN
# 2       Three-toed sloth     Bradypus  herbi     Pilosa          NaN
# 3      Northern fur seal  Callorhinus  carni  Carnivora           vu
# 4           Vesper mouse      Calomys    NaN   Rodentia          NaN
# ..                   ...          ...    ...        ...          ...
# 76  Bottle-nosed dolphin     Tursiops  carni    Cetacea          NaN
# 77                 Genet      Genetta  carni  Carnivora          NaN
# 78            Arctic fox       Vulpes  carni  Carnivora          NaN
# 79               Red fox       Vulpes  carni  Carnivora          NaN
# 80                Panda4          NaN    NaN        NaN          NaN
#
#     sleep_total  sleep_rem  sleep_cycle
# 0          12.1        NaN          NaN
# 1          17.0        1.8          NaN
# ...

# %%
frame=pd.read_csv('F:/PandasUdemy/course-files/Prestige.csv')

# %%
frame.head()
# Out:
#                   name  education  income  women  prestige  census  type
# 0   gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1     general.managers      12.26   25879   4.02      69.1    1130  prof
# 2          accountants      12.77    9271  15.70      63.4    1171  prof
# 3  purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4             chemists      14.62    8403  11.68      73.5    2111  prof

# %%
dict = {'name':['data scientist'],'education':['np.NaN'],'income':['np.NaN'],'women':['np.NaN'],
        'prestige':['np.NaN'],'census':['np.NaN'],'type':['np.NaN']}

# %%
frame = pd.concat([frame,pd.DataFrame(dict)], ignore_index=True)

# %%
frame.tail()
# Out:
#                name education  income   women prestige  census    type
# 98     taxi.drivers      7.93    4224    3.59     25.1    9173      bc
# 99     longshoremen      8.37    4753     0.0     26.1    9313      bc
# 100     typesetters      10.0    6462   13.58     42.2    9511      bc
# 101     bookbinders      8.55    3617   70.87     35.2    9517      bc
# 102  data scientist    np.NaN  np.NaN  np.NaN   np.NaN  np.NaN  np.NaN

# %%
taxi = frame[frame['name']=='taxi.drivers']

# %%
taxi
# Out:
#             name education income women prestige census type
# 98  taxi.drivers      7.93   4224  3.59     25.1   9173   bc

# %%
frame['name']=='taxi.drivers'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 98      True
# 99     False
# 100    False
# 101    False
# 102    False
# Name: name, Length: 103, dtype: bool

# %%
frame.drop(index=98,inplace=True)

# %%
frame.tail()
# Out:
#                name education  income   women prestige  census    type
# 97      bus.drivers      7.58    5562    9.47     35.9    9171      bc
# 99     longshoremen      8.37    4753     0.0     26.1    9313      bc
# 100     typesetters      10.0    6462   13.58     42.2    9511      bc
# 101     bookbinders      8.55    3617   70.87     35.2    9517      bc
# 102  data scientist    np.NaN  np.NaN  np.NaN   np.NaN  np.NaN  np.NaN

# %%
frame=pd.concat([frame,taxi], ignore_index=True)

# %%
frame.tail()
# Out:
#                name education  income   women prestige  census    type
# 98     longshoremen      8.37    4753     0.0     26.1    9313      bc
# 99      typesetters      10.0    6462   13.58     42.2    9511      bc
# 100     bookbinders      8.55    3617   70.87     35.2    9517      bc
# 101  data scientist    np.NaN  np.NaN  np.NaN   np.NaN  np.NaN  np.NaN
# 102    taxi.drivers      7.93    4224    3.59     25.1    9173      bc

# %%
professions.drop(columns=['census'], inplace=True)

# %%
del professions['type']

# %%
professions.head()
# Out:
#                      education   income  women  prestige
# name
# gov.administrators       13.11  12351.0  11.16      68.8
# general.managers         12.26  25879.0   4.02      69.1
# accountants              12.77   9271.0  15.70      63.4
# purchasing.officers      11.42   8865.0   9.11      56.8
# chemists                 14.62  12604.5  11.68      73.5

# %%
frame=pd.read_csv('F:/PandasUdemy/course-files/mammals.csv')

# %%
frame.head()
# Out:
#               name     body  brain
# 0       Arctic fox    3.385   44.5
# 1       Owl monkey    0.480   15.5
# 2  Mountain beaver    1.350    8.1
# 3              Cow  465.000  423.0
# 4        Grey wolf   36.330  119.5

# %%
frame.set_index('name',inplace=True)

# %%
frame.head()
# Out:
#                     body  brain
# name
# Arctic fox         3.385   44.5
# Owl monkey         0.480   15.5
# Mountain beaver    1.350    8.1
# Cow              465.000  423.0
# Grey wolf         36.330  119.5

# %%
frame.reset_index(inplace=True)

# %%
frame.head()
# Out:
#               name     body  brain
# 0       Arctic fox    3.385   44.5
# 1       Owl monkey    0.480   15.5
# 2  Mountain beaver    1.350    8.1
# 3              Cow  465.000  423.0
# 4        Grey wolf   36.330  119.5

# %%
frame.set_index('name',inplace=True)

# %%
frame.loc['Cow']
# Out:
# body     465.0
# brain    423.0
# Name: Cow, dtype: float64

# %%
frame.sort_index(inplace=True)

# %%
frame[:'Cat']
# Out:
#                                body   brain
# name
# African elephant           6654.000  5712.0
# African giant pouched rat     1.000     6.6
# Arctic fox                    3.385    44.5
# Arctic ground squirrel        0.920     5.7
# Asian elephant             2547.000  4603.0
# Baboon                       10.550   179.5
# Big brown bat                 0.023     0.3
# Brazilian tapir             160.000   169.0
# Cat                           3.300    25.6

# %%
frame['A':'C']
# Out:
#                                body   brain
# name
# African elephant           6654.000  5712.0
# African giant pouched rat     1.000     6.6
# Arctic fox                    3.385    44.5
# Arctic ground squirrel        0.920     5.7
# Asian elephant             2547.000  4603.0
# Baboon                       10.550   179.5
# Big brown bat                 0.023     0.3
# Brazilian tapir             160.000   169.0

# %%
fortune = pd.read_csv('F:/PandasUdemy/course-files/Fortune_500_2017.csv')

# %%
fortune.head()
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 2     3               Apple              http://www.apple.com     116000
# 3     4         Exxon Mobil         http://www.exxonmobil.com      72700
# 4     5            McKesson           http://www.mckesson.com      68000
#
#         Sector                                  Industry         Hqlocation  \
# 0    Retailing                     General Merchandisers    Bentonville, AR
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2   Technology               Computers, Office Equipment      Cupertino, CA
# 3       Energy                        Petroleum Refining         Irving, TX
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco, CA
#
#                    Hqaddr         Hqcity Hqstate  ...  \
# ...

# %%
fortune.set_index('Rank')
# Out:
#                    Title                           Website  Employees  \
# Rank
# 1                Walmart            http://www.walmart.com    2300000
# 2     Berkshire Hathaway  http://www.berkshirehathaway.com     367700
# 3                  Apple              http://www.apple.com     116000
# 4            Exxon Mobil         http://www.exxonmobil.com      72700
# 5               McKesson           http://www.mckesson.com      68000
# ...                  ...                               ...        ...
# 496        Michaels Cos.           http://www.michaels.com      31000
# 497        Toll Brothers       http://www.tollbrothers.com       4200
# 498                Yahoo              http://www.yahoo.com       8500
# 499        Vistra Energy       http://www.vistraenergy.com       4431
# 500       ABM Industries                http://www.abm.com     110000
#
#                           Sector                                  Industry  \
# Rank
# ...

# %%
fortune[100:105]
# Out:
#      Rank                        Title                   Website  Employees  \
# 100   101     Twenty-First Century Fox       http://www.21cf.com      21500
# 101   102                         USAA       http://www.usaa.com      29943
# 102   103          World Fuel Services    http://www.wfscorp.com       5000
# 103   104  Philip Morris International        http://www.pmi.com      79500
# 104   105                        Deere  http://www.johndeere.com      56767
#
#                         Sector                                  Industry  \
# 100                      Media                             Entertainment
# 101                 Financials  Insurance: Property and Casualty (Stock)
# 102                     Energy                                    Energy
# 103  Food, Beverages & Tobacco                                   Tobacco
# 104                Industrials           Construction and Farm Machinery
#
# ...

# %%
fortune[100:105][['Title','Employees']]
# Out:
#                            Title  Employees
# 100     Twenty-First Century Fox      21500
# 101                         USAA      29943
# 102          World Fuel Services       5000
# 103  Philip Morris International      79500
# 104                        Deere      56767

# %%
fortune.reset_index(inplace=True)

# %%
fortune.set_index('Title',inplace=True)

# %%
fortune.head()
# Out:
#                     index  Rank                           Website  Employees  \
# Title
# Walmart                 0     1            http://www.walmart.com    2300000
# Berkshire Hathaway      1     2  http://www.berkshirehathaway.com     367700
# Apple                   2     3              http://www.apple.com     116000
# Exxon Mobil             3     4         http://www.exxonmobil.com      72700
# McKesson                4     5           http://www.mckesson.com      68000
#
#                          Sector                                  Industry  \
# Title
# Walmart               Retailing                     General Merchandisers
# Berkshire Hathaway   Financials  Insurance: Property and Casualty (Stock)
# Apple                Technology               Computers, Office Equipment
# Exxon Mobil              Energy                        Petroleum Refining
# McKesson            Wholesalers                  Wholesalers: Health Care
#
# ...

# %%
fortune.sort_index(inplace=True)

# %%
fortune['X':'Y']
# Out:
#                index  Rank                    Website  Employees  \
# Title
# XPO Logistics    190   191         http://www.xpo.com      87000
# Xcel Energy      255   256  http://www.xcelenergy.com      11476
# Xerox            161   162       http://www.xerox.com     133600
#
#                        Sector                      Industry       Hqlocation  \
# Title
# XPO Logistics  Transportation  Transportation and Logistics    Greenwich, CT
# Xcel Energy            Energy   Utilities: Gas and Electric  Minneapolis, MN
# Xerox              Technology          Computer Peripherals      Norwalk, CT
#
#                           Hqaddr       Hqcity Hqstate  ...  \
# Title                                                  ...
# XPO Logistics    5 American Lane    Greenwich      CT  ...
# Xcel Energy    414 Nicollet Mall  Minneapolis      MN  ...
# Xerox             45 Glover Ave.      Norwalk      CT  ...
#
#                                                    Ceo-title  \
# Title
# ...

# %%
frame = pd.read_csv('F:/PandasUdemy/course-files/PublicTransitExpenses.csv', 
                    usecols=['Agency','Reporter Type', 'Total Operating Expenses'])

# %%
frame.head()
# Out:
#                                 Agency     Reporter Type  \
# 0      Washington County Commissioners  Reduced Reporter
# 1      Washington County Commissioners  Reduced Reporter
# 2  Texoma Area Paratransit System, Inc     Full Reporter
# 3            Kalispel Tribe of Indians  Reduced Reporter
# 4            Kalispel Tribe of Indians  Reduced Reporter
#
#   Total Operating Expenses
# 0               $122524.00
# 1               $272715.00
# 2                 $7295.00
# 3                $37416.00
# 4               $345789.00

# %%
contWash = frame['Agency'].str.contains('Washington')

# %%
frame[contWash]
# Out:
#                                     Agency     Reporter Type  \
# 0          Washington County Commissioners  Reduced Reporter
# 1          Washington County Commissioners  Reduced Reporter
# 199               Washington State Ferries     Full Reporter
# 213               Washington State Ferries     Full Reporter
# 364               Washington State Ferries     Full Reporter
# ...                                    ...               ...
# 15871  Washington Hancock Community Agency    Rural Reporter
# 16213                   City of Washington    Rural Reporter
# 16313                   City of Washington    Rural Reporter
# 16316   Washington Parish Council on Aging    Rural Reporter
# 16780   Washington Parish Council on Aging    Rural Reporter
#
#       Total Operating Expenses
# 0                   $122524.00
# 1                   $272715.00
# 199               $16215777.00
# 213               $11132493.00
# 364               $11750411.00
# ...                        ...
# ...

# %%
frame['Agency'] = frame['Agency'].str.lower()

# %%
frame['Agency'].str.lower().str.contains('washington')
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 17839    False
# 17840    False
# 17841    False
# 17842    False
# 17843    False
# Name: Agency, Length: 17844, dtype: bool

# %%
endsWithFerries = frame['Agency'].str.lower().str.strip().str.endswith('ferries')

# %%
frame[endsWithFerries]
# Out:
#                         Agency  Reporter Type Total Operating Expenses
# 199   washington state ferries  Full Reporter             $16215777.00
# 213   washington state ferries  Full Reporter             $11132493.00
# 364   washington state ferries  Full Reporter             $11750411.00
# 397   washington state ferries  Full Reporter             $22400732.00
# 604   washington state ferries  Full Reporter             $17715787.00
# 634   washington state ferries  Full Reporter            $236320045.00
# 653   washington state ferries  Full Reporter            $184425025.00
# 684   washington state ferries  Full Reporter            $186344635.00
# 915   washington state ferries  Full Reporter            $236711555.00
# 1114  washington state ferries  Full Reporter             $23046740.00

# %%
frame.loc[endsWithFerries,'Agency']
# Out:
# 199     washington state ferries
# 213     washington state ferries
# 364     washington state ferries
# 397     washington state ferries
# 604     washington state ferries
# 634     washington state ferries
# 653     washington state ferries
# 684     washington state ferries
# 915     washington state ferries
# 1114    washington state ferries
# Name: Agency, dtype: object

# %%
frame.set_index('Agency',inplace=True)

# %%
frame.index = frame.index.str.strip().str.upper()

# %%
frame.head()
# Out:
#                                         Reporter Type Total Operating Expenses
# Agency
# WASHINGTON COUNTY COMMISSIONERS      Reduced Reporter               $122524.00
# WASHINGTON COUNTY COMMISSIONERS      Reduced Reporter               $272715.00
# TEXOMA AREA PARATRANSIT SYSTEM, INC     Full Reporter                 $7295.00
# KALISPEL TRIBE OF INDIANS            Reduced Reporter                $37416.00
# KALISPEL TRIBE OF INDIANS            Reduced Reporter               $345789.00

# %%
frame['Reporter Type'].str.split(' ', expand=True).head()
# Out:
#                                            0         1
# Agency
# WASHINGTON COUNTY COMMISSIONERS      Reduced  Reporter
# WASHINGTON COUNTY COMMISSIONERS      Reduced  Reporter
# TEXOMA AREA PARATRANSIT SYSTEM, INC     Full  Reporter
# KALISPEL TRIBE OF INDIANS            Reduced  Reporter
# KALISPEL TRIBE OF INDIANS            Reduced  Reporter

# %%
frame[['ReporterType1','ReporterType2']] = frame['Reporter Type'].str.split(' ', expand=True)

# %%
frame.head()
# Out:
#                                         Reporter Type  \
# Agency
# WASHINGTON COUNTY COMMISSIONERS      Reduced Reporter
# WASHINGTON COUNTY COMMISSIONERS      Reduced Reporter
# TEXOMA AREA PARATRANSIT SYSTEM, INC     Full Reporter
# KALISPEL TRIBE OF INDIANS            Reduced Reporter
# KALISPEL TRIBE OF INDIANS            Reduced Reporter
#
#                                     Total Operating Expenses ReporterType1  \
# Agency
# WASHINGTON COUNTY COMMISSIONERS                   $122524.00       Reduced
# WASHINGTON COUNTY COMMISSIONERS                   $272715.00       Reduced
# TEXOMA AREA PARATRANSIT SYSTEM, INC                 $7295.00          Full
# KALISPEL TRIBE OF INDIANS                          $37416.00       Reduced
# KALISPEL TRIBE OF INDIANS                         $345789.00       Reduced
#
#                                     ReporterType2
# Agency
# WASHINGTON COUNTY COMMISSIONERS          Reporter
# WASHINGTON COUNTY COMMISSIONERS          Reporter
# ...

# %%
frame['Agency2'] = frame.index

# %%
frame.head()
# Out:
#                                         Reporter Type  \
# Agency
# WASHINGTON COUNTY COMMISSIONERS      Reduced Reporter
# WASHINGTON COUNTY COMMISSIONERS      Reduced Reporter
# TEXOMA AREA PARATRANSIT SYSTEM, INC     Full Reporter
# KALISPEL TRIBE OF INDIANS            Reduced Reporter
# KALISPEL TRIBE OF INDIANS            Reduced Reporter
#
#                                     Total Operating Expenses ReporterType1  \
# Agency
# WASHINGTON COUNTY COMMISSIONERS                   $122524.00       Reduced
# WASHINGTON COUNTY COMMISSIONERS                   $272715.00       Reduced
# TEXOMA AREA PARATRANSIT SYSTEM, INC                 $7295.00          Full
# KALISPEL TRIBE OF INDIANS                          $37416.00       Reduced
# KALISPEL TRIBE OF INDIANS                         $345789.00       Reduced
#
#                                     ReporterType2  \
# Agency
# WASHINGTON COUNTY COMMISSIONERS          Reporter
# WASHINGTON COUNTY COMMISSIONERS          Reporter
# ...

# %%
frame['Agency2'].str.split(' ',expand=True,n=10).head()
# Out:
#                                              0       1              2   \
# Agency
# WASHINGTON COUNTY COMMISSIONERS      WASHINGTON  COUNTY  COMMISSIONERS
# WASHINGTON COUNTY COMMISSIONERS      WASHINGTON  COUNTY  COMMISSIONERS
# TEXOMA AREA PARATRANSIT SYSTEM, INC      TEXOMA    AREA    PARATRANSIT
# KALISPEL TRIBE OF INDIANS              KALISPEL   TRIBE             OF
# KALISPEL TRIBE OF INDIANS              KALISPEL   TRIBE             OF
#
#                                           3     4     5     6     7     8   \
# Agency
# WASHINGTON COUNTY COMMISSIONERS         None  None  None  None  None  None
# WASHINGTON COUNTY COMMISSIONERS         None  None  None  None  None  None
# TEXOMA AREA PARATRANSIT SYSTEM, INC  SYSTEM,   INC  None  None  None  None
# KALISPEL TRIBE OF INDIANS            INDIANS  None  None  None  None  None
# KALISPEL TRIBE OF INDIANS            INDIANS  None  None  None  None  None
#
#                                        9     10
# Agency
# ...

# %%
def getComment(row):
    reporterType=row['Reporter Type']
    cost = float(row['Total Operating Expenses'].replace('$',''))
    
    if cost>200000:
        comment = 'CLASS A'
    else:
        comment = 'CLASS B'
    return reporterType+'/'+comment

# %%
frame.apply(getComment, axis=1)
# Out:
# Agency
# WASHINGTON COUNTY COMMISSIONERS        Reduced Reporter/CLASS B
# WASHINGTON COUNTY COMMISSIONERS        Reduced Reporter/CLASS A
# TEXOMA AREA PARATRANSIT SYSTEM, INC       Full Reporter/CLASS B
# KALISPEL TRIBE OF INDIANS              Reduced Reporter/CLASS B
# KALISPEL TRIBE OF INDIANS              Reduced Reporter/CLASS A
#                                                  ...
# CEDAR AREA TRANSPORTATION SERVICE        Rural Reporter/CLASS B
# TEHAMA COUNTY                            Rural Reporter/CLASS B
# CITY OF DIXON                            Rural Reporter/CLASS A
# MORONGO BASIN TRANSIT AUTHORITY          Rural Reporter/CLASS A
# CITY OF ARVIN                            Rural Reporter/CLASS B
# Length: 17844, dtype: object

# %%
frame.head()
# Out:
#                                         Reporter Type  \
# Agency
# WASHINGTON COUNTY COMMISSIONERS      Reduced Reporter
# WASHINGTON COUNTY COMMISSIONERS      Reduced Reporter
# TEXOMA AREA PARATRANSIT SYSTEM, INC     Full Reporter
# KALISPEL TRIBE OF INDIANS            Reduced Reporter
# KALISPEL TRIBE OF INDIANS            Reduced Reporter
#
#                                     Total Operating Expenses ReporterType1  \
# Agency
# WASHINGTON COUNTY COMMISSIONERS                   $122524.00       Reduced
# WASHINGTON COUNTY COMMISSIONERS                   $272715.00       Reduced
# TEXOMA AREA PARATRANSIT SYSTEM, INC                 $7295.00          Full
# KALISPEL TRIBE OF INDIANS                          $37416.00       Reduced
# KALISPEL TRIBE OF INDIANS                         $345789.00       Reduced
#
#                                     ReporterType2  \
# Agency
# WASHINGTON COUNTY COMMISSIONERS          Reporter
# WASHINGTON COUNTY COMMISSIONERS          Reporter
# ...

# %%
fortune = pd.read_csv('F:/PandasUdemy/course-files/Fortune_500_2017.csv',usecols=['Rank','Title','Industry','Hqlocation','Sector'])

# %%
fortune.head()
# Out:
#    Rank               Title       Sector  \
# 0     1             Walmart    Retailing
# 1     2  Berkshire Hathaway   Financials
# 2     3               Apple   Technology
# 3     4         Exxon Mobil       Energy
# 4     5            McKesson  Wholesalers
#
#                                    Industry         Hqlocation
# 0                     General Merchandisers    Bentonville, AR
# 1  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2               Computers, Office Equipment      Cupertino, CA
# 3                        Petroleum Refining         Irving, TX
# 4                  Wholesalers: Health Care  San Francisco, CA

# %%
fortune['Sector'] = fortune['Sector'].str.upper()

# %%
fortune.head()
# Out:
#    Rank               Title       Sector  \
# 0     1             Walmart    RETAILING
# 1     2  Berkshire Hathaway   FINANCIALS
# 2     3               Apple   TECHNOLOGY
# 3     4         Exxon Mobil       ENERGY
# 4     5            McKesson  WHOLESALERS
#
#                                    Industry         Hqlocation
# 0                     General Merchandisers    Bentonville, AR
# 1  Insurance: Property and Casualty (Stock)          Omaha, NE
# 2               Computers, Office Equipment      Cupertino, CA
# 3                        Petroleum Refining         Irving, TX
# 4                  Wholesalers: Health Care  San Francisco, CA

# %%
ContainsComp = fortune['Industry'].str.lower().str.contains('comp')

# %%
fortune[ContainsComp]
# Out:
#      Rank                Title      Sector  \
# 2       3                Apple  TECHNOLOGY
# 27     28            Microsoft  TECHNOLOGY
# 40     41    Dell Technologies  TECHNOLOGY
# 46     47                Intel  TECHNOLOGY
# 60     61                   HP  TECHNOLOGY
# 80     81               Oracle  TECHNOLOGY
# 118   119             Qualcomm  TECHNOLOGY
# 151   152        Jabil Circuit  TECHNOLOGY
# 161   162                Xerox  TECHNOLOGY
# 205   206    Texas Instruments  TECHNOLOGY
# 216   217      Western Digital  TECHNOLOGY
# 225   226    Micron Technology  TECHNOLOGY
# 264   265    Applied Materials  TECHNOLOGY
# 325   326       salesforce.com  TECHNOLOGY
# 386   387               Nvidia  TECHNOLOGY
# 405   406  Activision Blizzard  TECHNOLOGY
# 408   409                  NCR  TECHNOLOGY
# 413   414              Sanmina  TECHNOLOGY
# 439   440         Lam Research  TECHNOLOGY
# 442   443        Adobe Systems  TECHNOLOGY
# 464   465             Symantec  TECHNOLOGY
# ...

# %%
fortune.loc[ContainsComp,'Industry']
# Out:
# 2                         Computers, Office Equipment
# 27                                  Computer Software
# 40                        Computers, Office Equipment
# 46     Semiconductors and Other Electronic Components
# 60                        Computers, Office Equipment
# 80                                  Computer Software
# 118    Semiconductors and Other Electronic Components
# 151    Semiconductors and Other Electronic Components
# 161                              Computer Peripherals
# 205    Semiconductors and Other Electronic Components
# 216                              Computer Peripherals
# 225    Semiconductors and Other Electronic Components
# 264    Semiconductors and Other Electronic Components
# 325                                 Computer Software
# 386    Semiconductors and Other Electronic Components
# 405                                 Computer Software
# 408                       Computers, Office Equipment
# ...

# %%
fortune[['City','State']] = fortune['Hqlocation'].str.split(',', expand=True, n=2)

# %%
fortune.head()
# Out:
#    Rank               Title       Sector  \
# 0     1             Walmart    RETAILING
# 1     2  Berkshire Hathaway   FINANCIALS
# 2     3               Apple   TECHNOLOGY
# 3     4         Exxon Mobil       ENERGY
# 4     5            McKesson  WHOLESALERS
#
#                                    Industry         Hqlocation           City  \
# 0                     General Merchandisers    Bentonville, AR    Bentonville
# 1  Insurance: Property and Casualty (Stock)          Omaha, NE          Omaha
# 2               Computers, Office Equipment      Cupertino, CA      Cupertino
# 3                        Petroleum Refining         Irving, TX         Irving
# 4                  Wholesalers: Health Care  San Francisco, CA  San Francisco
#
#   State
# 0    AR
# 1    NE
# 2    CA
# 3    TX
# 4    CA

# %%
def BuildShortcut(row):
    industry = row['Industry']
    result=''
    for word in industry.split(' '):
        if word[0].isalpha():
            result+=word[0]
    return result

# %%
dict = {'Industry':'Factory Under Newspaper'}

# %%
BuildShortcut(dict)
# Out:
# 'FUN'

# %%
fortune['IndShort'] = fortune.apply(BuildShortcut, axis=1)

# %%
fortune.head()
# Out:
#    Rank               Title       Sector  \
# 0     1             Walmart    RETAILING
# 1     2  Berkshire Hathaway   FINANCIALS
# 2     3               Apple   TECHNOLOGY
# 3     4         Exxon Mobil       ENERGY
# 4     5            McKesson  WHOLESALERS
#
#                                    Industry         Hqlocation           City  \
# 0                     General Merchandisers    Bentonville, AR    Bentonville
# 1  Insurance: Property and Casualty (Stock)          Omaha, NE          Omaha
# 2               Computers, Office Equipment      Cupertino, CA      Cupertino
# 3                        Petroleum Refining         Irving, TX         Irving
# 4                  Wholesalers: Health Care  San Francisco, CA  San Francisco
#
#   State IndShort
# 0    AR       GM
# 1    NE     IPaC
# 2    CA      COE
# 3    TX       PR
# 4    CA      WHC

# %%
frame = pd.read_csv('F:/PandasUdemy/course-files/PublicTransitExpenses.csv', low_memory=False, 
                    usecols=['Agency', 'Reporter Type','Organization Type','Service Area Population','Rail (Y/N)',
                            'Fixed Route (Y/N)','Service Costs','Tires and Tubes','Total Operating Expenses'])

# %%
frame.head()
# Out:
#                                 Agency     Reporter Type Organization Type  \
# 0      Washington County Commissioners  Reduced Reporter               NaN
# 1      Washington County Commissioners  Reduced Reporter               NaN
# 2  Texoma Area Paratransit System, Inc     Full Reporter               NaN
# 3            Kalispel Tribe of Indians  Reduced Reporter             Tribe
# 4            Kalispel Tribe of Indians  Reduced Reporter             Tribe
#
#    Service Area Population Rail (Y/N) Fixed Route (Y/N) Service Costs  \
# 0                      NaN        NaN               NaN         $0.00
# 1                      NaN        NaN               NaN         $0.00
# 2                      NaN        NaN               NaN           NaN
# 3                      NaN          N                 N           NaN
# 4                      NaN          N                 Y           NaN
#
#   Tires and Tubes Total Operating Expenses
# 0           $0.00               $122524.00
# ...

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17844 entries, 0 to 17843
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Agency                    17844 non-null  object
#  1   Reporter Type             17844 non-null  object
#  2   Organization Type         17759 non-null  object
#  3   Service Area Population   14418 non-null  float64
#  4   Rail (Y/N)                17318 non-null  object
#  5   Fixed Route (Y/N)         17318 non-null  object
#  6   Service Costs             10262 non-null  object
#  7   Tires and Tubes           5615 non-null   object
#  8   Total Operating Expenses  17844 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 9.5 MB

# %%
newColNames = {'Reporter Type'            : 'ReporterType',
               'Organization Type'        : 'OrgType',
               'Service Area Population'  : 'Population',
               'Rail (Y/N)'               : 'IsRail',
               'Fixed Route (Y/N)'        : 'IsFixedRoute',
               'Service Costs'            : 'ServiceCost',
               'Tires and Tubes'          : 'TiresTubesCost',
               'Total Operating Expenses' : 'TotalExpenses'}

# %%
frame.rename(columns=newColNames, inplace=True)

# %%
frame.head()
# Out:
#                                 Agency      ReporterType OrgType  Population  \
# 0      Washington County Commissioners  Reduced Reporter     NaN         NaN
# 1      Washington County Commissioners  Reduced Reporter     NaN         NaN
# 2  Texoma Area Paratransit System, Inc     Full Reporter     NaN         NaN
# 3            Kalispel Tribe of Indians  Reduced Reporter   Tribe         NaN
# 4            Kalispel Tribe of Indians  Reduced Reporter   Tribe         NaN
#
#   IsRail IsFixedRoute ServiceCosts TiresTubesCost TotalExpenses
# 0    NaN          NaN        $0.00          $0.00    $122524.00
# 1    NaN          NaN        $0.00          $0.00    $272715.00
# 2    NaN          NaN          NaN            NaN      $7295.00
# 3      N            N          NaN            NaN     $37416.00
# 4      N            Y          NaN            NaN    $345789.00

# %%
frame['ReporterType'].value_counts()
# Out:
# ReporterType
# Full Reporter       13345
# Rural Reporter       3116
# Reduced Reporter     1313
# Separate Service       70
# Name: count, dtype: int64

# %%
frame['ReporterType'].count()
# Out:
# 17844

# %%
frame['ReporterType'].nunique()
# Out:
# 4

# %%
frame['ReporterType']=frame['ReporterType'].astype('category')

# %%
frame['OrgType']=frame['OrgType'].astype('category')

# %%
frame['Agency'] = frame['Agency'].astype('category')

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17844 entries, 0 to 17843
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Agency          17844 non-null  category
#  1   ReporterType    17844 non-null  category
#  2   OrgType         17759 non-null  category
#  3   Population      14418 non-null  float64
#  4   IsRail          17318 non-null  object
#  5   IsFixedRoute    17318 non-null  object
#  6   ServiceCosts    10262 non-null  object
#  7   TiresTubesCost  5615 non-null   object
#  8   TotalExpenses   17844 non-null  object
# dtypes: category(3), float64(1), object(5)
# memory usage: 5.1 MB

# %%
frame['Population'].fillna(value=0, inplace=True)

# %%
frame['Population'] = frame['Population'].astype('int')

# %%
frame[frame['Population']>0].head()
# Out:
#                                  Agency      ReporterType  \
# 71            Reno-Sparks Indian Colony  Reduced Reporter
# 92                    City of Pocatello  Reduced Reporter
# 93   Lee-Russell Council of Governments  Reduced Reporter
# 94    Aiken Area Council on Aging, Inc.  Reduced Reporter
# 101                    City of Lawrence     Full Reporter
#
#                                                OrgType  Population IsRail  \
# 71                                               Tribe        1127      N
# 92   City, County or Local Government Unit or Depar...       81730      N
# 93                   MPO, COG or Other Planning Agency      193194      N
# 94                                Area Agency on Aging      160099      N
# 101                              Consolidated Reporter       87643      N
#
#     IsFixedRoute ServiceCosts TiresTubesCost TotalExpenses
# 71             Y          NaN            NaN    $174810.00
# ...

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17844 entries, 0 to 17843
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Agency          17844 non-null  category
#  1   ReporterType    17844 non-null  category
#  2   OrgType         17759 non-null  category
#  3   Population      17844 non-null  int32
#  4   IsRail          17318 non-null  object
#  5   IsFixedRoute    17318 non-null  object
#  6   ServiceCosts    10262 non-null  object
#  7   TiresTubesCost  5615 non-null   object
#  8   TotalExpenses   17844 non-null  object
# dtypes: category(3), int32(1), object(5)
# memory usage: 5.1 MB

# %%
frame['IsRail'].replace(('Y','N'),(True,False), inplace=True)

# %%
frame.head()
# Out:
#                                 Agency      ReporterType OrgType  Population  \
# 0      Washington County Commissioners  Reduced Reporter     NaN           0
# 1      Washington County Commissioners  Reduced Reporter     NaN           0
# 2  Texoma Area Paratransit System, Inc     Full Reporter     NaN           0
# 3            Kalispel Tribe of Indians  Reduced Reporter   Tribe           0
# 4            Kalispel Tribe of Indians  Reduced Reporter   Tribe           0
#
#   IsRail IsFixedRoute ServiceCosts TiresTubesCost TotalExpenses
# 0    NaN          NaN        $0.00          $0.00    $122524.00
# 1    NaN          NaN        $0.00          $0.00    $272715.00
# 2    NaN          NaN          NaN            NaN      $7295.00
# 3  False            N          NaN            NaN     $37416.00
# 4  False            Y          NaN            NaN    $345789.00

# %%
frame['IsRail'].fillna(False, inplace=True)

# %%
frame['IsRail'] = frame['IsRail'].astype('bool')

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17844 entries, 0 to 17843
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Agency          17844 non-null  category
#  1   ReporterType    17844 non-null  category
#  2   OrgType         17759 non-null  category
#  3   Population      17844 non-null  int32
#  4   IsRail          17844 non-null  bool
#  5   IsFixedRoute    17318 non-null  object
#  6   ServiceCosts    10262 non-null  object
#  7   TiresTubesCost  5615 non-null   object
#  8   TotalExpenses   17844 non-null  object
# dtypes: bool(1), category(3), int32(1), object(4)
# memory usage: 4.1 MB

# %%
frame['IsFixedRoute'].fillna(False, inplace=True)

# %%
frame['IsFixedRoute'] = frame['IsFixedRoute'].astype('bool')

# %%
frame.head()
# Out:
#                                 Agency      ReporterType OrgType  Population  \
# 0      Washington County Commissioners  Reduced Reporter     NaN           0
# 1      Washington County Commissioners  Reduced Reporter     NaN           0
# 2  Texoma Area Paratransit System, Inc     Full Reporter     NaN           0
# 3            Kalispel Tribe of Indians  Reduced Reporter   Tribe           0
# 4            Kalispel Tribe of Indians  Reduced Reporter   Tribe           0
#
#    IsRail  IsFixedRoute ServiceCosts TiresTubesCost TotalExpenses
# 0   False         False        $0.00          $0.00    $122524.00
# 1   False         False        $0.00          $0.00    $272715.00
# 2   False         False          NaN            NaN      $7295.00
# 3   False          True          NaN            NaN     $37416.00
# 4   False          True          NaN            NaN    $345789.00

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17844 entries, 0 to 17843
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Agency          17844 non-null  category
#  1   ReporterType    17844 non-null  category
#  2   OrgType         17759 non-null  category
#  3   Population      17844 non-null  int32
#  4   IsRail          17844 non-null  bool
#  5   IsFixedRoute    17844 non-null  bool
#  6   ServiceCosts    10262 non-null  object
#  7   TiresTubesCost  5615 non-null   object
#  8   TotalExpenses   17844 non-null  object
# dtypes: bool(2), category(3), int32(1), object(3)
# memory usage: 3.2 MB

# %%
frame['ServiceCosts'] = frame['ServiceCosts'].str.replace('$','')

# %%
frame.head()
# Out:
#                                 Agency      ReporterType OrgType  Population  \
# 0      Washington County Commissioners  Reduced Reporter     NaN           0
# 1      Washington County Commissioners  Reduced Reporter     NaN           0
# 2  Texoma Area Paratransit System, Inc     Full Reporter     NaN           0
# 3            Kalispel Tribe of Indians  Reduced Reporter   Tribe           0
# 4            Kalispel Tribe of Indians  Reduced Reporter   Tribe           0
#
#    IsRail  IsFixedRoute ServiceCosts TiresTubesCost TotalExpenses
# 0   False         False         0.00          $0.00    $122524.00
# 1   False         False         0.00          $0.00    $272715.00
# 2   False         False          NaN            NaN      $7295.00
# 3   False          True          NaN            NaN     $37416.00
# 4   False          True          NaN            NaN    $345789.00

# %%
frame['TiresTubesCost'] = frame['TiresTubesCost'].str.replace('$','')

# %%
frame.head()
# Out:
#                                 Agency      ReporterType OrgType  Population  \
# 0      Washington County Commissioners  Reduced Reporter     NaN           0
# 1      Washington County Commissioners  Reduced Reporter     NaN           0
# 2  Texoma Area Paratransit System, Inc     Full Reporter     NaN           0
# 3            Kalispel Tribe of Indians  Reduced Reporter   Tribe           0
# 4            Kalispel Tribe of Indians  Reduced Reporter   Tribe           0
#
#    IsRail  IsFixedRoute ServiceCosts TiresTubesCost TotalExpenses
# 0   False         False         0.00           0.00    $122524.00
# 1   False         False         0.00           0.00    $272715.00
# 2   False         False          NaN            NaN      $7295.00
# 3   False          True          NaN            NaN     $37416.00
# 4   False          True          NaN            NaN    $345789.00

# %%
frame['TotalExpenses'] = frame['TotalExpenses'].str.replace('$','')

# %%
frame.head()
# Out:
#                                 Agency      ReporterType OrgType  Population  \
# 0      Washington County Commissioners  Reduced Reporter     NaN           0
# 1      Washington County Commissioners  Reduced Reporter     NaN           0
# 2  Texoma Area Paratransit System, Inc     Full Reporter     NaN           0
# 3            Kalispel Tribe of Indians  Reduced Reporter   Tribe           0
# 4            Kalispel Tribe of Indians  Reduced Reporter   Tribe           0
#
#    IsRail  IsFixedRoute ServiceCosts TiresTubesCost TotalExpenses
# 0   False         False         0.00           0.00     122524.00
# 1   False         False         0.00           0.00     272715.00
# 2   False         False          NaN            NaN       7295.00
# 3   False          True          NaN            NaN      37416.00
# 4   False          True          NaN            NaN     345789.00

# %%
frame['ServiceCosts'] = frame['ServiceCosts'].astype('float')
frame['TiresTubesCost'] = frame['TiresTubesCost'].astype('float')
frame['TotalExpenses'] = frame['TotalExpenses'].astype('float')

# %%
frame.head()
# Out:
#                                 Agency      ReporterType OrgType  Population  \
# 0      Washington County Commissioners  Reduced Reporter     NaN           0
# 1      Washington County Commissioners  Reduced Reporter     NaN           0
# 2  Texoma Area Paratransit System, Inc     Full Reporter     NaN           0
# 3            Kalispel Tribe of Indians  Reduced Reporter   Tribe           0
# 4            Kalispel Tribe of Indians  Reduced Reporter   Tribe           0
#
#    IsRail  IsFixedRoute  ServiceCosts  TiresTubesCost  TotalExpenses
# 0   False         False           0.0             0.0       122524.0
# 1   False         False           0.0             0.0       272715.0
# 2   False         False           NaN             NaN         7295.0
# 3   False          True           NaN             NaN        37416.0
# 4   False          True           NaN             NaN       345789.0

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17844 entries, 0 to 17843
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Agency          17844 non-null  category
#  1   ReporterType    17844 non-null  category
#  2   OrgType         17759 non-null  category
#  3   Population      17844 non-null  int32
#  4   IsRail          17844 non-null  bool
#  5   IsFixedRoute    17844 non-null  bool
#  6   ServiceCosts    10262 non-null  float64
#  7   TiresTubesCost  5615 non-null   float64
#  8   TotalExpenses   17844 non-null  float64
# dtypes: bool(2), category(3), float64(3), int32(1)
# memory usage: 846.4 KB

# %%
frame['Agency'] = frame['Agency'].str.title().astype('category')

# %%
frame['ReporterType'] = frame['ReporterType'].str.upper().astype('category')

# %%
frame['OrgType'] = frame['OrgType'].str.upper().astype('category')

# %%
frame.head()
# Out:
#                                 Agency      ReporterType OrgType  Population  \
# 0      Washington County Commissioners  REDUCED REPORTER     NaN           0
# 1      Washington County Commissioners  REDUCED REPORTER     NaN           0
# 2  Texoma Area Paratransit System, Inc     FULL REPORTER     NaN           0
# 3            Kalispel Tribe Of Indians  REDUCED REPORTER   TRIBE           0
# 4            Kalispel Tribe Of Indians  REDUCED REPORTER   TRIBE           0
#
#    IsRail  IsFixedRoute  ServiceCosts  TiresTubesCost  TotalExpenses
# 0   False         False           0.0             0.0       122524.0
# 1   False         False           0.0             0.0       272715.0
# 2   False         False           NaN             NaN         7295.0
# 3   False          True           NaN             NaN        37416.0
# 4   False          True           NaN             NaN       345789.0

# %%
frame.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17844 entries, 0 to 17843
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Agency          17844 non-null  category
#  1   ReporterType    17844 non-null  category
#  2   OrgType         17759 non-null  category
#  3   Population      17844 non-null  int32
#  4   IsRail          17844 non-null  bool
#  5   IsFixedRoute    17844 non-null  bool
#  6   ServiceCosts    10262 non-null  float64
#  7   TiresTubesCost  5615 non-null   float64
#  8   TotalExpenses   17844 non-null  float64
# dtypes: bool(2), category(3), float64(3), int32(1)
# memory usage: 846.1 KB

# %%
fb = pd.read_csv('F:/PandasUdemy/course-files/mrbean_facebook_statuses_with_nulls.csv',
                 usecols=["status_message", "status_type", "link_name","num_reactions", "num_shares", "num_likes"])

fb.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   status_message  40 non-null     object
#  1   link_name       56 non-null     object
#  2   status_type     56 non-null     object
#  3   num_reactions   54 non-null     float64
#  4   num_shares      56 non-null     float64
#  5   num_likes       56 non-null     int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 16.1 KB

# %%
len(fb)
# Out:
# 56

# %%
fb['status_type'].nunique()
# Out:
# 3

# %%
fb['status_type'].value_counts()
# Out:
# status_type
# video    32
# photo    22
# link      2
# Name: count, dtype: int64

# %%
fb['status_type']=fb['status_type'].astype('category')

# %%
fb['link_name'].value_counts()
# Out:
# link_name
# Timeline Photos                                                               22
# www.youtube.com                                                                4
# Mr. Bean - Sneezing and Snoozing In Church                                     1
# Mr. Bean - Mystery creature                                                    1
# Mr. Bean - Saxophone Player                                                    1
# Mr. Bean - Elderly people on stairs                                            1
# Rowan Atkinson: I will never wave goodbye to Mr Bean                           1
# Mr. Bean's Happy Moments                                                       1
# Mr. Bean - At the Disco                                                        1
# Mr Bean - Preparing To Go Camping                                              1
# Mr. Bean - Shopping for Towels                                                 1
# ...

# %%
fb['link_name'] = fb['link_name'].astype('category')

# %%
fb.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   status_message  40 non-null     object
#  1   link_name       56 non-null     category
#  2   status_type     56 non-null     category
#  3   num_reactions   54 non-null     float64
#  4   num_shares      56 non-null     float64
#  5   num_likes       56 non-null     int64
# dtypes: category(2), float64(2), int64(1), object(1)
# memory usage: 12.4 KB

# %%
fb.head()
# Out:
#                                       status_message  \
# 0  It's time for Mr Bean and Teddy to get ready f...
# 1                                                NaN
# 2                                                NaN
# 3  Mr Bean is ready to do some shopping but bewar...
# 4                                                NaN
#
#                            link_name status_type  num_reactions  num_shares  \
# 0  Mr Bean - Preparing To Go Camping       video        16570.0       338.0
# 1                    Timeline Photos       photo       119886.0      1657.0
# 2                    Timeline Photos       photo            NaN     10050.0
# 3                    www.youtube.com       video        20913.0       257.0
# 4                    Timeline Photos       photo       223602.0      2228.0
#
#    num_likes
# 0      16079
# 1     114008
# 2     218579
# 3      20338
# 4     215591

# %%
fb['num_reactions'].fillna(0, inplace=True)

# %%
fb['num_shares'].fillna(0, inplace=True)

# %%
fb['num_reactions']=fb['num_reactions'].astype('int')
fb['num_shares']=fb['num_shares'].astype('int')

# %%
fb.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   status_message  40 non-null     object
#  1   link_name       56 non-null     category
#  2   status_type     56 non-null     category
#  3   num_reactions   56 non-null     int32
#  4   num_shares      56 non-null     int32
#  5   num_likes       56 non-null     int64
# dtypes: category(2), int32(2), int64(1), object(1)
# memory usage: 12.0 KB
