# %%
import pandas as pd
import numpy as np

# %%
categories = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/categories1.csv')

# %%
categories.head()
# Out:
#    CategoryID    CategoryName              Description
# 0           1       Beverages              Soft drinks
# 1           2      Condiments  Sweet and savory sauces
# 2           3     Confections                 Desserts
# 3           4  Dairy Products                  Cheeses
# 4           5  Grains/Cereals                   Breads

# %%
products = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/products.csv',
                       usecols=['ProductID', 'ProductName','UnitPrice','Quantity'])

# %%
products.head()
# Out:
#    ProductID                   ProductName  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %%
suppliers = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/suppliers.csv', usecols=['SupplierID','CompanyName','Country'])

# %%
suppliers.head()
# Out:
#    SupplierID                         CompanyName Country
# 0           1                      Exotic Liquids      UK
# 1           2          New Orleans Cajun Delights     USA
# 2           3           Grandma Kelly's Homestead     USA
# 3           4                       Tokyo Traders   Japan
# 4           5  Cooperativa de Quesos 'Las Cabras'   Spain

# %%
customers = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/customers.csv', usecols=['CustomerID','CompanyName','Country'])

# %%
customers.head()
# Out:
#   CustomerID                         CompanyName  Country
# 0      ALFKI                 Alfreds Futterkiste  Germany
# 1      ANATR  Ana Trujillo Emparedados y helados   Mexico
# 2      ANTON            Antonio Moreno Taquer?­a   Mexico
# 3      AROUT                     Around the Horn       UK
# 4      BERGS                 Berglunds snabbk?¶p   Sweden

# %%
len(suppliers)
# Out:
# 29

# %%
len(customers)
# Out:
# 91

# %%
df_joined = pd.concat([suppliers, customers], ignore_index=True)

# %%
df_joined
# Out:
#      SupplierID                         CompanyName  Country CustomerID
# 0           1.0                      Exotic Liquids       UK        NaN
# 1           2.0          New Orleans Cajun Delights      USA        NaN
# 2           3.0           Grandma Kelly's Homestead      USA        NaN
# 3           4.0                       Tokyo Traders    Japan        NaN
# 4           5.0  Cooperativa de Quesos 'Las Cabras'    Spain        NaN
# ..          ...                                 ...      ...        ...
# 115         NaN                      Wartian Herkku  Finland      WARTH
# 116         NaN              Wellington Importadora   Brazil      WELLI
# 117         NaN                White Clover Markets      USA      WHITC
# 118         NaN                         Wilman Kala  Finland      WILMK
# 119         NaN                      Wolski  Zajazd   Poland      WOLZA
#
# [120 rows x 4 columns]

# %%
len(df_joined)
# Out:
# 120

# %%
customers2= customers.copy()

# %%
customers2.head()
# Out:
#   CustomerID                         CompanyName  Country
# 0      ALFKI                 Alfreds Futterkiste  Germany
# 1      ANATR  Ana Trujillo Emparedados y helados   Mexico
# 2      ANTON            Antonio Moreno Taquer?­a   Mexico
# 3      AROUT                     Around the Horn       UK
# 4      BERGS                 Berglunds snabbk?¶p   Sweden

# %%
customers2.rename(columns={'CustomerID':'SupplierID'}, inplace=True)

# %%
df_joined = pd.concat([suppliers, customers2], ignore_index=True)

# %%
df_joined
# Out:
#     SupplierID                         CompanyName  Country
# 0            1                      Exotic Liquids       UK
# 1            2          New Orleans Cajun Delights      USA
# 2            3           Grandma Kelly's Homestead      USA
# 3            4                       Tokyo Traders    Japan
# 4            5  Cooperativa de Quesos 'Las Cabras'    Spain
# ..         ...                                 ...      ...
# 115      WARTH                      Wartian Herkku  Finland
# 116      WELLI              Wellington Importadora   Brazil
# 117      WHITC                White Clover Markets      USA
# 118      WILMK                         Wilman Kala  Finland
# 119      WOLZA                      Wolski  Zajazd   Poland
#
# [120 rows x 3 columns]

# %%
concated = pd.concat([suppliers, customers], ignore_index=True)

# %%
concated.head(40)
# Out:
#     SupplierID                             CompanyName      Country CustomerID
# 0          1.0                          Exotic Liquids           UK        NaN
# 1          2.0              New Orleans Cajun Delights          USA        NaN
# 2          3.0               Grandma Kelly's Homestead          USA        NaN
# 3          4.0                           Tokyo Traders        Japan        NaN
# 4          5.0      Cooperativa de Quesos 'Las Cabras'        Spain        NaN
# 5          6.0                                Mayumi's        Japan        NaN
# 6          7.0                            Pavlova Ltd.    Australia        NaN
# 7          8.0                 Specialty Biscuits Ltd.           UK        NaN
# 8          9.0                        PB Knäckebröd AB       Sweden        NaN
# 9         10.0               Refrescos Americanas LTDA       Brazil        NaN
# 10        11.0             Heli Süßwaren GmbH & Co. KG      Germany        NaN
# ...

# %%
prod_1 = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/products.csv', 
                     usecols=['ProductID', 'ProductName'], index_col='ProductID')

# %%
prod_2 = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/products.csv', 
                     usecols=['ProductID', 'UnitPrice','UnitsInStock'], index_col='ProductID')

# %%
prod_1.head()
# Out:
#                             ProductName
# ProductID
# 1                                  Chai
# 2                                 Chang
# 3                         Aniseed Syrup
# 4          Chef Anton's Cajun Seasoning
# 5                Chef Anton's Gumbo Mix

# %%
prod_2.head()
# Out:
#            UnitPrice  UnitsInStock
# ProductID
# 1              18.00            39
# 2              19.00            17
# 3              10.00            13
# 4              22.00            53
# 5              21.35             0

# %%
prod_1.join(prod_2)
# Out:
#                                ProductName  UnitPrice  UnitsInStock
# ProductID
# 1                                     Chai      18.00            39
# 2                                    Chang      19.00            17
# 3                            Aniseed Syrup      10.00            13
# 4             Chef Anton's Cajun Seasoning      22.00            53
# 5                   Chef Anton's Gumbo Mix      21.35             0
# ...                                    ...        ...           ...
# 73                              Röd Kaviar      15.00           101
# 74                           Longlife Tofu      10.00             4
# 75                    Rhönbräu Klosterbier       7.75           125
# 76                            Lakkalikööri      18.00            57
# 77         Original Frankfurter grüne Soße      13.00            32
#
# [77 rows x 3 columns]

# %%
products.head()
# Out:
#    ProductID                   ProductName  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %%
categories.head()
# Out:
#    CategoryID    CategoryName              Description
# 0           1       Beverages              Soft drinks
# 1           2      Condiments  Sweet and savory sauces
# 2           3     Confections                 Desserts
# 3           4  Dairy Products                  Cheeses
# 4           5  Grains/Cereals                   Breads

# %%
categories.set_index('CategoryID', inplace=True)

# %%
categories.head()
# Out:
#               CategoryName              Description
# CategoryID
# 1                Beverages              Soft drinks
# 2               Condiments  Sweet and savory sauces
# 3              Confections                 Desserts
# 4           Dairy Products                  Cheeses
# 5           Grains/Cereals                   Breads

# %%
products.join(other=categories, on='CategoryID')
# Out:
#     ProductID                      ProductName  CategoryID  UnitPrice  \
# 0           1                             Chai           1      18.00
# 1           2                            Chang           1      19.00
# 2           3                    Aniseed Syrup           2      10.00
# 3           4     Chef Anton's Cajun Seasoning           2      22.00
# 4           5           Chef Anton's Gumbo Mix           2      21.35
# ..        ...                              ...         ...        ...
# 72         73                       Röd Kaviar           8      15.00
# 73         74                    Longlife Tofu           7      10.00
# 74         75             Rhönbräu Klosterbier           1       7.75
# 75         76                     Lakkalikööri           1      18.00
# 76         77  Original Frankfurter grüne Soße           2      13.00
#
#    CategoryName                Description
# 0     Beverages                Soft drinks
# ...

# %%
cnames = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/customers.csv', 
                     usecols=['CustomerID', 'CompanyName'], index_col='CustomerID')

# %%
ccities = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/customers.csv', 
                     usecols=['CustomerID', 'City', 'Country'], index_col='CustomerID')

# %%
len(cnames)
# Out:
# 91

# %%
len(ccities)
# Out:
# 91

# %%
cnames.join(ccities)
# Out:
#                                    CompanyName          City  Country
# CustomerID
# ALFKI                      Alfreds Futterkiste        Berlin  Germany
# ANATR       Ana Trujillo Emparedados y helados  M?©xico D.F.   Mexico
# ANTON                 Antonio Moreno Taquer?­a  M?©xico D.F.   Mexico
# AROUT                          Around the Horn        London       UK
# BERGS                      Berglunds snabbk?¶p        Lule??   Sweden
# ...                                        ...           ...      ...
# WARTH                           Wartian Herkku          Oulu  Finland
# WELLI                   Wellington Importadora       Resende   Brazil
# WHITC                     White Clover Markets       Seattle      USA
# WILMK                              Wilman Kala      Helsinki  Finland
# WOLZA                           Wolski  Zajazd      Warszawa   Poland
#
# [91 rows x 3 columns]

# %%
cnames.reset_index(inplace=True)

# %%
cnames.head()
# Out:
#   CustomerID                         CompanyName
# 0      ALFKI                 Alfreds Futterkiste
# 1      ANATR  Ana Trujillo Emparedados y helados
# 2      ANTON            Antonio Moreno Taquer?­a
# 3      AROUT                     Around the Horn
# 4      BERGS                 Berglunds snabbk?¶p

# %%
cnames.join(ccities,on = 'CustomerID')
# Out:
#    CustomerID                         CompanyName          City  Country
# 0       ALFKI                 Alfreds Futterkiste        Berlin  Germany
# 1       ANATR  Ana Trujillo Emparedados y helados  M?©xico D.F.   Mexico
# 2       ANTON            Antonio Moreno Taquer?­a  M?©xico D.F.   Mexico
# 3       AROUT                     Around the Horn        London       UK
# 4       BERGS                 Berglunds snabbk?¶p        Lule??   Sweden
# ..        ...                                 ...           ...      ...
# 86      WARTH                      Wartian Herkku          Oulu  Finland
# 87      WELLI              Wellington Importadora       Resende   Brazil
# 88      WHITC                White Clover Markets       Seattle      USA
# 89      WILMK                         Wilman Kala      Helsinki  Finland
# 90      WOLZA                      Wolski  Zajazd      Warszawa   Poland
#
# [91 rows x 4 columns]

# %%
cat1 = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/categories_del_1.csv', usecols=['CategoryID','CategoryName'])

# %%
cat2 = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/categories_del_2.csv', usecols=['CategoryID','CategoryName'])

# %%
cat1.head()
# Out:
#    CategoryID    CategoryName
# 0           2      Condiments
# 1           3     Confections
# 2           4  Dairy Products
# 3           5  Grains/Cereals
# 4           6    Meat/Poultry

# %%
cat2.head()
# Out:
#    CategoryID    CategoryName
# 0           1       Beverages
# 1           2      Condiments
# 2           3     Confections
# 3           4  Dairy Products
# 4           7         Produce

# %%
cat1.merge(cat2, on='CategoryID', suffixes=['_1', '_2'], how='outer', indicator=True)
# Out:
#    CategoryID  CategoryName_1  CategoryName_2      _merge
# 0           2      Condiments      Condiments        both
# 1           3     Confections     Confections        both
# 2           4  Dairy Products  Dairy Products        both
# 3           5  Grains/Cereals             NaN   left_only
# 4           6    Meat/Poultry             NaN   left_only
# 5           7         Produce         Produce        both
# 6           8         Seafood         Seafood        both
# 7           1             NaN       Beverages  right_only

# %%
cat_merged = cat1.merge(cat2, on='CategoryID', suffixes=['_1', '_2'], how='outer', indicator=True)

# %%
cat_merged['_merge'] == 'left_only'
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# Name: _merge, dtype: bool

# %%
cat_merged[cat_merged['_merge'] == 'left_only']
# Out:
#    CategoryID  CategoryName_1 CategoryName_2     _merge
# 3           5  Grains/Cereals            NaN  left_only
# 4           6    Meat/Poultry            NaN  left_only

# %%
f_2015 = pd.read_csv('F:/PandasUdemy/course-files/Fortune_500_2015.csv', 
                     usecols=['rank','company'])

# %%
f_2016 = pd.read_csv('F:/PandasUdemy/course-files/Fortune_500_2016.csv', 
                     usecols=['rank','company'])

# %%
f_merged = f_2015.merge(f_2016, indicator=True, how='outer', on='company', suffixes=[' 2015',' 2016'])

# %%
filter_left = f_merged['_merge'] == 'left_only'

# %%
f_merged[filter_left]
# Out:
#      rank 2015                              company  rank 2016     _merge
# 83        84.0                              Safeway        NaN  left_only
# 94        95.0                              DirecTV        NaN  left_only
# 124      125.0                                Alcoa        NaN  left_only
# 164      165.0                                Kraft        NaN  left_only
# 174      175.0              TRW Automotive Holdings        NaN  left_only
# 214      215.0                                Chubb        NaN  left_only
# 271      272.0                           H.J. Heinz        NaN  left_only
# 280      281.0                 Family Dollar Stores        NaN  left_only
# 327      328.0                Caesars Entertainment        NaN  left_only
# 349      350.0                           Murphy Oil        NaN  left_only
# 367      368.0                Coca-Cola Enterprises        NaN  left_only
# 372      373.0                     Blackstone Group        NaN  left_only
# ...

# %%
filter_both = f_merged['_merge'] == 'both'

# %%
f_merged[filter_both]
# Out:
#      rank 2015                company  rank 2016 _merge
# 0          1.0                Walmart        1.0   both
# 1          2.0            Exxon Mobil        2.0   both
# 2          3.0                Chevron       14.0   both
# 3          4.0     Berkshire Hathaway        4.0   both
# 4          5.0                  Apple        3.0   both
# ..         ...                    ...        ...    ...
# 492      493.0    Insight Enterprises      474.0   both
# 493      494.0  Alliance Data Systems      404.0   both
# 494      495.0       LifePoint Health      430.0   both
# 496      497.0      Wyndham Worldwide      466.0   both
# 497      498.0          Owens Corning      480.0   both
#
# [466 rows x 4 columns]

# %%
 companies_2015_2016 = f_merged[filter_both]

# %%
 companies_2015_2016
# Out:
#      rank 2015                company  rank 2016 _merge
# 0          1.0                Walmart        1.0   both
# 1          2.0            Exxon Mobil        2.0   both
# 2          3.0                Chevron       14.0   both
# 3          4.0     Berkshire Hathaway        4.0   both
# 4          5.0                  Apple        3.0   both
# ..         ...                    ...        ...    ...
# 492      493.0    Insight Enterprises      474.0   both
# 493      494.0  Alliance Data Systems      404.0   both
# 494      495.0       LifePoint Health      430.0   both
# 496      497.0      Wyndham Worldwide      466.0   both
# 497      498.0          Owens Corning      480.0   both
#
# [466 rows x 4 columns]

# %%
products = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/products.csv',
                       usecols=['ProductID', 'ProductName'])

# %%
ordered_prod = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/order-details_del.csv',
                       usecols=['OrderID', 'ProductID','UnitPrice','Quantity'])

# %%
products.head()
# Out:
#    ProductID                   ProductName
# 0          1                          Chai
# 1          2                         Chang
# 2          3                 Aniseed Syrup
# 3          4  Chef Anton's Cajun Seasoning
# 4          5        Chef Anton's Gumbo Mix

# %%
ordered_prod.head()
# Out:
#    OrderID  ProductID  UnitPrice  Quantity
# 0    10331         54        5.9        15
# 1    10332         18       50.0        40
# 2    10332         42       11.2        10
# 3    10332         47        7.6        16
# 4    10333         14       18.6        10

# %%
merged = products.merge(right=ordered_prod, on='ProductID', how ='outer', indicator=True)

# %%
merged
# Out:
#      ProductID                      ProductName  OrderID  UnitPrice  Quantity  \
# 0            1                             Chai  10348.0       14.4      15.0
# 1            1                             Chai  10354.0       14.4      12.0
# 2            1                             Chai  10370.0       14.4      15.0
# 3            1                             Chai  10406.0       14.4      10.0
# 4            1                             Chai  10413.0       14.4      24.0
# ..         ...                              ...      ...        ...       ...
# 289         77  Original Frankfurter grüne Soße  10366.0       10.4       5.0
# 290         77  Original Frankfurter grüne Soße  10367.0       10.4       7.0
# 291         77  Original Frankfurter grüne Soße  10399.0       10.4      14.0
# 292         77  Original Frankfurter grüne Soße  10417.0       10.4      35.0
# 293         77  Original Frankfurter grüne Soße  10421.0       10.4      10.0
#
#     _merge
# 0     both
# ...

# %%
filter = merged['_merge']=='left_only'

# %%
merged[filter]
# Out:
#      ProductID                   ProductName  OrderID  UnitPrice  Quantity  \
# 16           6  Grandma's Boysenberry Spread      NaN        NaN       NaN
# 38          15                  Genen Shouyu      NaN        NaN       NaN
# 85          27            Schoggi Schokolade      NaN        NaN       NaN
# 242         66     Louisiana Hot Spiced Okra      NaN        NaN       NaN
# 243         67     Laughing Lumberjack Lager      NaN        NaN       NaN
#
#         _merge
# 16   left_only
# 38   left_only
# 85   left_only
# 242  left_only
# 243  left_only

# %%
merged['_merge'].value_counts()
# Out:
# _merge
# both          289
# left_only       5
# right_only      0
# Name: count, dtype: int64

# %%
suppliers = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/suppliers _del_1.csv',
                       usecols=['SupplierID','CompanyName', 'City'])

# %%
products = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/products_del_1.csv',
                       usecols=['ProductID','ProductName', 'SupplierID'])

# %%
prod_and_sup = products.merge(right=suppliers, how ='inner', indicator=True)

# %%
prod_and_sup
# Out:
#     ProductID                   ProductName  SupplierID  \
# 0           1                          Chai           1
# 1           2                         Chang           1
# 2           3                 Aniseed Syrup           1
# 3           4  Chef Anton's Cajun Seasoning           2
# 4           5        Chef Anton's Gumbo Mix           2
# ..        ...                           ...         ...
# 65         56        Gnocchi di nonna Alice          26
# 66         57                Ravioli Angelo          26
# 67         60             Camembert Pierrot          28
# 68         61                Sirop d'érable          29
# 69         62                Tarte au sucre          29
#
#                    CompanyName           City _merge
# 0               Exotic Liquids         London   both
# 1               Exotic Liquids         London   both
# 2               Exotic Liquids         London   both
# 3   New Orleans Cajun Delights    New Orleans   both
# ...

# %%
prod_and_sup['_merge'].value_counts()
# Out:
# _merge
# both          70
# left_only      0
# right_only     0
# Name: count, dtype: int64

# %%
len(products)
# Out:
# 75

# %%
len(prod_and_sup)
# Out:
# 70

# %%
outer = products.merge(right=suppliers, how ='outer', indicator=True)

# %%
outer[outer['_merge'] == 'left_only']
# Out:
#     ProductID          ProductName  SupplierID CompanyName City     _merge
# 27       22.0  Gustaf's Knäckebröd           9         NaN  NaN  left_only
# 28       23.0             Tunnbröd           9         NaN  NaN  left_only
# 48       36.0          Inlagd Sill          17         NaN  NaN  left_only
# 49       37.0           Gravad lax          17         NaN  NaN  left_only
# 50       73.0           Röd Kaviar          17         NaN  NaN  left_only

# %%
outer[outer['_merge'] == 'right_only']
# Out:
#     ProductID ProductName  SupplierID         CompanyName      City  \
# 75        NaN         NaN          27  Escargots Nouveaux  Montceau
#
#         _merge
# 75  right_only

# %%
products.head()
# Out:
#    ProductID                   ProductName
# 0          1                          Chai
# 1          2                         Chang
# 2          3                 Aniseed Syrup
# 3          4  Chef Anton's Cajun Seasoning
# 4          5        Chef Anton's Gumbo Mix

# %%
ordered_prod.head()
# Out:
#    OrderID  ProductID  UnitPrice  Quantity
# 0    10331         54        5.9        15
# 1    10332         18       50.0        40
# 2    10332         42       11.2        10
# 3    10332         47        7.6        16
# 4    10333         14       18.6        10

# %%
mergedl = products.merge(right=ordered_prod, on='ProductID', how='left', indicator=True)

# %%
mergedl['_merge'].value_counts()
# Out:
# _merge
# both          289
# left_only       5
# right_only      0
# Name: count, dtype: int64

# %%
mergedr = products.merge(right=ordered_prod, on='ProductID', how='right', indicator=True)

# %%
mergedr['_merge'].value_counts()
# Out:
# _merge
# both          289
# left_only       0
# right_only      0
# Name: count, dtype: int64

# %%
suppliers = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/suppliers.csv',
                       usecols=['SupplierID','CompanyName', 'City'])

# %%
products = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/products_del_2.csv',
                       usecols=['ProductID','ProductName', 'SupplierID'])

# %%
sup_prod = suppliers.merge(right=products, on='SupplierID', how='left', indicator=True)

# %%
sup_prod[sup_prod['_merge']=='left_only']
# Out:
#     SupplierID                 CompanyName         City  ProductID  \
# 2            2  New Orleans Cajun Delights  New Orleans        NaN
# 67          27          Escargots Nouveaux     Montceau        NaN
#
#    ProductName     _merge
# 2          NaN  left_only
# 67         NaN  left_only

# %%
len(suppliers)
# Out:
# 29

# %%
len(products)
# Out:
# 68

# %%
len(sup_prod)
# Out:
# 70

# %%
products = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/products.csv',
                       usecols=['ProductID','ProductName', 'CategoryID','UnitPrice'])

# %%
categories = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/categories1.csv',
                       usecols=['CategoryID','CategoryName', 'Description'])

# %%
products.head()
# Out:
#    ProductID                   ProductName  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %%
categories.head()
# Out:
#    CategoryID    CategoryName              Description
# 0           1       Beverages              Soft drinks
# 1           2      Condiments  Sweet and savory sauces
# 2           3     Confections                 Desserts
# 3           4  Dairy Products                  Cheeses
# 4           5  Grains/Cereals                   Breads

# %%
cat_prod = products.merge(right=categories, on='CategoryID')

# %%
cat_prod
# Out:
#     ProductID                    ProductName  CategoryID  UnitPrice  \
# 0           1                           Chai           1      18.00
# 1           2                          Chang           1      19.00
# 2          24             Guaraná Fantástica           1       4.50
# 3          34                  Sasquatch Ale           1      14.00
# 4          35                 Steeleye Stout           1      18.00
# ..        ...                            ...         ...        ...
# 72         42  Singaporean Hokkien Fried Mee           5      14.00
# 73         52                       Filo Mix           5       7.00
# 74         56         Gnocchi di nonna Alice           5      38.00
# 75         57                 Ravioli Angelo           5      19.50
# 76         64      Wimmers gute Semmelknödel           5      33.25
#
#       CategoryName  Description
# 0        Beverages  Soft drinks
# 1        Beverages  Soft drinks
# 2        Beverages  Soft drinks
# ...

# %%
categories.rename({'CategoryID': 'ID'}, axis='columns', inplace=True)

# %%
cat_prod = products.merge(right=categories, left_on='CategoryID', right_on='ID')

# %%
cat_prod
# Out:
#     ProductID                    ProductName  CategoryID  UnitPrice  ID  \
# 0           1                           Chai           1      18.00   1
# 1           2                          Chang           1      19.00   1
# 2          24             Guaraná Fantástica           1       4.50   1
# 3          34                  Sasquatch Ale           1      14.00   1
# 4          35                 Steeleye Stout           1      18.00   1
# ..        ...                            ...         ...        ...  ..
# 72         42  Singaporean Hokkien Fried Mee           5      14.00   5
# 73         52                       Filo Mix           5       7.00   5
# 74         56         Gnocchi di nonna Alice           5      38.00   5
# 75         57                 Ravioli Angelo           5      19.50   5
# 76         64      Wimmers gute Semmelknödel           5      33.25   5
#
#       CategoryName  Description
# 0        Beverages  Soft drinks
# 1        Beverages  Soft drinks
# ...

# %%
products.rename({'ProductName':'Name'}, axis='columns', inplace=True)

# %%
categories.rename({'CategoryName':'Name'}, axis='columns', inplace=True)

# %%
products.head()
# Out:
#    ProductID                          Name  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %%
categories.head()
# Out:
#    ID            Name              Description
# 0   1       Beverages              Soft drinks
# 1   2      Condiments  Sweet and savory sauces
# 2   3     Confections                 Desserts
# 3   4  Dairy Products                  Cheeses
# 4   5  Grains/Cereals                   Breads

# %%
products.merge(right=categories, left_on='CategoryID', right_on='ID', suffixes=['_Prod','_Cat'], sort=True)
# Out:
#     ProductID                        Name_Prod  CategoryID  UnitPrice  ID  \
# 0           1                             Chai           1      18.00   1
# 1           2                            Chang           1      19.00   1
# 2          24               Guaraná Fantástica           1       4.50   1
# 3          34                    Sasquatch Ale           1      14.00   1
# 4          35                   Steeleye Stout           1      18.00   1
# ..        ...                              ...         ...        ...  ..
# 72         41  Jack's New England Clam Chowder           8       9.65   8
# 73         45                      Rogede sild           8       9.50   8
# 74         46                        Spegesild           8      12.00   8
# 75         58           Escargots de Bourgogne           8      13.25   8
# 76         73                       Röd Kaviar           8      15.00   8
#
#      Name_Cat       Description
# 0   Beverages       Soft drinks
# ...

# %%
categories.head()
# Out:
#    ID            Name              Description
# 0   1       Beverages              Soft drinks
# 1   2      Condiments  Sweet and savory sauces
# 2   3     Confections                 Desserts
# 3   4  Dairy Products                  Cheeses
# 4   5  Grains/Cereals                   Breads

# %%
categories.set_index('ID', inplace=True)

# %%
categories.head()
# Out:
#               Name              Description
# ID
# 1        Beverages              Soft drinks
# 2       Condiments  Sweet and savory sauces
# 3      Confections                 Desserts
# 4   Dairy Products                  Cheeses
# 5   Grains/Cereals                   Breads

# %%
products.merge(right=categories, left_on='CategoryID', right_on='ID', suffixes=['_Prod','_Cat'], right_index=True)
# Out:
#     ProductID                      Name_Prod  CategoryID  UnitPrice  \
# 0           1                           Chai           1      18.00
# 1           2                          Chang           1      19.00
# 23         24             Guaraná Fantástica           1       4.50
# 33         34                  Sasquatch Ale           1      14.00
# 34         35                 Steeleye Stout           1      18.00
# ..        ...                            ...         ...        ...
# 41         42  Singaporean Hokkien Fried Mee           5      14.00
# 51         52                       Filo Mix           5       7.00
# 55         56         Gnocchi di nonna Alice           5      38.00
# 56         57                 Ravioli Angelo           5      19.50
# 63         64      Wimmers gute Semmelknödel           5      33.25
#
#           Name_Cat  Description
# 0        Beverages  Soft drinks
# 1        Beverages  Soft drinks
# 23       Beverages  Soft drinks
# ...

# %%
products = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/products.csv',
                       usecols=['ProductID','ProductName', 'SupplierID'])

# %%
suppliers = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/suppliers.csv',
                       usecols=['City','CompanyName', 'SupplierID'])

# %%
suppliers.merge(right=products, how='inner', on='SupplierID')
# Out:
#     SupplierID                 CompanyName           City  ProductID  \
# 0            1              Exotic Liquids         London          1
# 1            1              Exotic Liquids         London          2
# 2            1              Exotic Liquids         London          3
# 3            2  New Orleans Cajun Delights    New Orleans          4
# 4            2  New Orleans Cajun Delights    New Orleans          5
# ..         ...                         ...            ...        ...
# 72          27          Escargots Nouveaux       Montceau         58
# 73          28                Gai pâturage         Annecy         59
# 74          28                Gai pâturage         Annecy         60
# 75          29            Forêts d'érables  Ste-Hyacinthe         61
# 76          29            Forêts d'érables  Ste-Hyacinthe         62
#
#                      ProductName
# 0                           Chai
# 1                          Chang
# 2                  Aniseed Syrup
# ...

# %%
suppliers.set_index('SupplierID', inplace=True)

# %%
suppliers.merge(right=products, how='inner', left_index=True, right_on='SupplierID')
# Out:
#                    CompanyName           City  ProductID  \
# 0               Exotic Liquids         London          1
# 1               Exotic Liquids         London          2
# 2               Exotic Liquids         London          3
# 3   New Orleans Cajun Delights    New Orleans          4
# 4   New Orleans Cajun Delights    New Orleans          5
# ..                         ...            ...        ...
# 57          Escargots Nouveaux       Montceau         58
# 58                Gai pâturage         Annecy         59
# 59                Gai pâturage         Annecy         60
# 60            Forêts d'érables  Ste-Hyacinthe         61
# 61            Forêts d'érables  Ste-Hyacinthe         62
#
#                      ProductName  SupplierID
# 0                           Chai           1
# 1                          Chang           1
# 2                  Aniseed Syrup           1
# 3   Chef Anton's Cajun Seasoning           2
# 4         Chef Anton's Gumbo Mix           2
# ...

# %%
suppliers.merge(products, left_index=True, right_on='SupplierID')
# Out:
#                    CompanyName           City  ProductID  \
# 0               Exotic Liquids         London          1
# 1               Exotic Liquids         London          2
# 2               Exotic Liquids         London          3
# 3   New Orleans Cajun Delights    New Orleans          4
# 4   New Orleans Cajun Delights    New Orleans          5
# ..                         ...            ...        ...
# 57          Escargots Nouveaux       Montceau         58
# 58                Gai pâturage         Annecy         59
# 59                Gai pâturage         Annecy         60
# 60            Forêts d'érables  Ste-Hyacinthe         61
# 61            Forêts d'érables  Ste-Hyacinthe         62
#
#                      ProductName  SupplierID
# 0                           Chai           1
# 1                          Chang           1
# 2                  Aniseed Syrup           1
# 3   Chef Anton's Cajun Seasoning           2
# 4         Chef Anton's Gumbo Mix           2
# ...

# %%
products = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/products.csv',
                       usecols=['ProductID','ProductName', 'CategoryID', 'UnitPrice'])

# %%
categories = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/categories1.csv',
                       usecols=['CategoryID','CategoryName', 'Description'])

# %%
orders = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/order-details.csv')

# %%
products.head()
# Out:
#    ProductID                   ProductName  CategoryID  UnitPrice
# 0          1                          Chai           1      18.00
# 1          2                         Chang           1      19.00
# 2          3                 Aniseed Syrup           2      10.00
# 3          4  Chef Anton's Cajun Seasoning           2      22.00
# 4          5        Chef Anton's Gumbo Mix           2      21.35

# %%
categories.head()
# Out:
#    CategoryID    CategoryName              Description
# 0           1       Beverages              Soft drinks
# 1           2      Condiments  Sweet and savory sauces
# 2           3     Confections                 Desserts
# 3           4  Dairy Products                  Cheeses
# 4           5  Grains/Cereals                   Breads

# %%
orders.head()
# Out:
#    OrderID  ProductID  UnitPrice  Quantity  Discount
# 0    10248         11       14.0        12       0.0
# 1    10248         42        9.8        10       0.0
# 2    10248         72       34.8         5       0.0
# 3    10249         14       18.6         9       0.0
# 4    10249         51       42.4        40       0.0

# %%
cat_prod = categories.merge(right=products, on='CategoryID')

# %%
cat_prod
# Out:
#     CategoryID CategoryName       Description  ProductID  \
# 0            1    Beverages       Soft drinks          1
# 1            1    Beverages       Soft drinks          2
# 2            1    Beverages       Soft drinks         24
# 3            1    Beverages       Soft drinks         34
# 4            1    Beverages       Soft drinks         35
# ..         ...          ...               ...        ...
# 72           8      Seafood  Seaweed and fish         41
# 73           8      Seafood  Seaweed and fish         45
# 74           8      Seafood  Seaweed and fish         46
# 75           8      Seafood  Seaweed and fish         58
# 76           8      Seafood  Seaweed and fish         73
#
#                         ProductName  UnitPrice
# 0                              Chai      18.00
# 1                             Chang      19.00
# 2                Guaraná Fantástica       4.50
# 3                     Sasquatch Ale      14.00
# ...

# %%
catprod_ord = cat_prod.merge(orders, on='ProductID', suffixes=['_today','_inord'])

# %%
catprod_ord
# Out:
#       CategoryID CategoryName       Description  ProductID ProductName  \
# 0              1    Beverages       Soft drinks          1        Chai
# 1              1    Beverages       Soft drinks          1        Chai
# 2              1    Beverages       Soft drinks          1        Chai
# 3              1    Beverages       Soft drinks          1        Chai
# 4              1    Beverages       Soft drinks          1        Chai
# ...          ...          ...               ...        ...         ...
# 2150           8      Seafood  Seaweed and fish         73  Röd Kaviar
# 2151           8      Seafood  Seaweed and fish         73  Röd Kaviar
# 2152           8      Seafood  Seaweed and fish         73  Röd Kaviar
# 2153           8      Seafood  Seaweed and fish         73  Röd Kaviar
# 2154           8      Seafood  Seaweed and fish         73  Röd Kaviar
#
#       UnitPrice_today  OrderID  UnitPrice_inord  Quantity  Discount
# ...

# %%
suppliers = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/suppliers.csv',
                       usecols=['City','CompanyName', 'SupplierID'])

# %%
products = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/products.csv',
                       usecols=['ProductID','ProductName', 'CategoryID', 'SupplierID'])

# %%
categories = pd.read_csv('F:/PandasUdemy/course-files/northwind-mongo-master/categories1.csv',
                       usecols=['CategoryID','CategoryName'], index_col='CategoryID')

# %%
prod_cat = products.merge(categories, left_on='CategoryID', right_index=True)

# %%
prod_cat.head()
# Out:
#     ProductID         ProductName  SupplierID  CategoryID CategoryName
# 0           1                Chai           1           1    Beverages
# 1           2               Chang           1           1    Beverages
# 23         24  Guaraná Fantástica          10           1    Beverages
# 33         34       Sasquatch Ale          16           1    Beverages
# 34         35      Steeleye Stout          16           1    Beverages

# %%
prodcat_sup = prod_cat.merge(suppliers, on='SupplierID')

# %%
prodcat_sup
# Out:
#     ProductID             ProductName  SupplierID  CategoryID    CategoryName  \
# 0           1                    Chai           1           1       Beverages
# 1           2                   Chang           1           1       Beverages
# 2           3           Aniseed Syrup           1           2      Condiments
# 3          24      Guaraná Fantástica          10           1       Beverages
# 4          34           Sasquatch Ale          16           1       Beverages
# ..        ...                     ...         ...         ...             ...
# 72         48               Chocolade          22           3     Confections
# 73         22     Gustaf's Knäckebröd           9           5  Grains/Cereals
# 74         23                Tunnbröd           9           5  Grains/Cereals
# 75         56  Gnocchi di nonna Alice          26           5  Grains/Cereals
# 76         57          Ravioli Angelo          26           5  Grains/Cereals
#
# ...

# %%
products.merge(categories, left_on='CategoryID', right_index=True).merge(suppliers, on='SupplierID')
# Out:
#     ProductID             ProductName  SupplierID  CategoryID    CategoryName  \
# 0           1                    Chai           1           1       Beverages
# 1           2                   Chang           1           1       Beverages
# 2           3           Aniseed Syrup           1           2      Condiments
# 3          24      Guaraná Fantástica          10           1       Beverages
# 4          34           Sasquatch Ale          16           1       Beverages
# ..        ...                     ...         ...         ...             ...
# 72         48               Chocolade          22           3     Confections
# 73         22     Gustaf's Knäckebröd           9           5  Grains/Cereals
# 74         23                Tunnbröd           9           5  Grains/Cereals
# 75         56  Gnocchi di nonna Alice          26           5  Grains/Cereals
# 76         57          Ravioli Angelo          26           5  Grains/Cereals
#
# ...
